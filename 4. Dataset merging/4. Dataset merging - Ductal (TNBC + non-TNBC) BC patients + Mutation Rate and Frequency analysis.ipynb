# %% [markdown]
# # Dataset merging

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # TOTAL DUCTAL

# %% [markdown]
# ### Kan et al., Nature Communications 2018

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Breast Cancer (SMC 2018)")

# %%
data_mutation_TOTAL_ductal_Kan_et_al=pd.read_csv('mutation_table_Kan_et_al_Communications_2018_TOTAL_ductal.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_TOTAL_ductal_Kan_et_al = data_mutation_TOTAL_ductal_Kan_et_al.iloc[:, 1:]
data_mutation_TOTAL_ductal_Kan_et_al
# Out:
#                   PATIENT_ID    Tumor_Sample_Barcode Hugo_Symbol Chromosome  \
# 0     brca_smc_2018_BB01_002  brca_smc_2018_BB01_002       KALRN          3
# 1     brca_smc_2018_BB01_002  brca_smc_2018_BB01_002        ANK2          4
# 2     brca_smc_2018_BB01_002  brca_smc_2018_BB01_002      SORBS2          4
# 3     brca_smc_2018_BB01_002  brca_smc_2018_BB01_002     PCDHA11          5
# 4     brca_smc_2018_BB01_002  brca_smc_2018_BB01_002      WRNIP1          6
# ...                      ...                     ...         ...        ...
# 6047     brca_smc_2018_BR469     brca_smc_2018_BR469       PPIL2         22
# 6048     brca_smc_2018_BR469     brca_smc_2018_BR469       PORCN          X
# 6049     brca_smc_2018_BR469     brca_smc_2018_BR469       KIF4A          X
# 6050     brca_smc_2018_BR469     brca_smc_2018_BR469       MAML3          4
# 6051     brca_smc_2018_BR469     brca_smc_2018_BR469      MAP3K1          5
#
# ...

# %%
# check if there are duplicate rows 
data_mutation_TOTAL_ductal_Kan_et_al.duplicated().sum()
# Out:
# 0

# %%
data_mutation_TOTAL_ductal_Kan_et_al['Variant_Classification'].unique()
# Out:
# array(['Missense_Mutation', 'Nonsense_Mutation', 'Splice_Site',
#        'Frame_Shift_Ins', 'In_Frame_Ins', 'Frame_Shift_Del',
#        'In_Frame_Del', 'Nonstop_Mutation', 'RNA', "5'Flank",
#        'Translation_Start_Site', 'Intron', 'Silent', "5'UTR"],
#       dtype=object)

# %% [markdown]
# ### Banerji et al., Nature 2012

# %%
# Banerji et al., Nature 2012
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Breast Invasive Carcinoma (Broad, Nature 2012)")

# %%
data_mutation_TOTAL_ductal_Banerji=pd.read_csv('mutation_table_Banerji_et_al_Broad_Nature2012_TOTAL_ductal.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_TOTAL_ductal_Banerji = data_mutation_TOTAL_ductal_Banerji.iloc[:, 1:]
data_mutation_TOTAL_ductal_Banerji
# Out:
#      PATIENT_ID Tumor_Sample_Barcode Hugo_Symbol Chromosome  Start_Position  \
# 0      BR-V-002             BR-V-002         A2M         12         9229398
# 1      BR-V-002             BR-V-002      ACTBL2          5        56777819
# 2      BR-V-002             BR-V-002      ZFAND4         10        46143950
# 3      BR-V-002             BR-V-002       APEX1         14        20925406
# 4      BR-V-002             BR-V-002       BIRC6          2        32678880
# ...         ...                  ...         ...        ...             ...
# 4501   BR-M-200             BR-M-200      NUP107         12        69115632
# 4502   BR-M-200             BR-M-200       OR5I1         11        55703409
# 4503   BR-M-200             BR-M-200      PTP4A2          1        32377414
# 4504   BR-M-200             BR-M-200        SYT3         19        51140602
# 4505   BR-M-200             BR-M-200         TPR          1       186296647
#
# ...

# %% [markdown]
# ### Stephens et al., Nature 2012

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Breast Invasive Carcinoma (Sanger, Nature 2012)")

# %%
data_mutation_TOTAL_ductal_Stephens = pd.read_csv('mutation_table_Stephens_et_al_Sanger_Nature2012_TOTAL_ductal.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_TOTAL_ductal_Stephens = data_mutation_TOTAL_ductal_Stephens.iloc[:, 1:]
data_mutation_TOTAL_ductal_Stephens
# Out:
#      PATIENT_ID Tumor_Sample_Barcode Hugo_Symbol Chromosome  Start_Position  \
# 0       PD3857a              PD3857a      MYO15B         17        73592569
# 1       PD3857a              PD3857a     CTTNBP2          7       117501370
# 2       PD3857a              PD3857a      MAGEB6          X        26212583
# 3       PD3857a              PD3857a       FCRL5          1       157490878
# 4       PD3857a              PD3857a       CNTN2          1       205035644
# ...         ...                  ...         ...        ...             ...
# 5951    PD4939a              PD4939a       MUC16         19         9076181
# 5952    PD4939a              PD4939a      SHKBP1         19        41086542
# 5953    PD4939a              PD4939a      SPTLC3         20        13060509
# 5954    PD4939a              PD4939a      GPR112          X       135429006
# 5955    PD4939a              PD4939a        TP53         17         7578257
#
# ...

# %% [markdown]
# ### Krug et al., Cell 2020

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Proteogenomic landscape of breast cancer (CPTAC, Cell 2020)")

# %%
data_mutation_TOTAL_ductal_Krug = pd.read_csv('mutation_table_Krug_et_al_Cell_2018_FINAL.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_TOTAL_ductal_Krug = data_mutation_TOTAL_ductal_Krug.iloc[:, 1:]
data_mutation_TOTAL_ductal_Krug
# Out:
#       Tumor_Sample_Barcode PATIENT_ID Hugo_Symbol Chromosome  Start_Position  \
# 0                CPT000814  CPT000814        SZT2          1        43908878
# 1                CPT000814  CPT000814       AGBL4          1        49283877
# 2                CPT000814  CPT000814      PTGER3          1        71512957
# 3                CPT000814  CPT000814        HFM1          1        91859745
# 4                CPT000814  CPT000814       PRUNE          1       150999720
# ...                    ...        ...         ...        ...             ...
# 29013             X22BR006   X22BR006      ZNF652         17        47375881
# 29014             X22BR006   X22BR006       GALK1         17        73754610
# 29015             X22BR006   X22BR006      ZNF584         19        58928243
# 29016             X22BR006   X22BR006       ASXL1         20        31022238
# 29017             X22BR006   X22BR006       SYTL5          X        37948781
#
# ...

# %% [markdown]
# ### TCGA, Cell 2018

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Breast Invasive Carcinoma (TCGA, PanCancer Atlas)")

# %%
data_mutation_TOTAL_ductal_TCGA=pd.read_csv('mutation_table_TCGA_PanCancer2018_TOTAL_ductal.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_TOTAL_ductal_TCGA=data_mutation_TOTAL_ductal_TCGA.iloc[:, 1:]
data_mutation_TOTAL_ductal_TCGA
# Out:
#          PATIENT_ID Tumor_Sample_Barcode Hugo_Symbol Chromosome  \
# 0      TCGA-3C-AALI      TCGA-3C-AALI-01        BTRC         10
# 1      TCGA-3C-AALI      TCGA-3C-AALI-01       NFKB2         10
# 2      TCGA-3C-AALI      TCGA-3C-AALI-01       DHX32         10
# 3      TCGA-3C-AALI      TCGA-3C-AALI-01       FOXI2         10
# 4      TCGA-3C-AALI      TCGA-3C-AALI-01        NMT2         10
# ...             ...                  ...         ...        ...
# 94479  TCGA-WT-AB41      TCGA-WT-AB41-01      ALPPL2          2
# 94480  TCGA-WT-AB41      TCGA-WT-AB41-01       ASAP2          2
# 94481  TCGA-WT-AB41      TCGA-WT-AB41-01        ECE2          3
# 94482  TCGA-WT-AB41      TCGA-WT-AB41-01       KCNH8          3
# 94483  TCGA-WT-AB41      TCGA-WT-AB41-01     CCDC71L          7
#
#        Start_Position  End_Position Variant_Classification Variant_Type  \
# 0         103292795.0   103292795.0                 Silent          SNP
# ...

# %% [markdown]
# ### Lefebvre et al., Metastatic Breast Cancer (INSERM, PLoS Med 2016)

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Metastatic Breast Cancer (INSERM, PLoS Med 2016)")

# %%
data_mutation_TOTAL_ductal_Lefebvre=pd.read_csv('mutation_table_Lefebvre_et_al_INSERM_PLoS_Med_2016_FINAL.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_TOTAL_ductal_Lefebvre=data_mutation_TOTAL_ductal_Lefebvre.iloc[:, 1:]
data_mutation_TOTAL_ductal_Lefebvre
# Out:
#       Tumor_Sample_Barcode PATIENT_ID    Hugo_Symbol Chromosome  \
# 0                   MBC_81     MBC_81         VWA5B1          1
# 1                   MBC_81     MBC_81           GJB5          1
# 2                   MBC_81     MBC_81          LPHN2          1
# 3                   MBC_81     MBC_81            FLG          1
# 4                   MBC_81     MBC_81         PRSS38          1
# ...                    ...        ...            ...        ...
# 22936              MBC_215    MBC_215          POMT1          9
# 22937              MBC_216    MBC_216          NCOR1         17
# 22938               MBC_24     MBC_24    RP11-44M6.3          7
# 22939               MBC_67     MBC_67       NEBL-AS1         10
# 22940              MBC_192    MBC_192  RP11-596D21.1         14
#
#        Start_Position  End_Position Variant_Classification Variant_Type  \
# 0            20639336      20639336                 Silent          SNP
# ...

# %%
# check if there are duplicate rows 
data_mutation_TOTAL_ductal_Lefebvre.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### MBC project (Provisional, Dec 2021)

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/The Metastatic Breast Cancer Project (Provisional, December 2021)")

# %%
data_mutation_TOTAL_ductal_MBC = pd.read_csv('mutation_table_MBCproject_TOTAL_ductal.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_TOTAL_ductal_MBC = data_mutation_TOTAL_ductal_MBC.iloc[:, 1:]
data_mutation_TOTAL_ductal_MBC
# Out:
#                 PATIENT_ID                    Tumor_Sample_Barcode  \
# 0      MBCProject_0aTBfPcG  MBC-MBCProject_0aTBfPcG-Tumor-SM-DL3W1
# 1      MBCProject_0aTBfPcG  MBC-MBCProject_0aTBfPcG-Tumor-SM-DL3W1
# 2      MBCProject_0aTBfPcG  MBC-MBCProject_0aTBfPcG-Tumor-SM-DL3W1
# 3      MBCProject_0aTBfPcG  MBC-MBCProject_0aTBfPcG-Tumor-SM-DL3W1
# 4      MBCProject_0aTBfPcG  MBC-MBCProject_0aTBfPcG-Tumor-SM-DL3W1
# ...                    ...                                     ...
# 19868  MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19869  MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19870  MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19871  MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19872  MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#       Hugo_Symbol  Chromosome  Start_Position  End_Position  \
# 0         DNAJC11           1         6697390       6697390
# ...

# %% [markdown]
# ### Merging all the datasets

# %%
# concatenate all the datasets into one larger dataset
data_mutation_TOTAL_ductal = pd.concat([data_mutation_TOTAL_ductal_Kan_et_al, data_mutation_TOTAL_ductal_Banerji, data_mutation_TOTAL_ductal_Stephens, data_mutation_TOTAL_ductal_Krug, data_mutation_TOTAL_ductal_TCGA,data_mutation_TOTAL_ductal_Lefebvre, data_mutation_TOTAL_ductal_MBC], axis=0)
data_mutation_TOTAL_ductal
# Out:
#                    PATIENT_ID                    Tumor_Sample_Barcode  \
# 0      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 1      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 2      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 3      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 4      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# ...                       ...                                     ...
# 19868     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19869     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19870     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19871     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19872     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#       Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0           KALRN          3     123988087.0   123988087.0
# ...

# %%
data_mutation_TOTAL_ductal['PATIENT_ID'].nunique()
# Out:
# 1554

# %%
data_mutation_TOTAL_ductal['Hugo_Symbol'].nunique()
# Out:
# 19985

# %% [markdown]
# ### Mutation Rate analysis

# %%
# add a column to the dataset representing the mutated bases length (End_Position-Start_Position+1)
data_mutation_TOTAL_ductal.loc[:, 'Mutation_length'] = data_mutation_TOTAL_ductal['End_Position']-data_mutation_TOTAL_ductal['Start_Position']+1
data_mutation_TOTAL_ductal
# Out:
#                    PATIENT_ID                    Tumor_Sample_Barcode  \
# 0      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 1      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 2      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 3      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 4      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# ...                       ...                                     ...
# 19868     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19869     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19870     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19871     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19872     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#       Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0           KALRN          3     123988087.0   123988087.0
# ...

# %%
# extract PATIENT_ID and Mutation_length
pts_mutation_length_TOTAL_ductal = data_mutation_TOTAL_ductal[['PATIENT_ID', 'Mutation_length']]
pts_mutation_length_TOTAL_ductal
# Out:
#                    PATIENT_ID  Mutation_length
# 0      brca_smc_2018_BB01_002              1.0
# 1      brca_smc_2018_BB01_002              1.0
# 2      brca_smc_2018_BB01_002              1.0
# 3      brca_smc_2018_BB01_002              1.0
# 4      brca_smc_2018_BB01_002              1.0
# ...                       ...              ...
# 19868     MBCProject_zyt5TKFB              1.0
# 19869     MBCProject_zyt5TKFB              1.0
# 19870     MBCProject_zyt5TKFB              1.0
# 19871     MBCProject_zyt5TKFB              1.0
# 19872     MBCProject_zyt5TKFB              1.0
#
# [182830 rows x 2 columns]

# %%
# group by PATIENT_ID and sum the mutation lengths for each pts
mutation_TOTAL_ductal_group_by_pts=pts_mutation_length_TOTAL_ductal.groupby(['PATIENT_ID'])['Mutation_length'].sum().reset_index()
mutation_TOTAL_ductal_group_by_pts.rename(columns = {'Mutation_length':'Total_sum_mutated_bases'}, inplace = True)
mutation_TOTAL_ductal_group_by_pts
# Out:
#                PATIENT_ID  Total_sum_mutated_bases
# 0                BR-M-005                     26.0
# 1                BR-M-027                     71.0
# 2                BR-M-030                     27.0
# 3                BR-M-034                     31.0
# 4                BR-M-036                     16.0
# ...                   ...                      ...
# 1549  brca_smc_2018_BR431                     26.0
# 1550  brca_smc_2018_BR437                     58.0
# 1551  brca_smc_2018_BR442                     39.0
# 1552  brca_smc_2018_BR457                     59.0
# 1553  brca_smc_2018_BR469                     16.0
#
# [1554 rows x 2 columns]

# %%
# extract Hugo_Symbol and Gene_length
gene_length_for_each_mutation_TOTAL_ductal = data_mutation_TOTAL_ductal[['Hugo_Symbol', 'Gene_length']]
gene_length_for_each_mutation_TOTAL_ductal
# Out:
#       Hugo_Symbol  Gene_length
# 0           KALRN       646303
# 1            ANK2       565632
# 2          SORBS2       371209
# 3         PCDHA11       143241
# 4          WRNIP1        21539
# ...           ...          ...
# 19868       NRSN2        12879
# 19869      CHRNA4        34334
# 19870      CHRNA4        34334
# 19871       KCNQ2        66452
# 19872        XBP1         6043
#
# [182830 rows x 2 columns]

# %%
# look at the number of distinct genes
gene_length_for_each_mutation_TOTAL_ductal['Hugo_Symbol'].nunique()
# Out:
# 19985

# %% [markdown]
# In the dataset there are 19985 distinct genes.

# %%
# group by gene (Hugo_Symbol) 
mutation_TOTAL_ductal_group_by_gene=gene_length_for_each_mutation_TOTAL_ductal.groupby(['Hugo_Symbol'])['Gene_length'].max().reset_index()
mutation_TOTAL_ductal_group_by_gene
# Out:
#         Hugo_Symbol  Gene_length
# 0              A1BG         8322
# 1              A1CF        86267
# 2               A2M        48566
# 3             A2ML1        64530
# 4         A2ML1-AS1        54729
# ...             ...          ...
# 19980          ZZZ3       121004
# 19981  hsa-mir-1199         2527
# 19982  hsa-mir-6080        32337
# 19983  hsa-mir-7162        25340
# 19984        snoU13          103
#
# [19985 rows x 2 columns]

# %%
# compute the total gene length (for all the genes in the dataset)
total_GeneLength_TOTAL_ductal = mutation_TOTAL_ductal_group_by_gene['Gene_length'].sum()
total_GeneLength_TOTAL_ductal
# Out:
# 1319700250

# %%
# add a column to the dataset representing the mutation rate for each patient (Mutation_rate= Mutation_length/total_gene_length)
mutation_TOTAL_ductal_group_by_pts["Mutation_rate"] = mutation_TOTAL_ductal_group_by_pts["Total_sum_mutated_bases"]/total_GeneLength_TOTAL_ductal
mutation_TOTAL_ductal_group_by_pts
# Out:
#                PATIENT_ID  Total_sum_mutated_bases  Mutation_rate
# 0                BR-M-005                     26.0   1.970144e-08
# 1                BR-M-027                     71.0   5.380010e-08
# 2                BR-M-030                     27.0   2.045919e-08
# 3                BR-M-034                     31.0   2.349018e-08
# 4                BR-M-036                     16.0   1.212397e-08
# ...                   ...                      ...            ...
# 1549  brca_smc_2018_BR431                     26.0   1.970144e-08
# 1550  brca_smc_2018_BR437                     58.0   4.394937e-08
# 1551  brca_smc_2018_BR442                     39.0   2.955217e-08
# 1552  brca_smc_2018_BR457                     59.0   4.470712e-08
# 1553  brca_smc_2018_BR469                     16.0   1.212397e-08
#
# [1554 rows x 3 columns]

# %%
# multiply the Mutation_rate values for 10^6
mutation_TOTAL_ductal_group_by_pts["Mutation_rate*10^6"] = mutation_TOTAL_ductal_group_by_pts["Mutation_rate"]*1000000
mutation_TOTAL_ductal_group_by_pts
# Out:
#                PATIENT_ID  Total_sum_mutated_bases  Mutation_rate  \
# 0                BR-M-005                     26.0   1.970144e-08
# 1                BR-M-027                     71.0   5.380010e-08
# 2                BR-M-030                     27.0   2.045919e-08
# 3                BR-M-034                     31.0   2.349018e-08
# 4                BR-M-036                     16.0   1.212397e-08
# ...                   ...                      ...            ...
# 1549  brca_smc_2018_BR431                     26.0   1.970144e-08
# 1550  brca_smc_2018_BR437                     58.0   4.394937e-08
# 1551  brca_smc_2018_BR442                     39.0   2.955217e-08
# 1552  brca_smc_2018_BR457                     59.0   4.470712e-08
# 1553  brca_smc_2018_BR469                     16.0   1.212397e-08
#
#       Mutation_rate*10^6
# 0               0.019701
# 1               0.053800
# 2               0.020459
# 3               0.023490
# 4               0.012124
# ...

# %%
# the PATIENT_IDs are sorted for descending order of mutation rate 
mutation_TOTAL_ductal_group_by_pts= mutation_TOTAL_ductal_group_by_pts.sort_values(by="Mutation_rate", ascending=False)
mutation_TOTAL_ductal_group_by_pts
# Out:
#                PATIENT_ID  Total_sum_mutated_bases  Mutation_rate  \
# 951          TCGA-BH-A18V                  25073.0   1.899901e-05
# 562          TCGA-A2-A0EV                  24708.0   1.872243e-05
# 702          TCGA-AC-A8OP                  23143.0   1.753656e-05
# 1288             X01BR043                  13093.0   9.921192e-06
# 663          TCGA-A8-A08L                   9075.0   6.876562e-06
# ...                   ...                      ...            ...
# 283               MBC_149                      3.0   2.273243e-09
# 1488  brca_smc_2018_BR099                      3.0   2.273243e-09
# 302               MBC_166                      1.0   7.577478e-10
# 296               MBC_160                      1.0   7.577478e-10
# 363                MBC_27                      1.0   7.577478e-10
#
#       Mutation_rate*10^6
# 951            18.999011
# 562            18.722433
# 702            17.536558
# 1288            9.921192
# 663             6.876562
# ...

# %%
patient_mutation_rate_TOTAL_ductal=mutation_TOTAL_ductal_group_by_pts[['PATIENT_ID', 'Mutation_rate*10^6' ]]
patient_mutation_rate_TOTAL_ductal
# Out:
#                PATIENT_ID  Mutation_rate*10^6
# 951          TCGA-BH-A18V           18.999011
# 562          TCGA-A2-A0EV           18.722433
# 702          TCGA-AC-A8OP           17.536558
# 1288             X01BR043            9.921192
# 663          TCGA-A8-A08L            6.876562
# ...                   ...                 ...
# 283               MBC_149            0.002273
# 1488  brca_smc_2018_BR099            0.002273
# 302               MBC_166            0.000758
# 296               MBC_160            0.000758
# 363                MBC_27            0.000758
#
# [1554 rows x 2 columns]

# %%
patient_mutation_rate_TOTAL_ductal[patient_mutation_rate_TOTAL_ductal['Mutation_rate*10^6'] < 0.0035]
# Out:
#                PATIENT_ID  Mutation_rate*10^6
# 350                MBC_21            0.003031
# 1467  brca_smc_2018_BR033            0.003031
# 247               MBC_116            0.003031
# 1191         TCGA-EW-A1P1            0.002273
# 283               MBC_149            0.002273
# 1488  brca_smc_2018_BR099            0.002273
# 302               MBC_166            0.000758
# 296               MBC_160            0.000758
# 363                MBC_27            0.000758

# %%
len(patient_mutation_rate_TOTAL_ductal[patient_mutation_rate_TOTAL_ductal['Mutation_rate*10^6'] < 0.0035])
# Out:
# 9

# %%
# adjust the indices
patient_mutation_rate_TOTAL_ductal = patient_mutation_rate_TOTAL_ductal.reset_index()
patient_mutation_rate_TOTAL_ductal = patient_mutation_rate_TOTAL_ductal.drop('index', axis=1)
patient_mutation_rate_TOTAL_ductal
# Out:
#                PATIENT_ID  Mutation_rate*10^6
# 0            TCGA-BH-A18V           18.999011
# 1            TCGA-A2-A0EV           18.722433
# 2            TCGA-AC-A8OP           17.536558
# 3                X01BR043            9.921192
# 4            TCGA-A8-A08L            6.876562
# ...                   ...                 ...
# 1549              MBC_149            0.002273
# 1550  brca_smc_2018_BR099            0.002273
# 1551              MBC_166            0.000758
# 1552              MBC_160            0.000758
# 1553               MBC_27            0.000758
#
# [1554 rows x 2 columns]

# %%
patient_mutation_rate_TOTAL_ductal.head(30).reset_index()
# Out:
#     index           PATIENT_ID  Mutation_rate*10^6
# 0       0         TCGA-BH-A18V           18.999011
# 1       1         TCGA-A2-A0EV           18.722433
# 2       2         TCGA-AC-A8OP           17.536558
# 3       3             X01BR043            9.921192
# 4       4         TCGA-A8-A08L            6.876562
# 5       5         TCGA-AN-A046            5.762672
# 6       6         TCGA-AC-A23H            4.892778
# 7       7         TCGA-LL-A8F5            1.918618
# 8       8  MBCProject_99CdCOHm            1.760248
# 9       9         TCGA-BH-A18G            1.538986
# 10     10         TCGA-AN-A0AK            1.466242
# 11     11         TCGA-D8-A1XK            1.160870
# 12     12         TCGA-BH-A0HF            1.104039
# 13     13             X18BR003            1.104039
# 14     14              MBC_189            0.975979
# 15     15         TCGA-AO-A128            0.970675
# 16     16         TCGA-D8-A1XQ            0.969917
# ...

# %% [markdown]
# ### Extract hypermutated patients

# %%
hyper_patients = patient_mutation_rate_TOTAL_ductal.head(18).reset_index()
hyper_patients = hyper_patients[['PATIENT_ID']]
hyper_patients
# Out:
#              PATIENT_ID
# 0          TCGA-BH-A18V
# 1          TCGA-A2-A0EV
# 2          TCGA-AC-A8OP
# 3              X01BR043
# 4          TCGA-A8-A08L
# 5          TCGA-AN-A046
# 6          TCGA-AC-A23H
# 7          TCGA-LL-A8F5
# 8   MBCProject_99CdCOHm
# 9          TCGA-BH-A18G
# 10         TCGA-AN-A0AK
# 11         TCGA-D8-A1XK
# 12         TCGA-BH-A0HF
# 13             X18BR003
# 14              MBC_189
# 15         TCGA-AO-A128
# 16         TCGA-D8-A1XQ
# 17         TCGA-D8-A1JA

# %% [markdown]
# There are 18 hypermutated patients.

# %%
patient_mutation_rate_TOTAL_ductal.tail(30).reset_index()
# Out:
#     index              PATIENT_ID  Mutation_rate*10^6
# 0    1524  brca_smc_2018_BB01_049            0.006820
# 1    1525            TCGA-A2-A25F            0.006820
# 2    1526            TCGA-PL-A8LY            0.006062
# 3    1527  brca_smc_2018_BB01_011            0.006062
# 4    1528  brca_smc_2018_BB01_016            0.006062
# 5    1529  brca_smc_2018_BB01_022            0.006062
# 6    1530     brca_smc_2018_BR206            0.006062
# 7    1531     brca_smc_2018_BR167            0.006062
# 8    1532     brca_smc_2018_BR143            0.005304
# 9    1533  brca_smc_2018_BB01_004            0.005304
# 10   1534     brca_smc_2018_BR300            0.005304
# 11   1535                 MBC_101            0.005304
# 12   1536                 PD4129a            0.005304
# 13   1537     brca_smc_2018_BR175            0.004546
# 14   1538     brca_smc_2018_BR081            0.004546
# 15   1539  brca_smc_2018_BB01_040            0.003789
# ...

# %% [markdown]
# ### Extract hypomutated patients
# I consider a threshold of mutation rate of 0.0035. In this way, 9 patients are deleted.

# %%
hypo_patients = patient_mutation_rate_TOTAL_ductal.tail(9).reset_index()
hypo_patients = hypo_patients[['PATIENT_ID']]
hypo_patients
# Out:
#             PATIENT_ID
# 0               MBC_21
# 1  brca_smc_2018_BR033
# 2              MBC_116
# 3         TCGA-EW-A1P1
# 4              MBC_149
# 5  brca_smc_2018_BR099
# 6              MBC_166
# 7              MBC_160
# 8               MBC_27

# %% [markdown]
# ### Concatenate the hypermutated patients with the hypomutated patients

# %%
hyper_hypo_patients_total_ductal = pd.concat([hyper_patients, hypo_patients])
hyper_hypo_patients_total_ductal
# Out:
#              PATIENT_ID
# 0          TCGA-BH-A18V
# 1          TCGA-A2-A0EV
# 2          TCGA-AC-A8OP
# 3              X01BR043
# 4          TCGA-A8-A08L
# 5          TCGA-AN-A046
# 6          TCGA-AC-A23H
# 7          TCGA-LL-A8F5
# 8   MBCProject_99CdCOHm
# 9          TCGA-BH-A18G
# 10         TCGA-AN-A0AK
# 11         TCGA-D8-A1XK
# 12         TCGA-BH-A0HF
# 13             X18BR003
# 14              MBC_189
# 15         TCGA-AO-A128
# 16         TCGA-D8-A1XQ
# 17         TCGA-D8-A1JA
# 0                MBC_21
# 1   brca_smc_2018_BR033
# 2               MBC_116
# 3          TCGA-EW-A1P1
# 4               MBC_149
# 5   brca_smc_2018_BR099
# 6               MBC_166
# 7               MBC_160
# 8                MBC_27

# %%
# save this dataset 
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi")
hyper_hypo_patients_total_ductal.to_csv("hyper_hypo_patients_total_ductal.csv", index=False, sep='\t')

# %%
hyper_hypo_patients_total_ductal.shape
# Out:
# (27, 1)

# %%
mutation_TOTAL_ductal_group_by_pts
# Out:
#                PATIENT_ID  Total_sum_mutated_bases  Mutation_rate  \
# 951          TCGA-BH-A18V                  25073.0   1.899901e-05
# 562          TCGA-A2-A0EV                  24708.0   1.872243e-05
# 702          TCGA-AC-A8OP                  23143.0   1.753656e-05
# 1288             X01BR043                  13093.0   9.921192e-06
# 663          TCGA-A8-A08L                   9075.0   6.876562e-06
# ...                   ...                      ...            ...
# 283               MBC_149                      3.0   2.273243e-09
# 1488  brca_smc_2018_BR099                      3.0   2.273243e-09
# 302               MBC_166                      1.0   7.577478e-10
# 296               MBC_160                      1.0   7.577478e-10
# 363                MBC_27                      1.0   7.577478e-10
#
#       Mutation_rate*10^6
# 951            18.999011
# 562            18.722433
# 702            17.536558
# 1288            9.921192
# 663             6.876562
# ...

# %%
patients=np.arange(0,1554,1)
# convert a series into a Numpy array
mutation_rate=mutation_TOTAL_ductal_group_by_pts[['Mutation_rate*10^6']].to_numpy()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 8)
plt.yscale("log") 
#set axes limit
plt.ylim(0.001, 1000)
plt.scatter(patients, mutation_rate)
plt.xlabel("Patients")
plt.ylabel("Mutation rate per 10^6 bases (log scale)")
plt.show()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (8, 6)
plt.yscale("log") 
#set axes limit
plt.xlim(-100, 1650)
#plt.ylim(0.001, 1000)
plt.scatter(patients, mutation_rate)
plt.xlabel("Patients", fontsize=11)
plt.ylabel("Mutation rate per 10^6 bases (log scale)", fontsize=11)
plt.axvline(x=17, color='green', linestyle='-', linewidth = 1.2, label='Hyper-mutated threshold')
plt.axvline(x=1541, color='red', linestyle='-', linewidth = 1.2, label='Hypo-mutated threshold')
plt.legend(loc='upper center', bbox_to_anchor=(0.74, 1))
#bbox_to_anchor=(0.5, 1.15)
plt.show()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (8, 6)
plt.yscale("log") 
#set axes limit
plt.xlim(-100, 1650)
plt.ylim(0.001, 1000)
plt.scatter(patients, mutation_rate)
plt.xlabel("Patients")
plt.ylabel("Mutation rate per 10^6 bases (log scale)")
plt.axvline(x=17, color='green', linestyle='-', linewidth = 1, label='x = 17 - threshold hyper')
plt.axvline(x=1541, color='red', linestyle='-', linewidth = 1, label='x = 1541 - threshold hypo')
plt.legend(loc='upper right')
plt.show()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 8)
plt.yscale("log") 
#set axes limit
#plt.xlim(-100, 1650)
#plt.ylim(0.001, 1000)
plt.scatter(patients, mutation_rate)
plt.xlabel("Total ductal patients", fontsize=18)
plt.ylabel("Mutation rate per 10^6 bases (log scale)", fontsize=18)
plt.axvline(x=17, color='green', linestyle='-', linewidth = 1.5, label='x = 17 - threshold hyper')
plt.axvline(x=1541, color='red', linestyle='-', linewidth = 1.5, label='x = 1541 - threshold hypo')
#plt.title ("Total Ductal",fontsize=20)
#plt.legend(loc='upper right')
plt.show()

# %%
# ZOOM
# %matplotlib inline
fig = plt.figure(figsize=(10, 8))
plt.plot(patients, mutation_rate)
#plt.xticks(np.arange(min(patients_TOTAL_ductal), max(patients_TOTAL_ductal)+1, 1.0))
plt.yscale("log")
plt.xlabel("Patients")
plt.ylabel("Mutation rate per 10^6 bases (log scale)")
plt.title ("Zoom",fontsize=20)
#plt.axvline(x=x_max_TCGA+1, color='red', linestyle='-')
x1, y1 = (patients[0], patient_mutation_rate_TOTAL_ductal.loc[0, 'Mutation_rate*10^6'])
x2, y2 = (patients[120], patient_mutation_rate_TOTAL_ductal.loc[120, 'Mutation_rate*10^6'])
#plt.axvline(x=x_max_TCGA-1, color='red', linestyle='-', linewidth = 1,  label = 'x_max-1')
plt.axvline(x=17, color='green', linestyle='-', linewidth = 1)
#plt.axhline(y=y_max_TCGA_avg, color='black', linestyle='--', linewidth = 1, label = 'Mutation Rate medio')
#plt.legend(loc='upper right', fontsize = 7)
plt.gca().set_xlim(x1, x2)
plt.gca().set_ylim(y2, y1)
# Out:
# (0.20610740961820687, 18.999011328519487)

# %%
# ZOOM
# %matplotlib inline
fig = plt.figure(figsize=(10, 8))
plt.plot(patients, mutation_rate)
#plt.xticks(np.arange(min(patients_TOTAL_ductal), max(patients_TOTAL_ductal)+1, 1.0))
plt.yscale("log")
plt.xlabel("Patients")
plt.ylabel("Mutation rate per 10^6 bases (log scale)")
plt.title ("Zoom",fontsize=20)
#plt.axvline(x=x_max_TCGA+1, color='red', linestyle='-')
x1, y1 = (patients[1000], patient_mutation_rate_TOTAL_ductal.loc[1000, 'Mutation_rate*10^6'])
x2, y2 = (patients[1553], patient_mutation_rate_TOTAL_ductal.loc[1553, 'Mutation_rate*10^6'])
#plt.axvline(x=x_max_TCGA-1, color='red', linestyle='-', linewidth = 1,  label = 'x_max-1')
plt.axvline(x=1541, color='green', linestyle='-', linewidth = 1)
#plt.axhline(y=y_max_TCGA_avg, color='black', linestyle='--', linewidth = 1, label = 'Mutation Rate medio')
#plt.legend(loc='upper right', fontsize = 7)
plt.gca().set_xlim(x1, x2)
plt.gca().set_ylim(y2, y1)
# Out:
# (0.0007577478294787017, 0.04016063496237119)

# %% [markdown]
# ### Mutation Frequency analysis

# %%
genes_patients_TOTAL_ductal=data_mutation_TOTAL_ductal[['PATIENT_ID', 'Hugo_Symbol']]
genes_patients_TOTAL_ductal
# Out:
#                    PATIENT_ID Hugo_Symbol
# 0      brca_smc_2018_BB01_002       KALRN
# 1      brca_smc_2018_BB01_002        ANK2
# 2      brca_smc_2018_BB01_002      SORBS2
# 3      brca_smc_2018_BB01_002     PCDHA11
# 4      brca_smc_2018_BB01_002      WRNIP1
# ...                       ...         ...
# 19868     MBCProject_zyt5TKFB       NRSN2
# 19869     MBCProject_zyt5TKFB      CHRNA4
# 19870     MBCProject_zyt5TKFB      CHRNA4
# 19871     MBCProject_zyt5TKFB       KCNQ2
# 19872     MBCProject_zyt5TKFB        XBP1
#
# [182830 rows x 2 columns]

# %%
genes_patients_TOTAL_ductal=genes_patients_TOTAL_ductal.drop_duplicates()
genes_patients_TOTAL_ductal
# Out:
#                    PATIENT_ID Hugo_Symbol
# 0      brca_smc_2018_BB01_002       KALRN
# 1      brca_smc_2018_BB01_002        ANK2
# 2      brca_smc_2018_BB01_002      SORBS2
# 3      brca_smc_2018_BB01_002     PCDHA11
# 4      brca_smc_2018_BB01_002      WRNIP1
# ...                       ...         ...
# 19867     MBCProject_zyt5TKFB       SSC5D
# 19868     MBCProject_zyt5TKFB       NRSN2
# 19869     MBCProject_zyt5TKFB      CHRNA4
# 19871     MBCProject_zyt5TKFB       KCNQ2
# 19872     MBCProject_zyt5TKFB        XBP1
#
# [165291 rows x 2 columns]

# %%
n_of_pts_per_gene_TOTAL_ductal= genes_patients_TOTAL_ductal.groupby(['Hugo_Symbol'])['PATIENT_ID'].count().reset_index()
n_of_pts_per_gene_TOTAL_ductal.rename(columns = {'PATIENT_ID':'Num_pts_per_gene'}, inplace = True)
n_of_pts_per_gene_TOTAL_ductal
# Out:
#         Hugo_Symbol  Num_pts_per_gene
# 0              A1BG                 6
# 1              A1CF                10
# 2               A2M                27
# 3             A2ML1                24
# 4         A2ML1-AS1                 1
# ...             ...               ...
# 19980          ZZZ3                 8
# 19981  hsa-mir-1199                 2
# 19982  hsa-mir-6080                 7
# 19983  hsa-mir-7162                 3
# 19984        snoU13                 3
#
# [19985 rows x 2 columns]

# %%
tot_pts_TOTAL_ductal = 1554

# %%
# add a column to the n_of_pts_per_gene dataframe representing the mutation frequency for each gene
n_of_pts_per_gene_TOTAL_ductal["Mutation_frequency (%)"] = (n_of_pts_per_gene_TOTAL_ductal["Num_pts_per_gene"]*100)/tot_pts_TOTAL_ductal
n_of_pts_per_gene_TOTAL_ductal
# Out:
#         Hugo_Symbol  Num_pts_per_gene  Mutation_frequency (%)
# 0              A1BG                 6                0.386100
# 1              A1CF                10                0.643501
# 2               A2M                27                1.737452
# 3             A2ML1                24                1.544402
# 4         A2ML1-AS1                 1                0.064350
# ...             ...               ...                     ...
# 19980          ZZZ3                 8                0.514801
# 19981  hsa-mir-1199                 2                0.128700
# 19982  hsa-mir-6080                 7                0.450450
# 19983  hsa-mir-7162                 3                0.193050
# 19984        snoU13                 3                0.193050
#
# [19985 rows x 3 columns]

# %%
# the numbers of patients per gene are sorted in descending order
n_of_pts_per_gene_TOTAL_ductal= n_of_pts_per_gene_TOTAL_ductal.sort_values(by="Num_pts_per_gene", ascending=False)
n_of_pts_per_gene_TOTAL_ductal
# Out:
#       Hugo_Symbol  Num_pts_per_gene  Mutation_frequency (%)
# 17847        TP53               638               41.055341
# 12723      PIK3CA               470               30.244530
# 18338         TTN               361               23.230373
# 6442        GATA3               186               11.969112
# 10645       MUC16               184               11.840412
# ...           ...               ...                     ...
# 4264     CYP4F24P                 1                0.064350
# 4266     CYP4F30P                 1                0.064350
# 10131      MIR204                 1                0.064350
# 10130      MIR203                 1                0.064350
# 14846     RPS6KL1                 1                0.064350
#
# [19985 rows x 3 columns]

# %%
gene_mutation_frequency_TOTAL_ductal = n_of_pts_per_gene_TOTAL_ductal[['Hugo_Symbol', 'Mutation_frequency (%)']]
gene_mutation_frequency_TOTAL_ductal
# Out:
#       Hugo_Symbol  Mutation_frequency (%)
# 17847        TP53               41.055341
# 12723      PIK3CA               30.244530
# 18338         TTN               23.230373
# 6442        GATA3               11.969112
# 10645       MUC16               11.840412
# ...           ...                     ...
# 4264     CYP4F24P                0.064350
# 4266     CYP4F30P                0.064350
# 10131      MIR204                0.064350
# 10130      MIR203                0.064350
# 14846     RPS6KL1                0.064350
#
# [19985 rows x 2 columns]

# %%
# select the first 50 genes
highest_mutated_genes_TOTAL_ductal=gene_mutation_frequency_TOTAL_ductal.head(50)
highest_mutated_genes_TOTAL_ductal
# Out:
#       Hugo_Symbol  Mutation_frequency (%)
# 17847        TP53               41.055341
# 12723      PIK3CA               30.244530
# 18338         TTN               23.230373
# 6442        GATA3               11.969112
# 10645       MUC16               11.840412
# 8798        KMT2C                8.880309
# 9708       MAP3K1                8.108108
# 14970        RYR2                8.043758
# 16843       SYNE1                7.593308
# 6095          FLG                7.335907
# 7463        HMCN1                7.207207
# 11564       OBSCN                6.949807
# 18654       USH2A                6.499356
# 4868          DST                6.177606
# 11006         NEB                6.048906
# 14969        RYR1                5.984556
# 16468       SPTA1                5.727156
# 35         ABCA13                5.662806
# 14971        RYR3                5.598456
# 3957        CSMD1                5.405405
# 2469      CACNA1E                5.276705
# ...

# %%
mutated_gene_names=highest_mutated_genes_TOTAL_ductal['Hugo_Symbol'].tolist()

# %%
# increase the quality and resolution of the chart
from IPython.display import set_matplotlib_formats
import matplotlib_inline.backend_inline

matplotlib_inline.backend_inline.set_matplotlib_formats('retina')
# set default figure size.
plt.rcParams['figure.figsize'] = (12, 8)
fig, ax = plt.subplots()
h=ax.bar(highest_mutated_genes_TOTAL_ductal['Hugo_Symbol'], highest_mutated_genes_TOTAL_ductal['Mutation_frequency (%)'], label=mutated_gene_names)
xticks_pos = [0.65*patch.get_width() + patch.get_xy()[0] for patch in h]

_ = plt.xticks(xticks_pos, mutated_gene_names,  ha='right', rotation=45)
#plt.title('Highest mutated genes', fontsize=14)
plt.xlabel('Mutated gene', fontsize=14)
plt.ylabel('Mutation frequency (%)', fontsize=14)


# First, let's remove the top, right and left spines (figure borders)
# which really aren't necessary for a bar chart.
# Also, make the bottom spine gray instead of black.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')

# Second, remove the ticks as well.
ax.tick_params(bottom=False, left=False)

# Third, add a horizontal grid (but keep the vertical grid hidden).
# Color the lines a light gray as well.
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Add text annotations to the top of the bars.
# Note, you'll have to adjust this slightly (the 0.3)
# with different data.
for bar in h:
  ax.text(
      bar.get_x() + bar.get_width() / 2,
      bar.get_height() + 0.3,
      round(bar.get_height(), 1),
      rotation='vertical',
      horizontalalignment='center'
  )


fig.tight_layout()

# %% [markdown]
# # DUCTAL and TRIPLE-NEGATIVE

# %% [markdown]
# ### Kan et al., Nature Communications 2018

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Breast Cancer (SMC 2018)")

# %%
data_mutation_ductal_TN_Kan = pd.read_csv('mutation_table_Kan_et_al_Communications_2018_TN_and_ductal.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_ductal_TN_Kan = data_mutation_ductal_TN_Kan.iloc[:, 1:]
data_mutation_ductal_TN_Kan
# Out:
#                   PATIENT_ID    Tumor_Sample_Barcode   Hugo_Symbol Chromosome  \
# 0     brca_smc_2018_BB01_004  brca_smc_2018_BB01_004       TMEM131          2
# 1     brca_smc_2018_BB01_004  brca_smc_2018_BB01_004        DNAAF1         16
# 2     brca_smc_2018_BB01_004  brca_smc_2018_BB01_004          TP53         17
# 3     brca_smc_2018_BB01_004  brca_smc_2018_BB01_004          MATK         19
# 4     brca_smc_2018_BB01_004  brca_smc_2018_BB01_004           BAX         19
# ...                      ...                     ...           ...        ...
# 1832     brca_smc_2018_BR419     brca_smc_2018_BR419          DLG3          X
# 1833     brca_smc_2018_BR419     brca_smc_2018_BR419         MORC4          X
# 1834     brca_smc_2018_BR419     brca_smc_2018_BR419  RP11-435B5.5          1
# 1835     brca_smc_2018_BR419     brca_smc_2018_BR419         MAML3          4
# 1836     brca_smc_2018_BR419     brca_smc_2018_BR419         CHTF8         16
#
# ...

# %%
# check if there are duplicate rows 
data_mutation_ductal_TN_Kan.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Banerji et al., Nature 2012

# %%
# Banerji et al., Nature 2012
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Breast Invasive Carcinoma (Broad, Nature 2012)")

# %%
data_mutation_ductal_TN_Banerji=pd.read_csv('mutation_table_Banerji_et_al_Broad_Nature2012_TN_ductal.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_ductal_TN_Banerji = data_mutation_ductal_TN_Banerji.iloc[:, 1:]
data_mutation_ductal_TN_Banerji
# Out:
#     PATIENT_ID Tumor_Sample_Barcode Hugo_Symbol Chromosome  Start_Position  \
# 0     BR-M-045             BR-M-045       ABCA9         17        66980259
# 1     BR-M-045             BR-M-045       ADAD2         16        84228910
# 2     BR-M-045             BR-M-045       AKAP9          7        91645550
# 3     BR-M-045             BR-M-045      ANGEL1         14        77275857
# 4     BR-M-045             BR-M-045    ANKRD30A         10        37508262
# ..         ...                  ...         ...        ...             ...
# 271   BR-M-174             BR-M-174        UPRT          X        74494112
# 272   BR-M-174             BR-M-174        WDR1          4        10099376
# 273   BR-M-174             BR-M-174      YEATS2          3       183471914
# 274   BR-M-174             BR-M-174      ZFAND3          6        38084369
# 275   BR-M-174             BR-M-174       ZNF34          8       145999971
#
# ...

# %% [markdown]
# ### Stephens et al., Nature 2012

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Breast Invasive Carcinoma (Sanger, Nature 2012)")

# %%
data_mutation_ductal_TN_Stephens = pd.read_csv('mutation_table_Stephens_et_al_Sanger_Nature2012_TN_ductal.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_ductal_TN_Stephens = data_mutation_ductal_TN_Stephens.iloc[:, 1:]
data_mutation_ductal_TN_Stephens
# Out:
#      PATIENT_ID Tumor_Sample_Barcode Hugo_Symbol Chromosome  Start_Position  \
# 0       PD3987a              PD3987a    ANKRD18A          9        38615632
# 1       PD3987a              PD3987a       TXLNG          X        16836744
# 2       PD3987a              PD3987a       SP140          2       231155280
# 3       PD3987a              PD3987a    ARHGEF26          3       153970973
# 4       PD3987a              PD3987a     PGLYRP3          1       153277444
# ...         ...                  ...         ...        ...             ...
# 1181    PD4844a              PD4844a       HCFC1          X       153223635
# 1182    PD4844a              PD4844a         RB1         13        48941721
# 1183    PD4844a              PD4844a        TP53         17         7579359
# 1184    PD4844a              PD4844a      PIK3CA          3       178916950
# 1185    PD4844a              PD4844a      PIK3CA          3       178952064
#
# ...

# %% [markdown]
# ### Krug et al., Cell 2020

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Proteogenomic landscape of breast cancer (CPTAC, Cell 2020)")

# %%
data_mutation_ductal_TN_Krug = pd.read_csv('mutation_table_Krug_et_al_Cell_2020_TN.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_ductal_TN_Krug = data_mutation_ductal_TN_Krug.iloc[:, 1:]
data_mutation_ductal_TN_Krug
# Out:
#       PATIENT_ID Tumor_Sample_Barcode Hugo_Symbol Chromosome  Start_Position  \
# 0      CPT000814            CPT000814        SZT2          1        43908878
# 1      CPT000814            CPT000814       AGBL4          1        49283877
# 2      CPT000814            CPT000814      PTGER3          1        71512957
# 3      CPT000814            CPT000814        HFM1          1        91859745
# 4      CPT000814            CPT000814       PRUNE          1       150999720
# ...          ...                  ...         ...        ...             ...
# 17602   X20BR008             X20BR008       FAAH2          X        57318997
# 17603   X20BR008             X20BR008        PLS3          X       114869345
# 17604   X20BR008             X20BR008       IGSF1          X       130413268
# 17605   X20BR008             X20BR008        FHL1          X       135291593
# 17606   X20BR008             X20BR008        GDI1          X       153665635
#
# ...

# %% [markdown]
# ### TCGA, Cell 2018

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Breast Invasive Carcinoma (TCGA, PanCancer Atlas)")

# %%
data_mutation_ductal_TN_TCGA=pd.read_csv('mutation_table_TCGA_PanCancer2018_basal_ductal.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_ductal_TN_TCGA=data_mutation_ductal_TN_TCGA.iloc[:, 1:]
data_mutation_ductal_TN_TCGA
# Out:
#          PATIENT_ID  Target Tumor_Sample_Barcode Hugo_Symbol Chromosome  \
# 0      TCGA-A1-A0SO       1      TCGA-A1-A0SO-01     XPNPEP1         10
# 1      TCGA-A1-A0SO       1      TCGA-A1-A0SO-01       PDCD4         10
# 2      TCGA-A1-A0SO       1      TCGA-A1-A0SO-01      HSPA14         10
# 3      TCGA-A1-A0SO       1      TCGA-A1-A0SO-01       SPAG6         10
# 4      TCGA-A1-A0SO       1      TCGA-A1-A0SO-01      GPR158         10
# ...             ...     ...                  ...         ...        ...
# 23316  TCGA-S3-AA15       1      TCGA-S3-AA15-01      KCNMB2          3
# 23317  TCGA-S3-AA15       1      TCGA-S3-AA15-01     TMEM110          3
# 23318  TCGA-S3-AA15       1      TCGA-S3-AA15-01        CSF2          5
# 23319  TCGA-S3-AA15       1      TCGA-S3-AA15-01       SNRPC          6
# 23320  TCGA-S3-AA15       1      TCGA-S3-AA15-01     PCDH11X          X
#
#        Start_Position  End_Position Variant_Classification Variant_Type  \
# ...

# %% [markdown]
# ### Lefebvre et al., Metastatic Breast Cancer (INSERM, PLoS Med 2016)

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Metastatic Breast Cancer (INSERM, PLoS Med 2016)")

# %%
data_mutation_ductal_TN_Lefebvre=pd.read_csv('mutation_table_Lefebvre_et_al_INSERM_PLoSMed2016_TN.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_ductal_TN_Lefebvre=data_mutation_ductal_TN_Lefebvre.iloc[:, 1:]
data_mutation_ductal_TN_Lefebvre
# Out:
#      PATIENT_ID Tumor_Sample_Barcode Hugo_Symbol Chromosome  Start_Position  \
# 0       MBC_182              MBC_182       LUZP1          1        23419111
# 1       MBC_182              MBC_182      ARID1A          1        27059208
# 2       MBC_182              MBC_182       GRIK3          1        37324766
# 3       MBC_182              MBC_182       RRAGC          1        39305274
# 4       MBC_182              MBC_182         JUN          1        59248632
# ...         ...                  ...         ...        ...             ...
# 4285     MBC_80               MBC_80       SCN5A          3        38647565
# 4286     MBC_80               MBC_80      COL6A6          3       130345394
# 4287     MBC_80               MBC_80       CARD6          5        40852576
# 4288     MBC_80               MBC_80       PTPRK          6       128643175
# 4289     MBC_80               MBC_80         QKI          6       163876427
#
# ...

# %%
# check if there are duplicate rows 
data_mutation_ductal_TN_Lefebvre.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### MBC project (Provisional, Dec 2021)

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/The Metastatic Breast Cancer Project (Provisional, December 2021)")

# %%
data_mutation_ductal_TN_MBC = pd.read_csv('mutation_table_MBCproject_TN_and_ductal.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_ductal_TN_MBC = data_mutation_ductal_TN_MBC.iloc[:, 1:]
data_mutation_ductal_TN_MBC
# Out:
#                PATIENT_ID                    Tumor_Sample_Barcode Hugo_Symbol  \
# 0     MBCProject_0aTBfPcG  MBC-MBCProject_0aTBfPcG-Tumor-SM-DL3W1     DNAJC11
# 1     MBCProject_0aTBfPcG  MBC-MBCProject_0aTBfPcG-Tumor-SM-DL3W1        MTOR
# 2     MBCProject_0aTBfPcG  MBC-MBCProject_0aTBfPcG-Tumor-SM-DL3W1      PTCHD2
# 3     MBCProject_0aTBfPcG  MBC-MBCProject_0aTBfPcG-Tumor-SM-DL3W1   KIAA0319L
# 4     MBCProject_0aTBfPcG  MBC-MBCProject_0aTBfPcG-Tumor-SM-DL3W1       FOXO6
# ...                   ...                                     ...         ...
# 2810  MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG        VAV1
# 2811  MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG         ADA
# 2812  MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG       ABCG1
# 2813  MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG       TRPM2
# 2814  MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG      FBXO11
#
# ...

# %% [markdown]
# ### Merging all the datasets

# %%
# concatenate all the datasets into one larger dataset
data_mutation_ductal_TN = pd.concat([data_mutation_ductal_TN_Kan, data_mutation_ductal_TN_Banerji, data_mutation_ductal_TN_Stephens, data_mutation_ductal_TN_Krug, data_mutation_ductal_TN_TCGA,data_mutation_ductal_TN_Lefebvre, data_mutation_ductal_TN_MBC], axis=0)
data_mutation_ductal_TN
# Out:
#                   PATIENT_ID                    Tumor_Sample_Barcode  \
# 0     brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 1     brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 2     brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 3     brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 4     brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# ...                      ...                                     ...
# 2810     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 2811     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 2812     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 2813     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 2814     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
#
#      Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0        TMEM131          2      98460725.0    98460725.0
# ...

# %%
data_mutation_ductal_TN['PATIENT_ID'].nunique()
# Out:
# 302

# %%
data_mutation_ductal_TN['Hugo_Symbol'].nunique()
# Out:
# 15570

# %% [markdown]
# ### How many hypomutated patients are Triple-Negative?

# %%
data_mutation_ductal_TN.merge(hypo_patients, on ='PATIENT_ID', how='inner')
# Out:
#   PATIENT_ID Tumor_Sample_Barcode Hugo_Symbol Chromosome  Start_Position  \
# 0    MBC_166              MBC_166      TRIM11          1     228593975.0
# 1     MBC_27               MBC_27        KRT2         12      53045615.0
#
#    End_Position Variant_Classification Variant_Type Reference_Allele  \
# 0   228593975.0                 Silent          SNP                G
# 1    53045615.0                 Silent          SNP                A
#
#   Tumor_Seq_Allele1 Tumor_Seq_Allele2                       HGVSc HGVSp_Short  \
# 0                 G                 C  ENST00000284551.6:c.288C>G      p.R96=
# 1                 A                 G  ENST00000309680.3:c.312T>C     p.G104=
#
#   Protein_position    Transcript_ID  Gene_length  Target ENSP
# 0             96.0  ENST00000284551        13168     NaN  NaN
# 1            104.0  ENST00000309680         7607     NaN  NaN

# %% [markdown]
# ### How many hypermutated patients are Triple-Negative?

# %%
hyper_TN = data_mutation_ductal_TN.merge(hyper_patients, on ='PATIENT_ID', how='inner')
hyper_TN
# Out:
#          PATIENT_ID Tumor_Sample_Barcode Hugo_Symbol Chromosome  \
# 0          X01BR043             X01BR043      SAMD11          1
# 1          X01BR043             X01BR043       NOC2L          1
# 2          X01BR043             X01BR043       NOC2L          1
# 3          X01BR043             X01BR043        AGRN          1
# 4          X01BR043             X01BR043        AGRN          1
# ...             ...                  ...         ...        ...
# 19338  TCGA-LL-A8F5      TCGA-LL-A8F5-01       PEG10          7
# 19339  TCGA-LL-A8F5      TCGA-LL-A8F5-01        SYBU          8
# 19340  TCGA-LL-A8F5      TCGA-LL-A8F5-01        PLAT          8
# 19341  TCGA-LL-A8F5      TCGA-LL-A8F5-01     FAM122A          9
# 19342  TCGA-LL-A8F5      TCGA-LL-A8F5-01       GCNT1          9
#
#        Start_Position  End_Position Variant_Classification Variant_Type  \
# 0            878374.0      878374.0                 Silent          SNP
# ...

# %%
hyper_TN.PATIENT_ID.nunique()
# Out:
# 7

# %% [markdown]
# ### Delete all the rows associated to the hypermutated and hypomutated patients

# %%
mask_TN = data_mutation_ductal_TN['PATIENT_ID'].isin(hyper_hypo_patients_total_ductal['PATIENT_ID'])
mask_TN
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2810    False
# 2811    False
# 2812    False
# 2813    False
# 2814    False
# Name: PATIENT_ID, Length: 51332, dtype: bool

# %%
data_mutation_ductal_TN_nohypo_nohyper = data_mutation_ductal_TN[~mask_TN].copy()
data_mutation_ductal_TN_nohypo_nohyper
# Out:
#                   PATIENT_ID                    Tumor_Sample_Barcode  \
# 0     brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 1     brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 2     brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 3     brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 4     brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# ...                      ...                                     ...
# 2810     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 2811     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 2812     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 2813     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 2814     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
#
#      Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0        TMEM131          2      98460725.0    98460725.0
# ...

# %%
data_mutation_ductal_TN_nohypo_nohyper['PATIENT_ID'].nunique()
# Out:
# 293

# %%
data_mutation_ductal_TN_nohypo_nohyper['Hugo_Symbol'].nunique()
# Out:
# 13306

# %%
# save the dataset 
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi")
data_mutation_ductal_TN_nohypo_nohyper.to_csv("mutation_table_ALL_DATASETS_ductal_TN_nohypo_nohyper.csv", index=False, sep='\t')

# %% [markdown]
# ## Prepare the TNBC mutation dataset for MutSig2CV

# %%
data_mutation_TN_nohypo_nohyper_MutSig2CV = data_mutation_ductal_TN_nohypo_nohyper[['Tumor_Sample_Barcode', 'Hugo_Symbol', 'Chromosome', 'Start_Position', 'Variant_Classification', 'Variant_Type', 'Reference_Allele', 'Tumor_Seq_Allele2']].copy()
data_mutation_TN_nohypo_nohyper_MutSig2CV
# Out:
#                         Tumor_Sample_Barcode Hugo_Symbol Chromosome  \
# 0                     brca_smc_2018_BB01_004     TMEM131          2
# 1                     brca_smc_2018_BB01_004      DNAAF1         16
# 2                     brca_smc_2018_BB01_004        TP53         17
# 3                     brca_smc_2018_BB01_004        MATK         19
# 4                     brca_smc_2018_BB01_004         BAX         19
# ...                                      ...         ...        ...
# 2810  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG        VAV1         19
# 2811  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG         ADA         20
# 2812  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG       ABCG1         21
# 2813  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG       TRPM2         21
# 2814  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG      FBXO11          2
#
#       Start_Position Variant_Classification Variant_Type Reference_Allele  \
# 0         98460725.0            Splice_Site          SNP                C
# ...

# %%
data_mutation_TN_nohypo_nohyper_MutSig2CV.rename(columns={"Start_Position": "Start_position"}, inplace=True)
data_mutation_TN_nohypo_nohyper_MutSig2CV
# Out:
#                         Tumor_Sample_Barcode Hugo_Symbol Chromosome  \
# 0                     brca_smc_2018_BB01_004     TMEM131          2
# 1                     brca_smc_2018_BB01_004      DNAAF1         16
# 2                     brca_smc_2018_BB01_004        TP53         17
# 3                     brca_smc_2018_BB01_004        MATK         19
# 4                     brca_smc_2018_BB01_004         BAX         19
# ...                                      ...         ...        ...
# 2810  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG        VAV1         19
# 2811  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG         ADA         20
# 2812  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG       ABCG1         21
# 2813  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG       TRPM2         21
# 2814  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG      FBXO11          2
#
#       Start_position Variant_Classification Variant_Type Reference_Allele  \
# 0         98460725.0            Splice_Site          SNP                C
# ...

# %%
# check if there are duplicated rows 
data_mutation_TN_nohypo_nohyper_MutSig2CV.duplicated().any()
# Out:
# False

# %%
#save the dataset as a tab-separated file 
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/MutSig2CV_input_DEFINITIVO")
data_mutation_TN_nohypo_nohyper_MutSig2CV.to_csv('mutation_table_ALL_DATASETS_TN_nohyper_nohypo.txt', sep='\t', index=False)

# %% [markdown]
# ## Study the Mutation Rate and the Mutation Frequency - TRIPLE NEGATIVE

# %%
data_mutation_ductal_TN['PATIENT_ID'].nunique()
# Out:
# 302

# %% [markdown]
# ### Mutation Rate analysis

# %%
# add a column to the dataset representing the mutated bases length (End_Position-Start_Position+1)
data_mutation_ductal_TN.loc[:, 'Mutation_length'] = data_mutation_ductal_TN['End_Position']-data_mutation_ductal_TN['Start_Position']+1
data_mutation_ductal_TN
# Out:
#                   PATIENT_ID                    Tumor_Sample_Barcode  \
# 0     brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 1     brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 2     brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 3     brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 4     brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# ...                      ...                                     ...
# 2810     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 2811     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 2812     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 2813     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 2814     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
#
#      Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0        TMEM131          2      98460725.0    98460725.0
# ...

# %%
data_mutation_ductal_TN['PATIENT_ID'].nunique()
# Out:
# 302

# %%
# extract PATIENT_ID and Mutation_length
pts_mutation_length_ductal_TN = data_mutation_ductal_TN[['PATIENT_ID', 'Mutation_length']]
pts_mutation_length_ductal_TN
# Out:
#                   PATIENT_ID  Mutation_length
# 0     brca_smc_2018_BB01_004              1.0
# 1     brca_smc_2018_BB01_004              1.0
# 2     brca_smc_2018_BB01_004              1.0
# 3     brca_smc_2018_BB01_004              1.0
# 4     brca_smc_2018_BB01_004              1.0
# ...                      ...              ...
# 2810     MBCProject_wzCxuoio              1.0
# 2811     MBCProject_wzCxuoio              1.0
# 2812     MBCProject_wzCxuoio              1.0
# 2813     MBCProject_wzCxuoio              1.0
# 2814     MBCProject_wzCxuoio              1.0
#
# [51332 rows x 2 columns]

# %%
# group by PATIENT_ID and sum the mutation lengths for each pts
mutation_ductal_TN_group_by_pts=pts_mutation_length_ductal_TN.groupby(['PATIENT_ID'])['Mutation_length'].sum().reset_index()
mutation_ductal_TN_group_by_pts.rename(columns = {'Mutation_length':'Total_sum_mutated_bases'}, inplace = True)
mutation_ductal_TN_group_by_pts
# Out:
#               PATIENT_ID  Total_sum_mutated_bases
# 0               BR-M-045                    168.0
# 1               BR-M-080                     21.0
# 2               BR-M-122                     48.0
# 3               BR-M-174                     75.0
# 4              CPT000814                    126.0
# ..                   ...                      ...
# 297  brca_smc_2018_BR313                     33.0
# 298  brca_smc_2018_BR367                     51.0
# 299  brca_smc_2018_BR393                     91.0
# 300  brca_smc_2018_BR395                     20.0
# 301  brca_smc_2018_BR419                     79.0
#
# [302 rows x 2 columns]

# %%
# extract Hugo_Symbol and Gene_length
gene_length_for_each_mutation_ductal_TN = data_mutation_ductal_TN[['Hugo_Symbol', 'Gene_length']]
gene_length_for_each_mutation_ductal_TN
# Out:
#      Hugo_Symbol  Gene_length
# 0        TMEM131       239590
# 1         DNAAF1        33509
# 2           TP53        25760
# 3           MATK        24157
# 4            BAX         6984
# ...          ...          ...
# 2810        VAV1        84653
# 2811         ADA        32712
# 2812       ABCG1        97556
# 2813       TRPM2        92919
# 2814      FBXO11       116478
#
# [51332 rows x 2 columns]

# %%
# look at the number of distinct genes
gene_length_for_each_mutation_ductal_TN['Hugo_Symbol'].nunique()
# Out:
# 15570

# %% [markdown]
# In the dataset there are 15570 distinct genes.

# %%
# group by gene (Hugo_Symbol) 
mutation_ductal_TN_group_by_gene=gene_length_for_each_mutation_ductal_TN.groupby(['Hugo_Symbol'])['Gene_length'].max().reset_index()
mutation_ductal_TN_group_by_gene
# Out:
#         Hugo_Symbol  Gene_length
# 0              A1BG         8322
# 1              A1CF        86267
# 2               A2M        48566
# 3             A2ML1        64530
# 4           A3GALT2        14333
# ...             ...          ...
# 15565           ZYX        10032
# 15566         ZZEF1       138576
# 15567          ZZZ3       121004
# 15568  hsa-mir-6080        32337
# 15569        snoU13          103
#
# [15570 rows x 2 columns]

# %%
# compute the total gene length (for all the genes in the dataset)
total_GeneLength_ductal_TN = mutation_ductal_TN_group_by_gene['Gene_length'].sum()
total_GeneLength_ductal_TN
# Out:
# 1171481561

# %%
# add a column to the dataset representing the mutation rate for each patient (Mutation_rate= Mutation_length/total_gene_length)
mutation_ductal_TN_group_by_pts["Mutation_rate"] = mutation_ductal_TN_group_by_pts["Total_sum_mutated_bases"]/total_GeneLength_ductal_TN
mutation_ductal_TN_group_by_pts
# Out:
#               PATIENT_ID  Total_sum_mutated_bases  Mutation_rate
# 0               BR-M-045                    168.0   1.434081e-07
# 1               BR-M-080                     21.0   1.792602e-08
# 2               BR-M-122                     48.0   4.097376e-08
# 3               BR-M-174                     75.0   6.402149e-08
# 4              CPT000814                    126.0   1.075561e-07
# ..                   ...                      ...            ...
# 297  brca_smc_2018_BR313                     33.0   2.816946e-08
# 298  brca_smc_2018_BR367                     51.0   4.353462e-08
# 299  brca_smc_2018_BR393                     91.0   7.767941e-08
# 300  brca_smc_2018_BR395                     20.0   1.707240e-08
# 301  brca_smc_2018_BR419                     79.0   6.743597e-08
#
# [302 rows x 3 columns]

# %%
# multiply the Mutation_rate values for 10^6
mutation_ductal_TN_group_by_pts["Mutation_rate*10^6"] = mutation_ductal_TN_group_by_pts["Mutation_rate"]*1000000
mutation_ductal_TN_group_by_pts
# Out:
#               PATIENT_ID  Total_sum_mutated_bases  Mutation_rate  \
# 0               BR-M-045                    168.0   1.434081e-07
# 1               BR-M-080                     21.0   1.792602e-08
# 2               BR-M-122                     48.0   4.097376e-08
# 3               BR-M-174                     75.0   6.402149e-08
# 4              CPT000814                    126.0   1.075561e-07
# ..                   ...                      ...            ...
# 297  brca_smc_2018_BR313                     33.0   2.816946e-08
# 298  brca_smc_2018_BR367                     51.0   4.353462e-08
# 299  brca_smc_2018_BR393                     91.0   7.767941e-08
# 300  brca_smc_2018_BR395                     20.0   1.707240e-08
# 301  brca_smc_2018_BR419                     79.0   6.743597e-08
#
#      Mutation_rate*10^6
# 0              0.143408
# 1              0.017926
# 2              0.040974
# 3              0.064021
# 4              0.107556
# ..                  ...
# ...

# %%
# the PATIENT_IDs are sorted for descending order of mutation rate 
mutation_ductal_TN_group_by_pts= mutation_ductal_TN_group_by_pts.sort_values(by="Mutation_rate", ascending=False)
mutation_ductal_TN_group_by_pts
# Out:
#                  PATIENT_ID  Total_sum_mutated_bases  Mutation_rate  \
# 176            TCGA-BH-A18V                  25073.0   2.140281e-05
# 250                X01BR043                  13093.0   1.117645e-05
# 230            TCGA-LL-A8F5                   2532.0   2.161366e-06
# 173            TCGA-BH-A18G                   2031.0   1.733702e-06
# 193            TCGA-D8-A1XK                   1532.0   1.307746e-06
# ..                      ...                      ...            ...
# 268  brca_smc_2018_BB01_022                      8.0   6.828959e-09
# 267  brca_smc_2018_BB01_004                      7.0   5.975339e-09
# 272  brca_smc_2018_BB01_040                      5.0   4.268100e-09
# 39                  MBC_166                      1.0   8.536199e-10
# 54                   MBC_27                      1.0   8.536199e-10
#
#      Mutation_rate*10^6
# 176           21.402812
# 250           11.176446
# 230            2.161366
# 173            1.733702
# ...

# %%
patient_mutation_rate_ductal_TN=mutation_ductal_TN_group_by_pts[['PATIENT_ID', 'Mutation_rate*10^6' ]]
patient_mutation_rate_ductal_TN
# Out:
#                  PATIENT_ID  Mutation_rate*10^6
# 176            TCGA-BH-A18V           21.402812
# 250                X01BR043           11.176446
# 230            TCGA-LL-A8F5            2.161366
# 173            TCGA-BH-A18G            1.733702
# 193            TCGA-D8-A1XK            1.307746
# ..                      ...                 ...
# 268  brca_smc_2018_BB01_022            0.006829
# 267  brca_smc_2018_BB01_004            0.005975
# 272  brca_smc_2018_BB01_040            0.004268
# 39                  MBC_166            0.000854
# 54                   MBC_27            0.000854
#
# [302 rows x 2 columns]

# %%
patients=np.arange(0,302,1)
# convert a series into a Numpy array
mutation_rate=mutation_ductal_TN_group_by_pts[['Mutation_rate*10^6']].to_numpy()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 8)
plt.yscale("log") 
#set axes limit
plt.ylim(0.0001, 1000)
plt.scatter(patients, mutation_rate)
plt.xlabel("Patients")
plt.ylabel("Mutation rate per 10^6 bases (log scale)")
plt.show()

# %% [markdown]
# ### Mutation Frequency analysis

# %%
genes_patients_ductal_TN=data_mutation_ductal_TN[['PATIENT_ID', 'Hugo_Symbol']]
genes_patients_ductal_TN
# Out:
#                   PATIENT_ID Hugo_Symbol
# 0     brca_smc_2018_BB01_004     TMEM131
# 1     brca_smc_2018_BB01_004      DNAAF1
# 2     brca_smc_2018_BB01_004        TP53
# 3     brca_smc_2018_BB01_004        MATK
# 4     brca_smc_2018_BB01_004         BAX
# ...                      ...         ...
# 2810     MBCProject_wzCxuoio        VAV1
# 2811     MBCProject_wzCxuoio         ADA
# 2812     MBCProject_wzCxuoio       ABCG1
# 2813     MBCProject_wzCxuoio       TRPM2
# 2814     MBCProject_wzCxuoio      FBXO11
#
# [51332 rows x 2 columns]

# %%
genes_patients_ductal_TN=genes_patients_ductal_TN.drop_duplicates()
genes_patients_ductal_TN
# Out:
#                   PATIENT_ID Hugo_Symbol
# 0     brca_smc_2018_BB01_004     TMEM131
# 1     brca_smc_2018_BB01_004      DNAAF1
# 2     brca_smc_2018_BB01_004        TP53
# 3     brca_smc_2018_BB01_004        MATK
# 4     brca_smc_2018_BB01_004         BAX
# ...                      ...         ...
# 2810     MBCProject_wzCxuoio        VAV1
# 2811     MBCProject_wzCxuoio         ADA
# 2812     MBCProject_wzCxuoio       ABCG1
# 2813     MBCProject_wzCxuoio       TRPM2
# 2814     MBCProject_wzCxuoio      FBXO11
#
# [43736 rows x 2 columns]

# %%
n_of_pts_per_gene_ductal_TN = genes_patients_ductal_TN.groupby(['Hugo_Symbol'])['PATIENT_ID'].count().reset_index()
n_of_pts_per_gene_ductal_TN.rename(columns = {'PATIENT_ID':'Num_pts_per_gene'}, inplace = True)
n_of_pts_per_gene_ductal_TN
# Out:
#         Hugo_Symbol  Num_pts_per_gene
# 0              A1BG                 1
# 1              A1CF                 1
# 2               A2M                 8
# 3             A2ML1                 4
# 4           A3GALT2                 1
# ...             ...               ...
# 15565           ZYX                 1
# 15566         ZZEF1                 4
# 15567          ZZZ3                 2
# 15568  hsa-mir-6080                 1
# 15569        snoU13                 1
#
# [15570 rows x 2 columns]

# %%
tot_pts_ductal_TN = 302

# %%
# add a column to the n_of_pts_per_gene dataframe representing the mutation frequency for each gene
n_of_pts_per_gene_ductal_TN["Mutation_frequency (%)"] = (n_of_pts_per_gene_ductal_TN["Num_pts_per_gene"]*100)/tot_pts_ductal_TN
n_of_pts_per_gene_ductal_TN
# Out:
#         Hugo_Symbol  Num_pts_per_gene  Mutation_frequency (%)
# 0              A1BG                 1                0.331126
# 1              A1CF                 1                0.331126
# 2               A2M                 8                2.649007
# 3             A2ML1                 4                1.324503
# 4           A3GALT2                 1                0.331126
# ...             ...               ...                     ...
# 15565           ZYX                 1                0.331126
# 15566         ZZEF1                 4                1.324503
# 15567          ZZZ3                 2                0.662252
# 15568  hsa-mir-6080                 1                0.331126
# 15569        snoU13                 1                0.331126
#
# [15570 rows x 3 columns]

# %%
# the numbers of patients per gene are sorted in descending order
n_of_pts_per_gene_ductal_TN= n_of_pts_per_gene_ductal_TN.sort_values(by="Num_pts_per_gene", ascending=False)
n_of_pts_per_gene_ductal_TN
# Out:
#       Hugo_Symbol  Num_pts_per_gene  Mutation_frequency (%)
# 13870        TP53               253               83.774834
# 14210         TTN               100               33.112583
# 8259        MUC16                38               12.582781
# 9952       PIK3CA                35               11.589404
# 3821          DST                32               10.596026
# ...           ...               ...                     ...
# 7832     METTL21C                 1                0.331126
# 7831     METTL21A                 1                0.331126
# 7829      METTL15                 1                0.331126
# 7828      METTL14                 1                0.331126
# 15569      snoU13                 1                0.331126
#
# [15570 rows x 3 columns]

# %%
gene_mutation_frequency_ductal_TN = n_of_pts_per_gene_ductal_TN[['Hugo_Symbol', 'Mutation_frequency (%)']]
gene_mutation_frequency_ductal_TN
# Out:
#       Hugo_Symbol  Mutation_frequency (%)
# 13870        TP53               83.774834
# 14210         TTN               33.112583
# 8259        MUC16               12.582781
# 9952       PIK3CA               11.589404
# 3821          DST               10.596026
# ...           ...                     ...
# 7832     METTL21C                0.331126
# 7831     METTL21A                0.331126
# 7829      METTL15                0.331126
# 7828      METTL14                0.331126
# 15569      snoU13                0.331126
#
# [15570 rows x 2 columns]

# %%
# select the first 50 genes
highest_mutated_genes_ductal_TN=gene_mutation_frequency_ductal_TN.head(50)
highest_mutated_genes_ductal_TN
# Out:
#       Hugo_Symbol  Mutation_frequency (%)
# 13870        TP53               83.774834
# 14210         TTN               33.112583
# 8259        MUC16               12.582781
# 9952       PIK3CA               11.589404
# 3821          DST               10.596026
# 8999        OBSCN                9.933775
# 4785          FLG                9.933775
# 14453       USH2A                9.602649
# 11068        RELN                9.271523
# 4601         FAT3                9.271523
# 13109       SYNE1                8.940397
# 5853        HMCN1                8.940397
# 8549          NEB                8.940397
# 11631        RYR2                8.609272
# 12812       SPTA1                8.278146
# 11630        RYR1                8.278146
# 10002     PKHD1L1                8.278146
# 3098        CSMD3                7.615894
# 12054          SI                6.953642
# 3655       DNAH10                6.953642
# 1392        BRCA1                6.622517
# ...

# %%
mutated_gene_names=highest_mutated_genes_ductal_TN['Hugo_Symbol'].tolist()

# %%
# increase the quality and resolution of the chart
from IPython.display import set_matplotlib_formats
import matplotlib_inline.backend_inline

matplotlib_inline.backend_inline.set_matplotlib_formats('retina')
# set default figure size.
plt.rcParams['figure.figsize'] = (12, 8)
fig, ax = plt.subplots()
h=ax.bar(highest_mutated_genes_ductal_TN['Hugo_Symbol'], highest_mutated_genes_ductal_TN['Mutation_frequency (%)'], label=mutated_gene_names)
xticks_pos = [0.65*patch.get_width() + patch.get_xy()[0] for patch in h]

_ = plt.xticks(xticks_pos, mutated_gene_names,  ha='right', rotation=45)
#plt.title('Highest mutated genes', fontsize=14)
plt.xlabel('Mutated gene', fontsize=14)
plt.ylabel('Mutation frequency (%)', fontsize=14)

plt.ylim(0, 90)

# First, let's remove the top, right and left spines (figure borders)
# which really aren't necessary for a bar chart.
# Also, make the bottom spine gray instead of black.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')

# Second, remove the ticks as well.
ax.tick_params(bottom=False, left=False)

# Third, add a horizontal grid (but keep the vertical grid hidden).
# Color the lines a light gray as well.
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Add text annotations to the top of the bars.
# Note, you'll have to adjust this slightly (the 0.3)
# with different data.
for bar in h:
  ax.text(
      bar.get_x() + bar.get_width() / 2,
      bar.get_height() + 0.3,
      round(bar.get_height(), 1),
      rotation='vertical',
      horizontalalignment='center'
  )


fig.tight_layout()

# %% [markdown]
# # DUCTAL NON TRIPLE-NEGATIVE

# %% [markdown]
# ### Kan et al., Nature Communications 2018

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Breast Cancer (SMC 2018)")

# %%
data_mutation_ductal_NON_TN_Kan=pd.read_csv('mutation_table_Kan_et_al_Communications_2018_NON_TN_and_ductal.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_ductal_NON_TN_Kan = data_mutation_ductal_NON_TN_Kan.iloc[:, 1:]
data_mutation_ductal_NON_TN_Kan
# Out:
#                   PATIENT_ID    Tumor_Sample_Barcode Hugo_Symbol Chromosome  \
# 0     brca_smc_2018_BB01_002  brca_smc_2018_BB01_002       KALRN          3
# 1     brca_smc_2018_BB01_002  brca_smc_2018_BB01_002        ANK2          4
# 2     brca_smc_2018_BB01_002  brca_smc_2018_BB01_002      SORBS2          4
# 3     brca_smc_2018_BB01_002  brca_smc_2018_BB01_002     PCDHA11          5
# 4     brca_smc_2018_BB01_002  brca_smc_2018_BB01_002      WRNIP1          6
# ...                      ...                     ...         ...        ...
# 4210     brca_smc_2018_BR469     brca_smc_2018_BR469       PPIL2         22
# 4211     brca_smc_2018_BR469     brca_smc_2018_BR469       PORCN          X
# 4212     brca_smc_2018_BR469     brca_smc_2018_BR469       KIF4A          X
# 4213     brca_smc_2018_BR469     brca_smc_2018_BR469       MAML3          4
# 4214     brca_smc_2018_BR469     brca_smc_2018_BR469      MAP3K1          5
#
# ...

# %%
# check if there are duplicate rows 
data_mutation_ductal_NON_TN_Kan.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Banerji et al., Nature 2012

# %%
# Banerji et al., Nature 2012
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Breast Invasive Carcinoma (Broad, Nature 2012)")

# %%
data_mutation_ductal_NON_TN_Banerji=pd.read_csv('mutation_table_Banerji_et_al_Broad_Nature2012_NON_TN_ductal.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_ductal_NON_TN_Banerji = data_mutation_ductal_NON_TN_Banerji.iloc[:, 1:]
data_mutation_ductal_NON_TN_Banerji
# Out:
#      PATIENT_ID Tumor_Sample_Barcode Hugo_Symbol Chromosome  Start_Position  \
# 0      BR-V-002             BR-V-002         A2M         12         9229398
# 1      BR-V-002             BR-V-002      ACTBL2          5        56777819
# 2      BR-V-002             BR-V-002      ZFAND4         10        46143950
# 3      BR-V-002             BR-V-002       APEX1         14        20925406
# 4      BR-V-002             BR-V-002       BIRC6          2        32678880
# ...         ...                  ...         ...        ...             ...
# 4225   BR-M-200             BR-M-200      NUP107         12        69115632
# 4226   BR-M-200             BR-M-200       OR5I1         11        55703409
# 4227   BR-M-200             BR-M-200      PTP4A2          1        32377414
# 4228   BR-M-200             BR-M-200        SYT3         19        51140602
# 4229   BR-M-200             BR-M-200         TPR          1       186296647
#
# ...

# %% [markdown]
# ### Stephens et al., Nature 2012

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Breast Invasive Carcinoma (Sanger, Nature 2012)")

# %%
data_mutation_ductal_NON_TN_Stephens = pd.read_csv('mutation_table_Stephens_et_al_Sanger_Nature2012_NON_TN_ductal.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_ductal_NON_TN_Stephens = data_mutation_ductal_NON_TN_Stephens.iloc[:, 1:]
data_mutation_ductal_NON_TN_Stephens
# Out:
#      PATIENT_ID Tumor_Sample_Barcode Hugo_Symbol Chromosome  Start_Position  \
# 0       PD3857a              PD3857a      MYO15B         17        73592569
# 1       PD3857a              PD3857a     CTTNBP2          7       117501370
# 2       PD3857a              PD3857a      MAGEB6          X        26212583
# 3       PD3857a              PD3857a       FCRL5          1       157490878
# 4       PD3857a              PD3857a       CNTN2          1       205035644
# ...         ...                  ...         ...        ...             ...
# 4765    PD4939a              PD4939a       MUC16         19         9076181
# 4766    PD4939a              PD4939a      SHKBP1         19        41086542
# 4767    PD4939a              PD4939a      SPTLC3         20        13060509
# 4768    PD4939a              PD4939a      GPR112          X       135429006
# 4769    PD4939a              PD4939a        TP53         17         7578257
#
# ...

# %% [markdown]
# ### Krug et al., Cell 2020

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Proteogenomic landscape of breast cancer (CPTAC, Cell 2020)")

# %%
data_mutation_ductal_NON_TN_Krug = pd.read_csv('mutation_table_Krug_et_al_Cell_2020_NON_TN.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_ductal_NON_TN_Krug = data_mutation_ductal_NON_TN_Krug.iloc[:, 1:]
data_mutation_ductal_NON_TN_Krug
# Out:
#       PATIENT_ID Tumor_Sample_Barcode Hugo_Symbol Chromosome  Start_Position  \
# 0       X01BR008             X01BR008       RUNX3          1        25254183
# 1       X01BR008             X01BR008        NCDN          1        36031009
# 2       X01BR008             X01BR008        PLK3          1        45266324
# 3       X01BR008             X01BR008       CDCP2          1        54605471
# 4       X01BR008             X01BR008      DEPDC1          1        68948560
# ...          ...                  ...         ...        ...             ...
# 11406   X22BR006             X22BR006      ZNF652         17        47375881
# 11407   X22BR006             X22BR006       GALK1         17        73754610
# 11408   X22BR006             X22BR006      ZNF584         19        58928243
# 11409   X22BR006             X22BR006       ASXL1         20        31022238
# 11410   X22BR006             X22BR006       SYTL5          X        37948781
#
# ...

# %% [markdown]
# ### TCGA, Cell 2018

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Breast Invasive Carcinoma (TCGA, PanCancer Atlas)")

# %%
data_mutation_ductal_NON_TN_TCGA=pd.read_csv('mutation_table_TCGA_PanCancer2018_NON_basal_ductal.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_ductal_NON_TN_TCGA=data_mutation_ductal_NON_TN_TCGA.iloc[:, 1:]
data_mutation_ductal_NON_TN_TCGA
# Out:
#           PATIENT_ID  Target Tumor_Sample_Barcode Hugo_Symbol Chromosome  \
# 0       TCGA-A1-A0SO     1.0      TCGA-A1-A0SO-01     XPNPEP1         10
# 1       TCGA-A1-A0SO     1.0      TCGA-A1-A0SO-01       PDCD4         10
# 2       TCGA-A1-A0SO     1.0      TCGA-A1-A0SO-01      HSPA14         10
# 3       TCGA-A1-A0SO     1.0      TCGA-A1-A0SO-01       SPAG6         10
# 4       TCGA-A1-A0SO     1.0      TCGA-A1-A0SO-01      GPR158         10
# ...              ...     ...                  ...         ...        ...
# 117800  TCGA-WT-AB41     NaN      TCGA-WT-AB41-01      ALPPL2          2
# 117801  TCGA-WT-AB41     NaN      TCGA-WT-AB41-01       ASAP2          2
# 117802  TCGA-WT-AB41     NaN      TCGA-WT-AB41-01        ECE2          3
# 117803  TCGA-WT-AB41     NaN      TCGA-WT-AB41-01       KCNH8          3
# 117804  TCGA-WT-AB41     NaN      TCGA-WT-AB41-01     CCDC71L          7
#
#         Start_Position  End_Position Variant_Classification Variant_Type  \
# ...

# %% [markdown]
# ### Lefebvre et al., Metastatic Breast Cancer (INSERM, PLoS Med 2016)

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/Metastatic Breast Cancer (INSERM, PLoS Med 2016)")

# %%
data_mutation_ductal_NON_TN_Lefebvre=pd.read_csv('mutation_table_Lefebvre_et_al_INSERM_PLoSMed2016_NON_TN.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_ductal_NON_TN_Lefebvre=data_mutation_ductal_NON_TN_Lefebvre.iloc[:, 1:]
data_mutation_ductal_NON_TN_Lefebvre
# Out:
#       PATIENT_ID Tumor_Sample_Barcode Hugo_Symbol Chromosome  Start_Position  \
# 0        MBC_183              MBC_183     SNRNP40          1        31769527
# 1        MBC_183              MBC_183        GJA8          1       147380326
# 2        MBC_183              MBC_183        PBX1          1       164781363
# 3        MBC_183              MBC_183        CRB1          1       197398576
# 4        MBC_183              MBC_183     CAMSAP2          1       200817731
# ...          ...                  ...         ...        ...             ...
# 18646     MBC_79               MBC_79       WDR87         19        38383556
# 18647     MBC_79               MBC_79       CENPB         20         3766635
# 18648     MBC_79               MBC_79    IVNS1ABP          1       185270219
# 18649     MBC_79               MBC_79         NEB          2       152409953
# 18650     MBC_79               MBC_79       AZIN1          8       103842156
#
# ...

# %%
# check if there are duplicate rows 
data_mutation_ductal_NON_TN_Lefebvre.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### MBC project (Provisional, Dec 2021)

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Datasets/The Metastatic Breast Cancer Project (Provisional, December 2021)")

# %%
data_mutation_ductal_NON_TN_MBC = pd.read_csv('mutation_table_MBCproject_NON_TN_and_ductal.csv', sep=None, engine='python')
# delete the first column, that shows the number of each row
data_mutation_ductal_NON_TN_MBC = data_mutation_ductal_NON_TN_MBC.iloc[:, 1:]
data_mutation_ductal_NON_TN_MBC
# Out:
#                 PATIENT_ID                    Tumor_Sample_Barcode  \
# 0      MBCProject_1ps2hZH8  MBC-MBCProject_1ps2hZH8-Tumor-SM-DL4OO
# 1      MBCProject_1ps2hZH8  MBC-MBCProject_1ps2hZH8-Tumor-SM-DL4OO
# 2      MBCProject_1ps2hZH8  MBC-MBCProject_1ps2hZH8-Tumor-SM-DL4OO
# 3      MBCProject_1ps2hZH8  MBC-MBCProject_1ps2hZH8-Tumor-SM-DL4OO
# 4      MBCProject_1ps2hZH8  MBC-MBCProject_1ps2hZH8-Tumor-SM-DL4OO
# ...                    ...                                     ...
# 17053  MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17054  MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17055  MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17056  MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17057  MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#       Hugo_Symbol  Chromosome  Start_Position  End_Position  \
# 0           LMOD1           1       201868736     201868736
# ...

# %% [markdown]
# ### Merging all the datasets

# %%
# concatenate all the datasets into one larger dataset
data_mutation_ductal_NON_TN = pd.concat([data_mutation_ductal_NON_TN_Kan, data_mutation_ductal_NON_TN_Banerji, data_mutation_ductal_NON_TN_Stephens, data_mutation_ductal_NON_TN_Krug, data_mutation_ductal_NON_TN_TCGA,data_mutation_ductal_NON_TN_Lefebvre, data_mutation_ductal_NON_TN_MBC], axis=0)
data_mutation_ductal_NON_TN
# Out:
#                    PATIENT_ID                    Tumor_Sample_Barcode  \
# 0      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 1      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 2      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 3      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 4      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# ...                       ...                                     ...
# 17053     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17054     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17055     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17056     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17057     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#       Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0           KALRN          3     123988087.0   123988087.0
# ...

# %%
data_mutation_ductal_NON_TN['PATIENT_ID'].nunique()
# Out:
# 1405

# %%
data_mutation_ductal_NON_TN['Hugo_Symbol'].nunique()
# Out:
# 19686

# %% [markdown]
# ### How many hypomutated patients are NON TN?

# %%
hypo_nonTN_pts = data_mutation_ductal_NON_TN.merge(hypo_patients, on ='PATIENT_ID', how='inner')
hypo_nonTN_pts
# Out:
#              PATIENT_ID Tumor_Sample_Barcode Hugo_Symbol Chromosome  \
# 0   brca_smc_2018_BR033  brca_smc_2018_BR033       ZC3H3          8
# 1   brca_smc_2018_BR033  brca_smc_2018_BR033        PTEN         10
# 2   brca_smc_2018_BR033  brca_smc_2018_BR033        HAO1         20
# 3   brca_smc_2018_BR033  brca_smc_2018_BR033       UPF3B          X
# 4   brca_smc_2018_BR099  brca_smc_2018_BR099     RASGRP3          2
# 5   brca_smc_2018_BR099  brca_smc_2018_BR099       RBM25         14
# 6   brca_smc_2018_BR099  brca_smc_2018_BR099     SULT4A1         22
# 7          TCGA-EW-A1P1      TCGA-EW-A1P1-01        TP53         17
# 8          TCGA-EW-A1P1      TCGA-EW-A1P1-01        MMP9         20
# 9          TCGA-EW-A1P1      TCGA-EW-A1P1-01      ARPC1A          7
# 10              MBC_116              MBC_116     C5orf42          5
# 11              MBC_116              MBC_116       ACRBP         12
# 12              MBC_116              MBC_116        PDP2         16
# ...

# %%
hypo_nonTN_pts.PATIENT_ID.nunique()
# Out:
# 7

# %%
hyper_patients
# Out:
#              PATIENT_ID
# 0          TCGA-BH-A18V
# 1          TCGA-A2-A0EV
# 2          TCGA-AC-A8OP
# 3              X01BR043
# 4          TCGA-A8-A08L
# 5          TCGA-AN-A046
# 6          TCGA-AC-A23H
# 7          TCGA-LL-A8F5
# 8   MBCProject_99CdCOHm
# 9          TCGA-BH-A18G
# 10         TCGA-AN-A0AK
# 11         TCGA-D8-A1XK
# 12         TCGA-BH-A0HF
# 13             X18BR003
# 14              MBC_189
# 15         TCGA-AO-A128
# 16         TCGA-D8-A1XQ
# 17         TCGA-D8-A1JA

# %%
hyper_NONtn = data_mutation_ductal_NON_TN.merge(hyper_patients, on ='PATIENT_ID', how='inner')
hyper_NONtn
# Out:
#                 PATIENT_ID                    Tumor_Sample_Barcode  \
# 0                 X18BR003                                X18BR003
# 1                 X18BR003                                X18BR003
# 2                 X18BR003                                X18BR003
# 3                 X18BR003                                X18BR003
# 4                 X18BR003                                X18BR003
# ...                    ...                                     ...
# 36633  MBCProject_99CdCOHm  MBC-MBCProject_99CdCOHm-Tumor-SM-CGLF4
# 36634  MBCProject_99CdCOHm  MBC-MBCProject_99CdCOHm-Tumor-SM-CGLF4
# 36635  MBCProject_99CdCOHm  MBC-MBCProject_99CdCOHm-Tumor-SM-CGLF4
# 36636  MBCProject_99CdCOHm  MBC-MBCProject_99CdCOHm-Tumor-SM-CGLF4
# 36637  MBCProject_99CdCOHm  MBC-MBCProject_99CdCOHm-Tumor-SM-CGLF4
#
#       Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0            DVL1          1       1275804.0     1275804.0
# ...

# %%
hyper_NONtn.PATIENT_ID.nunique()
# Out:
# 17

# %% [markdown]
# ### Delete all the rows associated to the hypermutated and hypomutated patients

# %%
mask_NONTN = data_mutation_ductal_NON_TN['PATIENT_ID'].isin(hyper_hypo_patients_total_ductal['PATIENT_ID'])
mask_NONTN
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17053    False
# 17054    False
# 17055    False
# 17056    False
# 17057    False
# Name: PATIENT_ID, Length: 178140, dtype: bool

# %%
data_mutation_ductal_NONTN_nohypo_nohyper = data_mutation_ductal_NON_TN[~mask_NONTN].copy()
data_mutation_ductal_NONTN_nohypo_nohyper
# Out:
#                    PATIENT_ID                    Tumor_Sample_Barcode  \
# 0      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 1      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 2      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 3      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 4      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# ...                       ...                                     ...
# 17053     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17054     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17055     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17056     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17057     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#       Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0           KALRN          3     123988087.0   123988087.0
# ...

# %%
data_mutation_ductal_NONTN_nohypo_nohyper['PATIENT_ID'].nunique()
# Out:
# 1381

# %%
data_mutation_ductal_NONTN_nohypo_nohyper['Hugo_Symbol'].nunique()
# Out:
# 19190

# %%
data_mutation_ductal_NONTN_nohypo_nohyper.loc[data_mutation_ductal_NONTN_nohypo_nohyper['Hugo_Symbol']=='PIK3CA']
# Out:
#                    PATIENT_ID                    Tumor_Sample_Barcode  \
# 18     brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 28     brca_smc_2018_BB01_005                  brca_smc_2018_BB01_005
# 189    brca_smc_2018_BB01_013                  brca_smc_2018_BB01_013
# 201    brca_smc_2018_BB01_014                  brca_smc_2018_BB01_014
# 425    brca_smc_2018_BB01_028                  brca_smc_2018_BB01_028
# ...                       ...                                     ...
# 14066     MBCProject_kduys9h5  MBC-MBCProject_kduys9h5-Tumor-SM-DL47P
# 14141     MBCProject_kzuMSZIW  MBC-MBCProject_kzuMSZIW-Tumor-SM-DL4JN
# 15132     MBCProject_nkU3hDhB  MBC-MBCProject_nkU3hDhB-Tumor-SM-GQCKL
# 15200     MBCProject_nwIeUoSD  MBC-MBCProject_nwIeUoSD-Tumor-SM-GQC2D
# 15274     MBCProject_oNI6SXtq  MBC-MBCProject_oNI6SXtq-Tumor-SM-GQC8N
#
#       Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 18         PIK3CA          3     178952150.0   178952151.0
# ...

# %%
data_mutation_ductal_NONTN_nohypo_nohyper['Hugo_Symbol'] = data_mutation_ductal_NONTN_nohypo_nohyper['Hugo_Symbol'].replace(['EIF3CL'], 'EIF3C')

# %%
# save the dataset 
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi")
data_mutation_ductal_NONTN_nohypo_nohyper.to_csv("mutation_table_ALL_DATASETS_ductal_NONTN_nohypo_nohyper.csv", index=False, sep='\t')

# %% [markdown]
# ## Prepare the NON TN mutation dataset for MutSig2CV

# %%
data_mutation_ductal_NONTN_nohypo_nohyper_MutSig2CV = data_mutation_ductal_NONTN_nohypo_nohyper[['Tumor_Sample_Barcode', 'Hugo_Symbol', 'Chromosome', 'Start_Position', 'Variant_Classification', 'Variant_Type', 'Reference_Allele', 'Tumor_Seq_Allele2']].copy()
data_mutation_ductal_NONTN_nohypo_nohyper_MutSig2CV
# Out:
#                          Tumor_Sample_Barcode Hugo_Symbol Chromosome  \
# 0                      brca_smc_2018_BB01_002       KALRN          3
# 1                      brca_smc_2018_BB01_002        ANK2          4
# 2                      brca_smc_2018_BB01_002      SORBS2          4
# 3                      brca_smc_2018_BB01_002     PCDHA11          5
# 4                      brca_smc_2018_BB01_002      WRNIP1          6
# ...                                       ...         ...        ...
# 17053  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59       NRSN2         20
# 17054  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59      CHRNA4         20
# 17055  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59      CHRNA4         20
# 17056  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59       KCNQ2         20
# 17057  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59        XBP1         22
#
#        Start_Position Variant_Classification Variant_Type Reference_Allele  \
# ...

# %%
data_mutation_ductal_NONTN_nohypo_nohyper_MutSig2CV.rename(columns={"Start_Position": "Start_position"}, inplace=True)
data_mutation_ductal_NONTN_nohypo_nohyper_MutSig2CV
# Out:
#                          Tumor_Sample_Barcode Hugo_Symbol Chromosome  \
# 0                      brca_smc_2018_BB01_002       KALRN          3
# 1                      brca_smc_2018_BB01_002        ANK2          4
# 2                      brca_smc_2018_BB01_002      SORBS2          4
# 3                      brca_smc_2018_BB01_002     PCDHA11          5
# 4                      brca_smc_2018_BB01_002      WRNIP1          6
# ...                                       ...         ...        ...
# 17053  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59       NRSN2         20
# 17054  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59      CHRNA4         20
# 17055  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59      CHRNA4         20
# 17056  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59       KCNQ2         20
# 17057  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59        XBP1         22
#
#        Start_position Variant_Classification Variant_Type Reference_Allele  \
# ...

# %%
data_mutation_ductal_NONTN_nohypo_nohyper_MutSig2CV.loc[data_mutation_ductal_NONTN_nohypo_nohyper_MutSig2CV['Hugo_Symbol']=='MAML3']
# Out:
#                           Tumor_Sample_Barcode Hugo_Symbol Chromosome  \
# 231                     brca_smc_2018_BB01_016       MAML3          4
# 3834                       brca_smc_2018_BR374       MAML3          4
# 3891                       brca_smc_2018_BR386       MAML3          4
# 4213                       brca_smc_2018_BR469       MAML3          4
# 10346                                 X18BR016       MAML3          4
# 49791                          TCGA-A2-A0D1-01       MAML3          4
# 89491                          TCGA-BH-A0E2-01       MAML3          4
# 89907                          TCGA-BH-A0GY-01       MAML3          4
# 90650                          TCGA-BH-A0HA-01       MAML3          4
# 96178                          TCGA-BH-A209-01       MAML3          4
# 96179                          TCGA-BH-A209-01       MAML3          4
# 116003                         TCGA-LL-A7T0-01       MAML3          4
# ...

# %%
# check if there are duplicated rows 
data_mutation_ductal_NONTN_nohypo_nohyper_MutSig2CV.duplicated().any()
# Out:
# True

# %%
#save the dataset as a tab-separated file 
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/MutSig2CV_input_DEFINITIVO")
data_mutation_ductal_NONTN_nohypo_nohyper_MutSig2CV.to_csv('mutation_table_ALL_DATASETS_NONTN_nohyper_nohypo.txt', sep='\t', index=False)

# %% [markdown]
# ## Study the mutation rate and the mutation frequency - NON TRIPLE NEGATIVE

# %%
data_mutation_ductal_NON_TN['PATIENT_ID'].nunique()
# Out:
# 1405

# %% [markdown]
# ### Mutation Rate analysis

# %%
# add a column to the dataset representing the mutated bases length (End_Position-Start_Position+1)
data_mutation_ductal_NON_TN.loc[:, 'Mutation_length'] = data_mutation_ductal_NON_TN['End_Position']-data_mutation_ductal_NON_TN['Start_Position']+1
data_mutation_ductal_NON_TN
# Out:
#                    PATIENT_ID                    Tumor_Sample_Barcode  \
# 0      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 1      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 2      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 3      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 4      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# ...                       ...                                     ...
# 17053     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17054     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17055     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17056     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 17057     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#       Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0           KALRN          3     123988087.0   123988087.0
# ...

# %%
data_mutation_ductal_NON_TN['PATIENT_ID'].nunique()
# Out:
# 1405

# %%
# extract PATIENT_ID and Mutation_length
pts_mutation_length_ductal_NON_TN = data_mutation_ductal_NON_TN[['PATIENT_ID', 'Mutation_length']]
pts_mutation_length_ductal_NON_TN
# Out:
#                    PATIENT_ID  Mutation_length
# 0      brca_smc_2018_BB01_002              1.0
# 1      brca_smc_2018_BB01_002              1.0
# 2      brca_smc_2018_BB01_002              1.0
# 3      brca_smc_2018_BB01_002              1.0
# 4      brca_smc_2018_BB01_002              1.0
# ...                       ...              ...
# 17053     MBCProject_zyt5TKFB              1.0
# 17054     MBCProject_zyt5TKFB              1.0
# 17055     MBCProject_zyt5TKFB              1.0
# 17056     MBCProject_zyt5TKFB              1.0
# 17057     MBCProject_zyt5TKFB              1.0
#
# [178140 rows x 2 columns]

# %%
# group by PATIENT_ID and sum the mutation lengths for each pts
mutation_ductal_NON_TN_group_by_pts=pts_mutation_length_ductal_NON_TN.groupby(['PATIENT_ID'])['Mutation_length'].sum().reset_index()
mutation_ductal_NON_TN_group_by_pts.rename(columns = {'Mutation_length':'Total_sum_mutated_bases'}, inplace = True)
mutation_ductal_NON_TN_group_by_pts
# Out:
#                PATIENT_ID  Total_sum_mutated_bases
# 0                BR-M-005                     26.0
# 1                BR-M-027                     71.0
# 2                BR-M-030                     27.0
# 3                BR-M-034                     31.0
# 4                BR-M-036                     16.0
# ...                   ...                      ...
# 1400  brca_smc_2018_BR431                     26.0
# 1401  brca_smc_2018_BR437                     58.0
# 1402  brca_smc_2018_BR442                     39.0
# 1403  brca_smc_2018_BR457                     59.0
# 1404  brca_smc_2018_BR469                     16.0
#
# [1405 rows x 2 columns]

# %%
# extract Hugo_Symbol and Gene_length
gene_length_for_each_mutation_ductal_NON_TN = data_mutation_ductal_NON_TN[['Hugo_Symbol', 'Gene_length']]
gene_length_for_each_mutation_ductal_NON_TN
# Out:
#       Hugo_Symbol  Gene_length
# 0           KALRN       646303
# 1            ANK2       565632
# 2          SORBS2       371209
# 3         PCDHA11       143241
# 4          WRNIP1        21539
# ...           ...          ...
# 17053       NRSN2        12879
# 17054      CHRNA4        34334
# 17055      CHRNA4        34334
# 17056       KCNQ2        66452
# 17057        XBP1         6043
#
# [178140 rows x 2 columns]

# %%
# look at the number of distinct genes
gene_length_for_each_mutation_ductal_NON_TN['Hugo_Symbol'].nunique()
# Out:
# 19686

# %%
# group by gene (Hugo_Symbol) 
mutation_ductal_NON_TN_group_by_gene=gene_length_for_each_mutation_ductal_NON_TN.groupby(['Hugo_Symbol'])['Gene_length'].max().reset_index()
mutation_ductal_NON_TN_group_by_gene
# Out:
#         Hugo_Symbol  Gene_length
# 0              A1BG         8322
# 1              A1CF        86267
# 2               A2M        48566
# 3             A2ML1        64530
# 4         A2ML1-AS1        54729
# ...             ...          ...
# 19681          ZZZ3       121004
# 19682  hsa-mir-1199         2527
# 19683  hsa-mir-6080        32337
# 19684  hsa-mir-7162        25340
# 19685        snoU13          103
#
# [19686 rows x 2 columns]

# %%
# compute the total gene length (for all the genes in the dataset)
total_GeneLength_ductal_NON_TN = mutation_ductal_NON_TN_group_by_gene['Gene_length'].sum()
total_GeneLength_ductal_NON_TN
# Out:
# 1313421106

# %%
# add a column to the dataset representing the mutation rate for each patient (Mutation_rate= Mutation_length/total_gene_length)
mutation_ductal_NON_TN_group_by_pts["Mutation_rate"] = mutation_ductal_NON_TN_group_by_pts["Total_sum_mutated_bases"]/total_GeneLength_ductal_NON_TN
mutation_ductal_NON_TN_group_by_pts
# Out:
#                PATIENT_ID  Total_sum_mutated_bases  Mutation_rate
# 0                BR-M-005                     26.0   1.979563e-08
# 1                BR-M-027                     71.0   5.405730e-08
# 2                BR-M-030                     27.0   2.055700e-08
# 3                BR-M-034                     31.0   2.360248e-08
# 4                BR-M-036                     16.0   1.218193e-08
# ...                   ...                      ...            ...
# 1400  brca_smc_2018_BR431                     26.0   1.979563e-08
# 1401  brca_smc_2018_BR437                     58.0   4.415949e-08
# 1402  brca_smc_2018_BR442                     39.0   2.969345e-08
# 1403  brca_smc_2018_BR457                     59.0   4.492086e-08
# 1404  brca_smc_2018_BR469                     16.0   1.218193e-08
#
# [1405 rows x 3 columns]

# %%
# multiply the Mutation_rate values for 10^6
mutation_ductal_NON_TN_group_by_pts["Mutation_rate*10^6"] = mutation_ductal_NON_TN_group_by_pts["Mutation_rate"]*1000000
mutation_ductal_NON_TN_group_by_pts
# Out:
#                PATIENT_ID  Total_sum_mutated_bases  Mutation_rate  \
# 0                BR-M-005                     26.0   1.979563e-08
# 1                BR-M-027                     71.0   5.405730e-08
# 2                BR-M-030                     27.0   2.055700e-08
# 3                BR-M-034                     31.0   2.360248e-08
# 4                BR-M-036                     16.0   1.218193e-08
# ...                   ...                      ...            ...
# 1400  brca_smc_2018_BR431                     26.0   1.979563e-08
# 1401  brca_smc_2018_BR437                     58.0   4.415949e-08
# 1402  brca_smc_2018_BR442                     39.0   2.969345e-08
# 1403  brca_smc_2018_BR457                     59.0   4.492086e-08
# 1404  brca_smc_2018_BR469                     16.0   1.218193e-08
#
#       Mutation_rate*10^6
# 0               0.019796
# 1               0.054057
# 2               0.020557
# 3               0.023602
# 4               0.012182
# ...

# %%
# the PATIENT_IDs are sorted for descending order of mutation rate 
mutation_ductal_NON_TN_group_by_pts= mutation_ductal_NON_TN_group_by_pts.sort_values(by="Mutation_rate", ascending=False)
mutation_ductal_NON_TN_group_by_pts
# Out:
#                PATIENT_ID  Total_sum_mutated_bases  Mutation_rate  \
# 863          TCGA-BH-A18V                  50146.0   3.817968e-05
# 474          TCGA-A2-A0EV                  24708.0   1.881194e-05
# 614          TCGA-AC-A8OP                  23143.0   1.762040e-05
# 575          TCGA-A8-A08L                   9075.0   6.909437e-06
# 619          TCGA-AN-A046                   7605.0   5.790222e-06
# ...                   ...                      ...            ...
# 1334  brca_smc_2018_BR033                      4.0   3.045482e-09
# 1350  brca_smc_2018_BR099                      3.0   2.284111e-09
# 248               MBC_149                      3.0   2.284111e-09
# 1103         TCGA-EW-A1P1                      3.0   2.284111e-09
# 258               MBC_160                      1.0   7.613704e-10
#
#       Mutation_rate*10^6
# 863            38.179682
# 474            18.811941
# 614            17.620396
# 575             6.909437
# 619             5.790222
# ...

# %%
patient_mutation_rate_ductal_NON_TN=mutation_ductal_NON_TN_group_by_pts[['PATIENT_ID', 'Mutation_rate*10^6' ]]
patient_mutation_rate_ductal_NON_TN
# Out:
#                PATIENT_ID  Mutation_rate*10^6
# 863          TCGA-BH-A18V           38.179682
# 474          TCGA-A2-A0EV           18.811941
# 614          TCGA-AC-A8OP           17.620396
# 575          TCGA-A8-A08L            6.909437
# 619          TCGA-AN-A046            5.790222
# ...                   ...                 ...
# 1334  brca_smc_2018_BR033            0.003045
# 1350  brca_smc_2018_BR099            0.002284
# 248               MBC_149            0.002284
# 1103         TCGA-EW-A1P1            0.002284
# 258               MBC_160            0.000761
#
# [1405 rows x 2 columns]

# %%
patients=np.arange(0,1405,1)
# convert a series into a Numpy array
mutation_rate=mutation_ductal_NON_TN_group_by_pts[['Mutation_rate*10^6']].to_numpy()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 8)
plt.yscale("log") 
#set axes limit
plt.ylim(0.001, 1000)
plt.scatter(patients, mutation_rate)
plt.xlabel("Patients")
plt.ylabel("Mutation rate per 10^6 bases (log scale)")
plt.show()

# %% [markdown]
# ### Mutation Frequency analysis

# %%
genes_patients_ductal_NON_TN=data_mutation_ductal_NON_TN[['PATIENT_ID', 'Hugo_Symbol']]
genes_patients_ductal_NON_TN
# Out:
#                    PATIENT_ID Hugo_Symbol
# 0      brca_smc_2018_BB01_002       KALRN
# 1      brca_smc_2018_BB01_002        ANK2
# 2      brca_smc_2018_BB01_002      SORBS2
# 3      brca_smc_2018_BB01_002     PCDHA11
# 4      brca_smc_2018_BB01_002      WRNIP1
# ...                       ...         ...
# 17053     MBCProject_zyt5TKFB       NRSN2
# 17054     MBCProject_zyt5TKFB      CHRNA4
# 17055     MBCProject_zyt5TKFB      CHRNA4
# 17056     MBCProject_zyt5TKFB       KCNQ2
# 17057     MBCProject_zyt5TKFB        XBP1
#
# [178140 rows x 2 columns]

# %%
genes_patients_ductal_NON_TN=genes_patients_ductal_NON_TN.drop_duplicates()
genes_patients_ductal_NON_TN
# Out:
#                    PATIENT_ID Hugo_Symbol
# 0      brca_smc_2018_BB01_002       KALRN
# 1      brca_smc_2018_BB01_002        ANK2
# 2      brca_smc_2018_BB01_002      SORBS2
# 3      brca_smc_2018_BB01_002     PCDHA11
# 4      brca_smc_2018_BB01_002      WRNIP1
# ...                       ...         ...
# 17052     MBCProject_zyt5TKFB       SSC5D
# 17053     MBCProject_zyt5TKFB       NRSN2
# 17054     MBCProject_zyt5TKFB      CHRNA4
# 17056     MBCProject_zyt5TKFB       KCNQ2
# 17057     MBCProject_zyt5TKFB        XBP1
#
# [143968 rows x 2 columns]

# %%
n_of_pts_per_gene_ductal_NON_TN= genes_patients_ductal_NON_TN.groupby(['Hugo_Symbol'])['PATIENT_ID'].count().reset_index()
n_of_pts_per_gene_ductal_NON_TN.rename(columns = {'PATIENT_ID':'Num_pts_per_gene'}, inplace = True)
n_of_pts_per_gene_ductal_NON_TN
# Out:
#         Hugo_Symbol  Num_pts_per_gene
# 0              A1BG                 5
# 1              A1CF                 9
# 2               A2M                26
# 3             A2ML1                23
# 4         A2ML1-AS1                 1
# ...             ...               ...
# 19681          ZZZ3                 8
# 19682  hsa-mir-1199                 2
# 19683  hsa-mir-6080                 7
# 19684  hsa-mir-7162                 3
# 19685        snoU13                 3
#
# [19686 rows x 2 columns]

# %%
tot_pts_ductal_NON_TN = 1252

# %%
# add a column to the n_of_pts_per_gene dataframe representing the mutation frequency for each gene
n_of_pts_per_gene_ductal_NON_TN["Mutation_frequency (%)"] = (n_of_pts_per_gene_ductal_NON_TN["Num_pts_per_gene"]*100)/tot_pts_ductal_NON_TN
n_of_pts_per_gene_ductal_NON_TN
# Out:
#         Hugo_Symbol  Num_pts_per_gene  Mutation_frequency (%)
# 0              A1BG                 5                0.399361
# 1              A1CF                 9                0.718850
# 2               A2M                26                2.076677
# 3             A2ML1                23                1.837061
# 4         A2ML1-AS1                 1                0.079872
# ...             ...               ...                     ...
# 19681          ZZZ3                 8                0.638978
# 19682  hsa-mir-1199                 2                0.159744
# 19683  hsa-mir-6080                 7                0.559105
# 19684  hsa-mir-7162                 3                0.239617
# 19685        snoU13                 3                0.239617
#
# [19686 rows x 3 columns]

# %%
# the numbers of patients per gene are sorted in descending order
n_of_pts_per_gene_ductal_NON_TN= n_of_pts_per_gene_ductal_NON_TN.sort_values(by="Num_pts_per_gene", ascending=False)
n_of_pts_per_gene_ductal_NON_TN
# Out:
#       Hugo_Symbol  Num_pts_per_gene  Mutation_frequency (%)
# 17563        TP53               522               41.693291
# 12534      PIK3CA               446               35.623003
# 18051         TTN               309               24.680511
# 6326        GATA3               185               14.776358
# 10478       MUC16               166               13.258786
# ...           ...               ...                     ...
# 17766      TRGV11                 1                0.079872
# 11923       OVOL2                 1                0.079872
# 17768       TRGV4                 1                0.079872
# 17769       TRGV5                 1                0.079872
# 2062     C1orf162                 1                0.079872
#
# [19686 rows x 3 columns]

# %%
gene_mutation_frequency_ductal_NON_TN = n_of_pts_per_gene_ductal_NON_TN[['Hugo_Symbol', 'Mutation_frequency (%)']]
gene_mutation_frequency_ductal_NON_TN
# Out:
#       Hugo_Symbol  Mutation_frequency (%)
# 17563        TP53               41.693291
# 12534      PIK3CA               35.623003
# 18051         TTN               24.680511
# 6326        GATA3               14.776358
# 10478       MUC16               13.258786
# ...           ...                     ...
# 17766      TRGV11                0.079872
# 11923       OVOL2                0.079872
# 17768       TRGV4                0.079872
# 17769       TRGV5                0.079872
# 2062     C1orf162                0.079872
#
# [19686 rows x 2 columns]

# %%
# select the first 50 genes
highest_mutated_genes_ductal_NON_TN=gene_mutation_frequency_ductal_NON_TN.head(50)
highest_mutated_genes_ductal_NON_TN
# Out:
#       Hugo_Symbol  Mutation_frequency (%)
# 17563        TP53               41.693291
# 12534      PIK3CA               35.623003
# 18051         TTN               24.680511
# 6326        GATA3               14.776358
# 10478       MUC16               13.258786
# 8661        KMT2C               10.623003
# 9552       MAP3K1                9.904153
# 14714        RYR2                9.025559
# 16570       SYNE1                8.466454
# 5982          FLG                8.146965
# 7335        HMCN1                7.747604
# 11387       OBSCN                7.428115
# 18365       USH2A                7.028754
# 14715        RYR3                6.549521
# 16198       SPTA1                6.389776
# 33         ABCA13                6.309904
# 14713        RYR1                6.309904
# 10837         NEB                6.230032
# 4775          DST                6.150160
# 3878        CSMD1                6.070288
# 2405      CACNA1E                5.830671
# ...

# %%
mutated_gene_names=highest_mutated_genes_ductal_NON_TN['Hugo_Symbol'].tolist()

# %%
# increase the quality and resolution of the chart
from IPython.display import set_matplotlib_formats
import matplotlib_inline.backend_inline

matplotlib_inline.backend_inline.set_matplotlib_formats('retina')
# set default figure size.
plt.rcParams['figure.figsize'] = (12, 8)
fig, ax = plt.subplots()
h=ax.bar(highest_mutated_genes_ductal_NON_TN['Hugo_Symbol'], highest_mutated_genes_ductal_NON_TN['Mutation_frequency (%)'], label=mutated_gene_names)
xticks_pos = [0.65*patch.get_width() + patch.get_xy()[0] for patch in h]

_ = plt.xticks(xticks_pos, mutated_gene_names,  ha='right', rotation=45)
#plt.title('Highest mutated genes', fontsize=14)
plt.xlabel('Mutated gene', fontsize=14)
plt.ylabel('Mutation frequency (%)', fontsize=14)

plt.ylim(0, 40)

# First, let's remove the top, right and left spines (figure borders)
# which really aren't necessary for a bar chart.
# Also, make the bottom spine gray instead of black.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')

# Second, remove the ticks as well.
ax.tick_params(bottom=False, left=False)

# Third, add a horizontal grid (but keep the vertical grid hidden).
# Color the lines a light gray as well.
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Add text annotations to the top of the bars.
# Note, you'll have to adjust this slightly (the 0.3)
# with different data.
for bar in h:
  ax.text(
      bar.get_x() + bar.get_width() / 2,
      bar.get_height() + 0.3,
      round(bar.get_height(), 1),
      rotation='vertical',
      horizontalalignment='center'
  )


fig.tight_layout()

# %% [markdown]
# ### Delete from the total ductal BC mutation dataset both the hypermutated and the hypomutated patients

# %%
data_mutation_TOTAL_ductal
# Out:
#                    PATIENT_ID                    Tumor_Sample_Barcode  \
# 0      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 1      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 2      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 3      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 4      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# ...                       ...                                     ...
# 19868     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19869     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19870     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19871     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19872     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#       Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0           KALRN          3     123988087.0   123988087.0
# ...

# %%
mask_totalductal = data_mutation_TOTAL_ductal['PATIENT_ID'].isin(hyper_hypo_patients_total_ductal['PATIENT_ID'])
mask_totalductal
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19868    False
# 19869    False
# 19870    False
# 19871    False
# 19872    False
# Name: PATIENT_ID, Length: 182830, dtype: bool

# %%
data_mutation_totalductal_nohypo_nohyper = data_mutation_TOTAL_ductal[~mask_totalductal].copy()
data_mutation_totalductal_nohypo_nohyper
# Out:
#                    PATIENT_ID                    Tumor_Sample_Barcode  \
# 0      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 1      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 2      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 3      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 4      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# ...                       ...                                     ...
# 19868     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19869     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19870     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19871     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19872     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#       Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0           KALRN          3     123988087.0   123988087.0
# ...

# %%
data_mutation_totalductal_nohypo_nohyper['Hugo_Symbol'] = data_mutation_totalductal_nohypo_nohyper['Hugo_Symbol'].replace(['EPPIN-WFDC6'], 'EPPIN')

# %%
data_mutation_totalductal_nohypo_nohyper['Hugo_Symbol'] = data_mutation_totalductal_nohypo_nohyper['Hugo_Symbol'].replace(['EIF3CL'], 'EIF3C')

# %%
data_mutation_totalductal_nohypo_nohyper.PATIENT_ID.nunique()
# Out:
# 1527

# %%
data_mutation_totalductal_nohypo_nohyper.Hugo_Symbol.nunique()
# Out:
# 19466

# %%
data_mutation_totalductal_nohypo_nohyper
# Out:
#                    PATIENT_ID                    Tumor_Sample_Barcode  \
# 0      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 1      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 2      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 3      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 4      brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# ...                       ...                                     ...
# 19868     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19869     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19870     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19871     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 19872     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#       Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0           KALRN          3     123988087.0   123988087.0
# ...

# %%
#save the dataset as a tab-separated file 
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi")
data_mutation_totalductal_nohypo_nohyper.to_csv('mutation_table_ALL_DATASETS_total_ductal_nohypo_nohyper_definitive.txt', sep='\t', index=False)

# %%
data_mutation_totalductal_nohypo_nohyper['Hugo_Symbol'].nunique()
# Out:
# 19466

# %%
genes_totalductal_nohypo_nohyper = data_mutation_totalductal_nohypo_nohyper[['Hugo_Symbol']]
genes_totalductal_nohypo_nohyper
# Out:
#       Hugo_Symbol
# 0           KALRN
# 1            ANK2
# 2          SORBS2
# 3         PCDHA11
# 4          WRNIP1
# ...           ...
# 19868       NRSN2
# 19869      CHRNA4
# 19870      CHRNA4
# 19871       KCNQ2
# 19872        XBP1
#
# [139370 rows x 1 columns]

# %%
genes_unique_totalductal_nohypo_nohyper = genes_totalductal_nohypo_nohyper.drop_duplicates(subset=['Hugo_Symbol'], keep='first')
genes_unique_totalductal_nohypo_nohyper
# Out:
#          Hugo_Symbol
# 0              KALRN
# 1               ANK2
# 2             SORBS2
# 3            PCDHA11
# 4             WRNIP1
# ...              ...
# 19729          FGF17
# 19752          LYVE1
# 19760       C12orf29
# 19785          HSBP1
# 19803  MEF2BNB-MEF2B
#
# [19466 rows x 1 columns]

# %%
#save the dataset as a tab-separated file 
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi")
genes_unique_totalductal_nohypo_nohyper.to_csv('gene_total_ductal.txt', sep='\t', index=False)
