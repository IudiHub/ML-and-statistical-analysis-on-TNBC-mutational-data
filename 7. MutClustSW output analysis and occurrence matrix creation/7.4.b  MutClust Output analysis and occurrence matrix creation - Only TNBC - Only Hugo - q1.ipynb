# %% [markdown]
# # MutClust Output analysis and occurrence matrix creation - Only TNBC - Only Hugo - q-value < 1

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import os
import sklearn

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/MutClust_output_definitivo")

# %% [markdown]
# REMEMBER:
# - from MutSig2CV I selected the genes with q-value < 1
# - in input to MutClust I just gave the Hugo symbols without the variant classifications

# %% [markdown]
# ### Genes significantly mutated both in the Triple-Negative dataset (qval < 1)

# %%
# I run MutClust on the TOTAL DATASET intersected with the significant genes from MutSig2CV
df_mutclust_q1_TNandNONTN_onlyHugo = pd.read_csv('Output_onlyHugo_onlyTN_q1_definitivo.txt', delimiter='\t', engine='python')
df_mutclust_q1_TNandNONTN_onlyHugo
# Out:
#         Gene  Start  End  Scoresum Recursion  Mutation        NES    Pvalue
# 0       TP53    270  282  0.085953         Y        78  13.231975  0.000000
# 1       TP53    191  199  0.079947         Y        65  12.007543  0.000000
# 2       TP53    236  258  0.077052         Y        94  11.417253  0.000000
# 3       TP53    173  177  0.061644         Y        47   8.275880  0.000000
# 4       TP53    211  218  0.030277         Y        32   1.880502  0.049505
# ..       ...    ...  ...       ...       ...       ...        ...       ...
# 389  ZKSCAN1    402  402  0.033938         N         1  -3.147024  0.990099
# 390  ZKSCAN1    436  436  0.033938         N         1  -3.147024  0.990099
# 391  ZKSCAN1    458  458  0.033938         N         1  -3.147024  0.990099
# 392  ZKSCAN1    511  511  0.033938         N         1  -3.147024  0.990099
# 393  ZKSCAN1    530  530  0.033938         N         1  -3.147024  0.990099
#
# [394 rows x 8 columns]

# %%
# sort the dataframe by ascending order of Pvalue (from the most significant mutation to the least significant)
df_mutclust_q1_TNandNONTN_onlyHugo = df_mutclust_q1_TNandNONTN_onlyHugo.sort_values('Pvalue')
df_mutclust_q1_TNandNONTN_onlyHugo
# Out:
#         Gene  Start  End  Scoresum Recursion  Mutation        NES    Pvalue
# 0       TP53    270  282  0.085953         Y        78  13.231975  0.000000
# 84     MAML3    503  503  0.388010         Y         7   6.054144  0.000000
# 336    MYL10     26   26  0.631939         Y         7   6.045801  0.000000
# 44    PIK3CA    102  113  0.037354         Y        26   8.067682  0.000000
# 42    PIK3CA    541  542  0.107077         Y        56  32.590886  0.000000
# ..       ...    ...  ...       ...       ...       ...        ...       ...
# 146   NOTCH2    476  476  0.027373         N         1  -2.611719  0.990099
# 145   NOTCH2    268  268  0.027373         N         1  -2.611719  0.990099
# 144   NOTCH2    217  217  0.027373         N         1  -2.611719  0.990099
# 216      RB1    873  873  0.027494         N         1  -2.691638  0.990099
# 393  ZKSCAN1    530  530  0.033938         N         1  -3.147024  0.990099
#
# [394 rows x 8 columns]

# %% [markdown]
# **Relevant_cluster** : creates a dictionary containing values from 0.01 to 1 (with an interval of 0.01), in which each value is associated to the number of genes with p-value lower than the value itself.

# %%
# define a function that gives in output the number of relevant clusters at different p-values
def Relevant_cluster (df_mutclust):
    n_relevant_clusters = {}   
    for i in np.arange(0.01, 1, 0.01):
        n_relevant_clusters[i]=len(df_mutclust[df_mutclust.Pvalue<i]) 
    return (n_relevant_clusters)

# %%
n_relevant_clusters_mutclust_q1_TNandNONTN_onlyHugo = Relevant_cluster(df_mutclust_q1_TNandNONTN_onlyHugo)
n_relevant_clusters_mutclust_q1_TNandNONTN_onlyHugo
# Out:
# {0.01: 14,
#  0.02: 16,
#  0.03: 17,
#  0.04: 18,
#  0.05: 19,
#  0.060000000000000005: 20,
#  0.06999999999999999: 20,
#  0.08: 20,
#  0.09: 23,
#  0.09999999999999999: 23,
#  0.11: 23,
#  0.12: 23,
#  0.13: 23,
#  0.14: 24,
#  0.15000000000000002: 25,
#  0.16: 25,
#  0.17: 25,
#  0.18000000000000002: 25,
#  0.19: 26,
#  0.2: 26,
#  0.21000000000000002: 26,
#  0.22: 26,
#  0.23: 26,
#  0.24000000000000002: 26,
#  0.25: 27,
#  0.26: 28,
#  0.27: 28,
#  0.28: 28,
#  0.29000000000000004: 28,
#  0.3: 28,
#  0.31: 28,
#  0.32: 28,
#  0.33: 29,
#  0.34: 30,
#  0.35000000000000003: 30,
#  0.36000000000000004: 30,
#  0.37: 30,
#  0.38: 30,
#  0.39: 30,
#  0.4: 30,
#  0.41000000000000003: 30,
#  0.42000000000000004: 30,
#  0.43: 30,
#  0.44: 31,
#  0.45: 31,
#  0.46: 31,
#  0.47000000000000003: 31,
#  0.48000000000000004: 31,
#  0.49: 31,
#  0.5: 31,
#  0.51: 31,
#  0.52: 31,
#  0.53: 31,
#  0.54: 31,
#  0.55: 31,
#  0.56: 32,
#  0.5700000000000001: 32,
#  0.5800000000000001: 32,
#  0.59: 35,
#  0.6: 35,
#  0.61: 35,
#  0.62: 35,
#  0.63: 35,
#  0.64: 35,
#  0.65: 35,
#  0.66: 35,
#  0.67: 35,
#  0.68: 36,
#  0.6900000000000001: 38,
#  0.7000000000000001: 38,
#  0.7100000000000001: 40,
#  0.72: 40,
#  0.73: 41,
#  0.74: 41,
#  0.75: 41,
#  0.76: 41,
#  0.77: 41,
#  0.78: 41,
#  0.79: 42,
#  0.8: 42,
#  0.81: 43,
#  0.8200000000000001: 43,
#  0.8300000000000001: 43,
#  0.8400000000000001: 43,
#  0.85: 43,
#  0.86: 43,
#  0.87: 43,
#  0.88: 43,
#  0.89: 44,
#  0.9: 44,
#  0.91: 44,
#  0.92: 46,
#  0.93: 48,
#  0.9400000000000001: 48,
#  0.9500000000000001: 48,
#  0.9600000000000001: 50,
#  0.97: 52,
#  0.98: 56,
#  0.99: 62}

# %%
# count how many clusters have p-value = 0 
len(df_mutclust_q1_TNandNONTN_onlyHugo.loc[df_mutclust_q1_TNandNONTN_onlyHugo['Pvalue'] == 0.000000])
# Out:
# 14

# %%
# convert the dictionary into a Dataframe
df_n_relevant_clusters_mutclust_q1_TNandNONTN_onlyHugo = pd.DataFrame.from_dict(n_relevant_clusters_mutclust_q1_TNandNONTN_onlyHugo, orient='index')
df_n_relevant_clusters_mutclust_q1_TNandNONTN_onlyHugo.rename(columns={0: "Significant clusters"}, inplace=True)
df_n_relevant_clusters_mutclust_q1_TNandNONTN_onlyHugo.reset_index(level=0, inplace=True)
df_n_relevant_clusters_mutclust_q1_TNandNONTN_onlyHugo.rename(columns={"index": "P-value"}, inplace=True)
df_n_relevant_clusters_mutclust_q1_TNandNONTN_onlyHugo
# Out:
#     P-value  Significant clusters
# 0      0.01                    14
# 1      0.02                    16
# 2      0.03                    17
# 3      0.04                    18
# 4      0.05                    19
# ..      ...                   ...
# 94     0.95                    48
# 95     0.96                    50
# 96     0.97                    52
# 97     0.98                    56
# 98     0.99                    62
#
# [99 rows x 2 columns]

# %% [markdown]
# ### Plot the number of significant clusters as the p-value varies
#
# Define a function to plot the number of significant clusters as the p-value varies.

# %%
def Grafico_Clusters_significativi_one_dataset(df_n_rel_clusters_mutclust, caso):
    casistica_titolo = 'Significant hotspots as the p-value varies - XXX'
    casistica_titolo = casistica_titolo.replace('XXX',caso)
    casistica_legenda = 'Significant hotspots determined by the XXX'
    casistica_legenda = casistica_legenda.replace('XXX', caso)
    
    df_n_rel_clusters_mutclust_copy = df_n_rel_clusters_mutclust.copy()
    df_n_rel_clusters_mutclust_copy = df_n_rel_clusters_mutclust_copy.set_index('P-value')
    
    plt.rcParams['figure.figsize'] = (10, 8)
    plt.plot(df_n_rel_clusters_mutclust_copy, label = casistica_legenda, color = 'red')
    plt.xlabel('P-value', fontsize=13)
    plt.ylabel('Number of significant hotspots', fontsize=13)
    plt.legend(loc='lower left', bbox_to_anchor=(0.0, -0.2), fontsize='large')
    plt.title(casistica_titolo,fontsize= 18)

# %%
Grafico_Clusters_significativi_one_dataset(df_n_relevant_clusters_mutclust_q1_TNandNONTN_onlyHugo, 'total genes from Triple-negative and Non Triple-negative patients')

# %% [markdown]
# ### Look at the clusters with a p-value < 0.05

# %% [markdown]
# **Freq_cluster**: this function takes as input the output of MutClust containing the clusters associated to a p-value and a specific p-value. The output is a subset of the original dataframe containing only the clusters with a p-value < seleceted p-value.

# %%
def Freq_cluster (df, val):
    freq_clusters = df[(df.Pvalue<val)]
    return (freq_clusters)

# %%
# Genes significantly mutated both in the Triple-Negative dataset and in the non Triple-Negative dataset (qval < 1)
freq_cluster_q1_TNandNONTN_onlyHugo = Freq_cluster(df_mutclust_q1_TNandNONTN_onlyHugo, 0.05)
freq_cluster_q1_TNandNONTN_onlyHugo = freq_cluster_q1_TNandNONTN_onlyHugo.reset_index(drop=True)
freq_cluster_q1_TNandNONTN_onlyHugo
# Out:
#        Gene  Start   End  Scoresum Recursion  Mutation         NES    Pvalue
# 0      TP53    270   282  0.085953         Y        78   13.231975  0.000000
# 1     MAML3    503   503  0.388010         Y         7    6.054144  0.000000
# 2     MYL10     26    26  0.631939         Y         7    6.045801  0.000000
# 3    PIK3CA    102   113  0.037354         Y        26    8.067682  0.000000
# 4    PIK3CA    541   542  0.107077         Y        56   32.590886  0.000000
# 5    PIK3CA    545   546  0.188789         Y        98   61.330893  0.000000
# 6    PIK3CA   1046  1047  0.383341         Y       198  129.759481  0.000000
# 7   ZKSCAN1    270   270  0.569652         Y        16   19.585304  0.000000
# 8    PIK3R1    566   578  0.327791         Y        12    9.646755  0.000000
# 9    ZNF195    109   111  0.493618         Y         8    6.920219  0.000000
# 10   PIK3CA    345   345  0.059375         N        31   15.813067  0.000000
# 11     TP53    191   199  0.079947         Y        65   12.007543  0.000000
# 12     TP53    173   177  0.061644         Y        47    8.275880  0.000000
# 13     TP53    236   258  0.077052         Y        94   11.417253  0.000000
# 14   MTMR12    520   521  0.381938         Y         5    3.050856  0.019802
# 15   PIK3CA    418   420  0.020537         N        12    2.152978  0.019802
# 16     PTEN    317   318  0.088371         Y         7    2.091945  0.029703
# 17   NOTCH2   2297  2303  0.134416         Y         5    1.873056  0.039604
# 18     TP53    211   218  0.030277         Y        32    1.880502  0.049505

# %%
len(freq_cluster_q1_TNandNONTN_onlyHugo)
# Out:
# 19

# %% [markdown]
# There are 19 significant clusters (p-value < 0.05) considering all the relevant genes in BOTH the Triple-negative dataset and the NON Triple-Negative dataset.

# %% [markdown]
# # Occurrence Matrix Creation

# %%
# load the mutation dataset resulting from the intersection between the significant TN and NON TN genes from MutSig and the total ductal dataset
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/MutClust_input_definitivo")
significant_mutations_TNandNONTN_AND_total_ductal_onlyHugo_Q1 = pd.read_csv('data_mutation_SINIFICANTgenes_ONLYhugo_onlyTN_Q1_definitivo.txt', sep=None, engine='python')
significant_mutations_TNandNONTN_AND_total_ductal_onlyHugo_Q1
# Out:
#                   PATIENT_ID                     Tumor_Sample_Barcode  \
# 0     brca_smc_2018_BB01_002                   brca_smc_2018_BB01_002
# 1     brca_smc_2018_BB01_002                   brca_smc_2018_BB01_002
# 2     brca_smc_2018_BB01_004                   brca_smc_2018_BB01_004
# 3     brca_smc_2018_BB01_004                   brca_smc_2018_BB01_004
# 4     brca_smc_2018_BB01_005                   brca_smc_2018_BB01_005
# ...                      ...                                      ...
# 1655     MBCProject_pyhbI1H5   MBC-MBCProject_pyhbI1H5-Tumor-SM-GQCX6
# 1656     MBCProject_rJHBiKTl   MBC-MBCProject_rJHBiKTl-Tumor-SM-DL3K3
# 1657     MBCProject_rYSXcxcV  RP-1156_MBCProject_rYSXcxcV_T1_v4_Exome
# 1658     MBCProject_rvULI3TV   MBC-MBCProject_rvULI3TV-Tumor-SM-DL41F
# 1659     MBCProject_xBfJfri9   MBC-MBCProject_xBfJfri9-Tumor-SM-CGLAP
#
#      Hugo_Symbol  Chromosome  Start_Position  End_Position  \
# 0           TP53          17       7574003.0     7574003.0
# 1         PIK3CA           3     178952150.0   178952151.0
# 2           TP53          17       7577117.0     7577117.0
# 3          MAML3           4     140811082.0   140811083.0
# 4         PIK3CA           3     178952085.0   178952085.0
# ...          ...         ...             ...           ...
# 1655        TP53          17       7579356.0     7579356.0
# 1656        TP53          17       7578271.0     7578271.0
# 1657        TP53          17       7578208.0     7578208.0
# 1658     ZKSCAN1           7      99630937.0    99630938.0
# 1659        PTEN          10      89720799.0    89720802.0
#
#      Variant_Classification Variant_Type Reference_Allele Tumor_Seq_Allele1  \
# 0         Nonsense_Mutation          SNP                G                 G
# 1           Frame_Shift_Ins          INS                -                 -
# 2         Missense_Mutation          SNP                A                 A
# 3              In_Frame_Ins          INS                -                 -
# 4         Missense_Mutation          SNP                A                 A
# ...                     ...          ...              ...               ...
# 1655      Missense_Mutation          SNP                G                 G
# 1656      Missense_Mutation          SNP                T                 T
# 1657      Missense_Mutation          SNP                T                 T
# 1658        Frame_Shift_Ins          INS                -                 -
# 1659        Frame_Shift_Del          DEL             TACT              TACT
#
#       ...                                 HGVSc     HGVSp_Short  \
# 0     ...           ENST00000269305.4:c.1024C>T         p.R342*
# 1     ...  ENST00000263967.3:c.3205_3206insTTTT    p.*1069Ffs*5
# 2     ...            ENST00000269305.4:c.821T>G         p.V274G
# 3     ...   ENST00000509479.2:c.1508_1509insCAA  p.Q503delinsHK
# 4     ...           ENST00000263967.3:c.3140A>G        p.H1047R
# ...   ...                                   ...             ...
# 1655  ...            ENST00000269305.4:c.331C>G         p.L111V
# 1656  ...            ENST00000269305.4:c.578A>G         p.H193R
# 1657  ...            ENST00000269305.4:c.641A>G         p.H214R
# 1658  ...            ENST00000324306.6:c.810dup     p.R271Qfs*3
# 1659  ...        ENST00000371953.3:c.955_958del         p.T319*
#
#         Transcript_ID Gene_length  ENSP              Hugo_variant  \
# 0     ENST00000269305       25760   NaN    TP53_Nonsense_Mutation
# 1     ENST00000263967       91980   NaN    PIK3CA_Frame_Shift_Ins
# 2     ENST00000269305       25760   NaN    TP53_Missense_Mutation
# 3     ENST00000509479      437432   NaN        MAML3_In_Frame_Ins
# 4     ENST00000263967       91980   NaN  PIK3CA_Missense_Mutation
# ...               ...         ...   ...                       ...
# 1655  ENST00000269305       25760   NaN    TP53_Missense_Mutation
# 1656  ENST00000269305       25760   NaN    TP53_Missense_Mutation
# 1657  ENST00000269305       25760   NaN    TP53_Missense_Mutation
# 1658  ENST00000324306       26109   NaN   ZKSCAN1_Frame_Shift_Ins
# 1659  ENST00000371953      108818   NaN      PTEN_Frame_Shift_Del
#
#      Mutation_length  Protein_position_start  Protein_position_end  \
# 0                1.0                   342.0                 342.0
# 1                2.0                  1069.0                1069.0
# 2                1.0                   274.0                 274.0
# 3                2.0                   503.0                 503.0
# 4                1.0                  1047.0                1047.0
# ...              ...                     ...                   ...
# 1655             1.0                   111.0                 111.0
# 1656             1.0                   193.0                 193.0
# 1657             1.0                   214.0                 214.0
# 1658             2.0                   270.0                 270.0
# 1659             4.0                   317.0                 317.0
#
#       Protein_length
# 0                393
# 1               1068
# 2                393
# 3               1138
# 4               1068
# ...              ...
# 1655             393
# 1656             393
# 1657             393
# 1658             563
# 1659             403
#
# [1660 rows x 21 columns]

# %%
significant_mutations_TNandNONTN_AND_total_ductal_onlyHugo_Q1.PATIENT_ID.nunique()
# Out:
# 1058

# %%
significant_mutations_TNandNONTN_AND_total_ductal_onlyHugo_Q1.Hugo_Symbol.nunique()
# Out:
# 23

# %%
unique_Hugo_symbols_array = significant_mutations_TNandNONTN_AND_total_ductal_onlyHugo_Q1.Hugo_Symbol.unique()
unique_Hugo_symbols_array
# Out:
# array(['TP53', 'PIK3CA', 'MAML3', 'PTEN', 'NOTCH2', 'CDKN2A', 'FBXW7',
#        'RB1', 'ZNF195', 'PIK3R1', 'C6orf118', 'STAB2', 'BRCA1', 'MGAT5B',
#        'MYL10', 'NUP153', 'LZTR1', 'MTMR12', 'ZKSCAN1', 'COIL', 'NBN',
#        'ATG4C', 'RAB42'], dtype=object)

# %%
df_unique_Hugo_symbols = pd.DataFrame(unique_Hugo_symbols_array, columns=['Hugo_Symbol'])
df_unique_Hugo_symbols
# Out:
#    Hugo_Symbol
# 0         TP53
# 1       PIK3CA
# 2        MAML3
# 3         PTEN
# 4       NOTCH2
# 5       CDKN2A
# 6        FBXW7
# 7          RB1
# 8       ZNF195
# 9       PIK3R1
# 10    C6orf118
# 11       STAB2
# 12       BRCA1
# 13      MGAT5B
# 14       MYL10
# 15      NUP153
# 16       LZTR1
# 17      MTMR12
# 18     ZKSCAN1
# 19        COIL
# 20         NBN
# 21       ATG4C
# 22       RAB42

# %%
# load the total ductal mutation dataset with the corrected protein_positions end and start
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi")
total_ductal_dataset = pd.read_csv('data_mutation_total_ductal_nohypo_nohyper_CORRECTION_protein_pos_definitivo.csv', sep=None, engine='python')
total_ductal_dataset
# Out:
#                     PATIENT_ID                    Tumor_Sample_Barcode  \
# 0       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 1       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 2       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 3       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 4       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# ...                        ...                                     ...
# 139365     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 139366     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 139367     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 139368     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 139369     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#        Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0            KALRN          3     123988087.0   123988087.0
# 1             ANK2          4     114195720.0   114195720.0
# 2           SORBS2          4     186539742.0   186539742.0
# 3          PCDHA11          5     140250828.0   140250828.0
# 4           WRNIP1          6       2766210.0     2766210.0
# ...            ...        ...             ...           ...
# 139365       NRSN2         20        333991.0      333991.0
# 139366      CHRNA4         20      61986887.0    61986887.0
# 139367      CHRNA4         20      61987386.0    61987386.0
# 139368       KCNQ2         20      62078103.0    62078103.0
# 139369        XBP1         22      29191563.0    29191563.0
#
#        Variant_Classification Variant_Type Reference_Allele Tumor_Seq_Allele1  \
# 0           Missense_Mutation          SNP                G                 G
# 1           Missense_Mutation          SNP                C                 C
# 2           Missense_Mutation          SNP                G                 G
# 3           Missense_Mutation          SNP                C                 C
# 4           Missense_Mutation          SNP                C                 C
# ...                       ...          ...              ...               ...
# 139365                 Silent          SNP                C                 C
# 139366                 Intron          SNP                G                 G
# 139367                 Silent          SNP                G                 G
# 139368                 Silent          SNP                G                 G
# 139369      Nonsense_Mutation          SNP                G                 G
#
#        Tumor_Seq_Allele2                           HGVSc HGVSp_Short  \
# 0                      C      ENST00000240874.3:c.948G>C     p.E316D
# 1                      T     ENST00000357077.4:c.1598C>T     p.P533L
# 2                      C     ENST00000355634.5:c.2936C>G     p.S979C
# 3                      G     ENST00000398640.2:c.2140C>G     p.L714V
# 4                      A      ENST00000380773.4:c.354C>A     p.S118R
# ...                  ...                             ...         ...
# 139365                 T      ENST00000382285.2:c.327C>T     p.N109=
# 139366                 C  ENST00000370263.4:c.383+440C>G     p.*128*
# 139367                 A      ENST00000370263.4:c.324C>T     p.V108=
# 139368                 A      ENST00000359125.2:c.384C>T     p.I128=
# 139369                 A      ENST00000216037.6:c.757C>T     p.Q253*
#
#           Transcript_ID  Gene_length ENSP               Hugo_variant  \
# 0       ENST00000240874       646303  NaN    KALRN_Missense_Mutation
# 1       ENST00000357077       565632  NaN     ANK2_Missense_Mutation
# 2       ENST00000355634       371209  NaN   SORBS2_Missense_Mutation
# 3       ENST00000398640       143241  NaN  PCDHA11_Missense_Mutation
# 4       ENST00000380773        21539  NaN   WRNIP1_Missense_Mutation
# ...                 ...          ...  ...                        ...
# 139365  ENST00000382285        12879  NaN               NRSN2_Silent
# 139366  ENST00000370263        34334  NaN              CHRNA4_Intron
# 139367  ENST00000370263        34334  NaN              CHRNA4_Silent
# 139368  ENST00000359125        66452  NaN               KCNQ2_Silent
# 139369  ENST00000216037         6043  NaN     XBP1_Nonsense_Mutation
#
#         Mutation_length  Protein_position_start  Protein_position_end
# 0                   1.0                   316.0                 316.0
# 1                   1.0                   533.0                 533.0
# 2                   1.0                   979.0                 979.0
# 3                   1.0                   714.0                 714.0
# 4                   1.0                   118.0                 118.0
# ...                 ...                     ...                   ...
# 139365              1.0                   109.0                 109.0
# 139366              1.0                     NaN                   NaN
# 139367              1.0                   108.0                 108.0
# 139368              1.0                   128.0                 128.0
# 139369              1.0                   253.0                 253.0
#
# [139370 rows x 20 columns]

# %%
freq_cluster_q1_TNandNONTN_onlyHugo
# Out:
#        Gene  Start   End  Scoresum Recursion  Mutation         NES    Pvalue
# 0      TP53    270   282  0.085953         Y        78   13.231975  0.000000
# 1     MAML3    503   503  0.388010         Y         7    6.054144  0.000000
# 2     MYL10     26    26  0.631939         Y         7    6.045801  0.000000
# 3    PIK3CA    102   113  0.037354         Y        26    8.067682  0.000000
# 4    PIK3CA    541   542  0.107077         Y        56   32.590886  0.000000
# 5    PIK3CA    545   546  0.188789         Y        98   61.330893  0.000000
# 6    PIK3CA   1046  1047  0.383341         Y       198  129.759481  0.000000
# 7   ZKSCAN1    270   270  0.569652         Y        16   19.585304  0.000000
# 8    PIK3R1    566   578  0.327791         Y        12    9.646755  0.000000
# 9    ZNF195    109   111  0.493618         Y         8    6.920219  0.000000
# 10   PIK3CA    345   345  0.059375         N        31   15.813067  0.000000
# 11     TP53    191   199  0.079947         Y        65   12.007543  0.000000
# 12     TP53    173   177  0.061644         Y        47    8.275880  0.000000
# 13     TP53    236   258  0.077052         Y        94   11.417253  0.000000
# 14   MTMR12    520   521  0.381938         Y         5    3.050856  0.019802
# 15   PIK3CA    418   420  0.020537         N        12    2.152978  0.019802
# 16     PTEN    317   318  0.088371         Y         7    2.091945  0.029703
# 17   NOTCH2   2297  2303  0.134416         Y         5    1.873056  0.039604
# 18     TP53    211   218  0.030277         Y        32    1.880502  0.049505

# %%
df_unique_Hugo_symbols
# Out:
#    Hugo_Symbol
# 0         TP53
# 1       PIK3CA
# 2        MAML3
# 3         PTEN
# 4       NOTCH2
# 5       CDKN2A
# 6        FBXW7
# 7          RB1
# 8       ZNF195
# 9       PIK3R1
# 10    C6orf118
# 11       STAB2
# 12       BRCA1
# 13      MGAT5B
# 14       MYL10
# 15      NUP153
# 16       LZTR1
# 17      MTMR12
# 18     ZKSCAN1
# 19        COIL
# 20         NBN
# 21       ATG4C
# 22       RAB42

# %% [markdown]
# ### Columns of the occurence matrix: hotspots found by MutClust and mutations on genes not belonging to any hotspot (columns that are marked with the suffix noClust)

# %%
# creo la lista delle colonne della matrice di occorrenza
def CreatingColumns_OccMatrix(freq_cluster_x, df_Hugo_unique):
    columns = []

    for index_clust, row_clust in freq_cluster_x.iterrows():
        columns.append(row_clust.Gene + '_' + str(row_clust.Start) + '_' + str(row_clust.End)) 
    
    #aggiungo le colonne per le mutazioni che non sono presenti in nessun cluster
    for index_mut, row_mut in df_Hugo_unique.iterrows():
        columns.append(row_mut.Hugo_Symbol + '_noClust')
    
    return columns

# %%
columns_occ_matrix_TNandNONTNgenes_q1_onlyHugo = CreatingColumns_OccMatrix (freq_cluster_q1_TNandNONTN_onlyHugo, df_unique_Hugo_symbols)
columns_occ_matrix_TNandNONTNgenes_q1_onlyHugo
# Out:
# ['TP53_270_282',
#  'MAML3_503_503',
#  'MYL10_26_26',
#  'PIK3CA_102_113',
#  'PIK3CA_541_542',
#  'PIK3CA_545_546',
#  'PIK3CA_1046_1047',
#  'ZKSCAN1_270_270',
#  'PIK3R1_566_578',
#  'ZNF195_109_111',
#  'PIK3CA_345_345',
#  'TP53_191_199',
#  'TP53_173_177',
#  'TP53_236_258',
#  'MTMR12_520_521',
#  'PIK3CA_418_420',
#  'PTEN_317_318',
#  'NOTCH2_2297_2303',
#  'TP53_211_218',
#  'TP53_noClust',
#  'PIK3CA_noClust',
#  'MAML3_noClust',
#  'PTEN_noClust',
#  'NOTCH2_noClust',
#  'CDKN2A_noClust',
#  'FBXW7_noClust',
#  'RB1_noClust',
#  'ZNF195_noClust',
#  'PIK3R1_noClust',
#  'C6orf118_noClust',
#  'STAB2_noClust',
#  'BRCA1_noClust',
#  'MGAT5B_noClust',
#  'MYL10_noClust',
#  'NUP153_noClust',
#  'LZTR1_noClust',
#  'MTMR12_noClust',
#  'ZKSCAN1_noClust',
#  'COIL_noClust',
#  'NBN_noClust',
#  'ATG4C_noClust',
#  'RAB42_noClust']

# %%
len(columns_occ_matrix_TNandNONTNgenes_q1_onlyHugo)
# Out:
# 42

# %%
# convert the list of columns into a dataframe
df_columns_occ_matrix_onlyHugo = pd.DataFrame(columns_occ_matrix_TNandNONTNgenes_q1_onlyHugo, columns=['columns_occurence_matrix'])
df_columns_occ_matrix_onlyHugo
# Out:
#    columns_occurence_matrix
# 0              TP53_270_282
# 1             MAML3_503_503
# 2               MYL10_26_26
# 3            PIK3CA_102_113
# 4            PIK3CA_541_542
# 5            PIK3CA_545_546
# 6          PIK3CA_1046_1047
# 7           ZKSCAN1_270_270
# 8            PIK3R1_566_578
# 9            ZNF195_109_111
# 10           PIK3CA_345_345
# 11             TP53_191_199
# 12             TP53_173_177
# 13             TP53_236_258
# 14           MTMR12_520_521
# 15           PIK3CA_418_420
# 16             PTEN_317_318
# 17         NOTCH2_2297_2303
# 18             TP53_211_218
# 19             TP53_noClust
# 20           PIK3CA_noClust
# 21            MAML3_noClust
# 22             PTEN_noClust
# 23           NOTCH2_noClust
# 24           CDKN2A_noClust
# 25            FBXW7_noClust
# 26              RB1_noClust
# 27           ZNF195_noClust
# 28           PIK3R1_noClust
# 29         C6orf118_noClust
# 30            STAB2_noClust
# 31            BRCA1_noClust
# 32           MGAT5B_noClust
# 33            MYL10_noClust
# 34           NUP153_noClust
# 35            LZTR1_noClust
# 36           MTMR12_noClust
# 37          ZKSCAN1_noClust
# 38             COIL_noClust
# 39              NBN_noClust
# 40            ATG4C_noClust
# 41            RAB42_noClust

# %% [markdown]
# ### Rows of the occurence matrix: Patient IDs

# %%
# Create the rows for the occurrence matrix
# NOTE: consider directly the mutation dataset that is the result of the intersection between the significant mutations from MutSig and the total ductal dataset
# There are not the total ductal patients (1551) but just 1462, because not all the patients have mutations on the significant genes 
unique_patientIDs_with_sign_mut = significant_mutations_TNandNONTN_AND_total_ductal_onlyHugo_Q1.PATIENT_ID.unique()
unique_patientIDs_with_sign_mut
# Out:
# array(['brca_smc_2018_BB01_002', 'brca_smc_2018_BB01_004',
#        'brca_smc_2018_BB01_005', ..., 'MBCProject_rYSXcxcV',
#        'MBCProject_rvULI3TV', 'MBCProject_xBfJfri9'], dtype=object)

# %%
len(unique_patientIDs_with_sign_mut)
# Out:
# 1058

# %% [markdown]
# ### Creation zeros matrix

# %%
def Matrice_zeri (columns, rows):
    df = pd.DataFrame(index=rows, columns=columns)
    df = df.fillna(0)
    return(df)

# %%
matrix_zeros_TNandNONTN_q1_onlyHugo = Matrice_zeri(columns_occ_matrix_TNandNONTNgenes_q1_onlyHugo, unique_patientIDs_with_sign_mut)
matrix_zeros_TNandNONTN_q1_onlyHugo
# Out:
#                         TP53_270_282  MAML3_503_503  MYL10_26_26  \
# brca_smc_2018_BB01_002             0              0            0
# brca_smc_2018_BB01_004             0              0            0
# brca_smc_2018_BB01_005             0              0            0
# brca_smc_2018_BB01_008             0              0            0
# brca_smc_2018_BB01_010             0              0            0
# ...                              ...            ...          ...
# MBCProject_pyhbI1H5                0              0            0
# MBCProject_rJHBiKTl                0              0            0
# MBCProject_rYSXcxcV                0              0            0
# MBCProject_rvULI3TV                0              0            0
# MBCProject_xBfJfri9                0              0            0
#
#                         PIK3CA_102_113  PIK3CA_541_542  PIK3CA_545_546  \
# brca_smc_2018_BB01_002               0               0               0
# brca_smc_2018_BB01_004               0               0               0
# brca_smc_2018_BB01_005               0               0               0
# brca_smc_2018_BB01_008               0               0               0
# brca_smc_2018_BB01_010               0               0               0
# ...                                ...             ...             ...
# MBCProject_pyhbI1H5                  0               0               0
# MBCProject_rJHBiKTl                  0               0               0
# MBCProject_rYSXcxcV                  0               0               0
# MBCProject_rvULI3TV                  0               0               0
# MBCProject_xBfJfri9                  0               0               0
#
#                         PIK3CA_1046_1047  ZKSCAN1_270_270  PIK3R1_566_578  \
# brca_smc_2018_BB01_002                 0                0               0
# brca_smc_2018_BB01_004                 0                0               0
# brca_smc_2018_BB01_005                 0                0               0
# brca_smc_2018_BB01_008                 0                0               0
# brca_smc_2018_BB01_010                 0                0               0
# ...                                  ...              ...             ...
# MBCProject_pyhbI1H5                    0                0               0
# MBCProject_rJHBiKTl                    0                0               0
# MBCProject_rYSXcxcV                    0                0               0
# MBCProject_rvULI3TV                    0                0               0
# MBCProject_xBfJfri9                    0                0               0
#
#                         ZNF195_109_111  ...  MGAT5B_noClust  MYL10_noClust  \
# brca_smc_2018_BB01_002               0  ...               0              0
# brca_smc_2018_BB01_004               0  ...               0              0
# brca_smc_2018_BB01_005               0  ...               0              0
# brca_smc_2018_BB01_008               0  ...               0              0
# brca_smc_2018_BB01_010               0  ...               0              0
# ...                                ...  ...             ...            ...
# MBCProject_pyhbI1H5                  0  ...               0              0
# MBCProject_rJHBiKTl                  0  ...               0              0
# MBCProject_rYSXcxcV                  0  ...               0              0
# MBCProject_rvULI3TV                  0  ...               0              0
# MBCProject_xBfJfri9                  0  ...               0              0
#
#                         NUP153_noClust  LZTR1_noClust  MTMR12_noClust  \
# brca_smc_2018_BB01_002               0              0               0
# brca_smc_2018_BB01_004               0              0               0
# brca_smc_2018_BB01_005               0              0               0
# brca_smc_2018_BB01_008               0              0               0
# brca_smc_2018_BB01_010               0              0               0
# ...                                ...            ...             ...
# MBCProject_pyhbI1H5                  0              0               0
# MBCProject_rJHBiKTl                  0              0               0
# MBCProject_rYSXcxcV                  0              0               0
# MBCProject_rvULI3TV                  0              0               0
# MBCProject_xBfJfri9                  0              0               0
#
#                         ZKSCAN1_noClust  COIL_noClust  NBN_noClust  \
# brca_smc_2018_BB01_002                0             0            0
# brca_smc_2018_BB01_004                0             0            0
# brca_smc_2018_BB01_005                0             0            0
# brca_smc_2018_BB01_008                0             0            0
# brca_smc_2018_BB01_010                0             0            0
# ...                                 ...           ...          ...
# MBCProject_pyhbI1H5                   0             0            0
# MBCProject_rJHBiKTl                   0             0            0
# MBCProject_rYSXcxcV                   0             0            0
# MBCProject_rvULI3TV                   0             0            0
# MBCProject_xBfJfri9                   0             0            0
#
#                         ATG4C_noClust  RAB42_noClust
# brca_smc_2018_BB01_002              0              0
# brca_smc_2018_BB01_004              0              0
# brca_smc_2018_BB01_005              0              0
# brca_smc_2018_BB01_008              0              0
# brca_smc_2018_BB01_010              0              0
# ...                               ...            ...
# MBCProject_pyhbI1H5                 0              0
# MBCProject_rJHBiKTl                 0              0
# MBCProject_rYSXcxcV                 0              0
# MBCProject_rvULI3TV                 0              0
# MBCProject_xBfJfri9                 0              0
#
# [1058 rows x 42 columns]

# %% [markdown]
# The occurence matrix has 1058 rows (patients) and 42 columns (gene clust and noClust).
#
# **NOTE:** 19 genes form clusters (the start and end positions of the clusters are indicated).

# %% [markdown]
# ### Fill the matrix with values

# %%
freq_cluster_q1_TNandNONTN_onlyHugo.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x000001A62CCCD4A0>

# %%
def Riempimento_matrice(df_sign_mutations, matrix, freq_cluster):
    for index_mut, row_mut in df_sign_mutations.iterrows():
        found = False
        gene = row_mut.at['Hugo_Symbol']
        #consequence = row_mut.at['Variant_Classification']
        patient = row_mut.at['PATIENT_ID']
        position_start = row_mut.at['Protein_position_start']
        position_end = row_mut.at['Protein_position_end']
        
        for index_cluster, row_cluster in freq_cluster.iterrows():
            if (gene == row_cluster['Gene']) and (
                ((position_start >= row_cluster['Start']) and (position_start <= row_cluster['End'])) or 
                ((position_end >= row_cluster['Start']) and (position_end <= row_cluster['End']))
            ):
                matrix.at[patient, (gene + '_'+ str(row_cluster['Start']) + '_' + str(row_cluster['End']))] += 1
                found = True
                break
                
        if not found:
            matrix.at[patient, gene + '_noClust'] += 1
    
    return matrix

# %%
df_occurrence_matrix_TNandNONTNrelgenes_q1_onlyHugo = Riempimento_matrice(significant_mutations_TNandNONTN_AND_total_ductal_onlyHugo_Q1, matrix_zeros_TNandNONTN_q1_onlyHugo, freq_cluster_q1_TNandNONTN_onlyHugo)
df_occurrence_matrix_TNandNONTNrelgenes_q1_onlyHugo
# Out:
#                         TP53_270_282  MAML3_503_503  MYL10_26_26  \
# brca_smc_2018_BB01_002             0              0            0
# brca_smc_2018_BB01_004             1              1            0
# brca_smc_2018_BB01_005             0              0            0
# brca_smc_2018_BB01_008             0              0            0
# brca_smc_2018_BB01_010             0              0            0
# ...                              ...            ...          ...
# MBCProject_pyhbI1H5                0              0            0
# MBCProject_rJHBiKTl                0              0            0
# MBCProject_rYSXcxcV                0              0            0
# MBCProject_rvULI3TV                0              0            0
# MBCProject_xBfJfri9                0              0            0
#
#                         PIK3CA_102_113  PIK3CA_541_542  PIK3CA_545_546  \
# brca_smc_2018_BB01_002               0               0               0
# brca_smc_2018_BB01_004               0               0               0
# brca_smc_2018_BB01_005               0               0               0
# brca_smc_2018_BB01_008               0               0               0
# brca_smc_2018_BB01_010               0               0               0
# ...                                ...             ...             ...
# MBCProject_pyhbI1H5                  0               0               0
# MBCProject_rJHBiKTl                  0               0               0
# MBCProject_rYSXcxcV                  0               0               0
# MBCProject_rvULI3TV                  0               0               0
# MBCProject_xBfJfri9                  0               0               0
#
#                         PIK3CA_1046_1047  ZKSCAN1_270_270  PIK3R1_566_578  \
# brca_smc_2018_BB01_002                 0                0               0
# brca_smc_2018_BB01_004                 0                0               0
# brca_smc_2018_BB01_005                 1                0               0
# brca_smc_2018_BB01_008                 0                0               0
# brca_smc_2018_BB01_010                 0                0               0
# ...                                  ...              ...             ...
# MBCProject_pyhbI1H5                    0                0               0
# MBCProject_rJHBiKTl                    0                0               0
# MBCProject_rYSXcxcV                    0                0               0
# MBCProject_rvULI3TV                    0                1               0
# MBCProject_xBfJfri9                    0                0               0
#
#                         ZNF195_109_111  ...  MGAT5B_noClust  MYL10_noClust  \
# brca_smc_2018_BB01_002               0  ...               0              0
# brca_smc_2018_BB01_004               0  ...               0              0
# brca_smc_2018_BB01_005               0  ...               0              0
# brca_smc_2018_BB01_008               0  ...               0              0
# brca_smc_2018_BB01_010               0  ...               0              0
# ...                                ...  ...             ...            ...
# MBCProject_pyhbI1H5                  0  ...               0              0
# MBCProject_rJHBiKTl                  0  ...               0              0
# MBCProject_rYSXcxcV                  0  ...               0              0
# MBCProject_rvULI3TV                  0  ...               0              0
# MBCProject_xBfJfri9                  0  ...               0              0
#
#                         NUP153_noClust  LZTR1_noClust  MTMR12_noClust  \
# brca_smc_2018_BB01_002               0              0               0
# brca_smc_2018_BB01_004               0              0               0
# brca_smc_2018_BB01_005               0              0               0
# brca_smc_2018_BB01_008               0              0               0
# brca_smc_2018_BB01_010               0              0               0
# ...                                ...            ...             ...
# MBCProject_pyhbI1H5                  0              0               0
# MBCProject_rJHBiKTl                  0              0               0
# MBCProject_rYSXcxcV                  0              0               0
# MBCProject_rvULI3TV                  0              0               0
# MBCProject_xBfJfri9                  0              0               0
#
#                         ZKSCAN1_noClust  COIL_noClust  NBN_noClust  \
# brca_smc_2018_BB01_002                0             0            0
# brca_smc_2018_BB01_004                0             0            0
# brca_smc_2018_BB01_005                0             0            0
# brca_smc_2018_BB01_008                0             0            0
# brca_smc_2018_BB01_010                0             0            0
# ...                                 ...           ...          ...
# MBCProject_pyhbI1H5                   0             0            0
# MBCProject_rJHBiKTl                   0             0            0
# MBCProject_rYSXcxcV                   0             0            0
# MBCProject_rvULI3TV                   0             0            0
# MBCProject_xBfJfri9                   0             0            0
#
#                         ATG4C_noClust  RAB42_noClust
# brca_smc_2018_BB01_002              0              0
# brca_smc_2018_BB01_004              0              0
# brca_smc_2018_BB01_005              0              0
# brca_smc_2018_BB01_008              0              0
# brca_smc_2018_BB01_010              0              0
# ...                               ...            ...
# MBCProject_pyhbI1H5                 0              0
# MBCProject_rJHBiKTl                 0              0
# MBCProject_rYSXcxcV                 0              0
# MBCProject_rvULI3TV                 0              0
# MBCProject_xBfJfri9                 0              0
#
# [1058 rows x 42 columns]

# %%
# count the total number of values in the matrix, i.e., the total number of mutations
df_occurrence_matrix_TNandNONTNrelgenes_q1_onlyHugo.sum().sum()
# Out:
# 1660

# %%
# count the number of rows containing all zero values 
df_occurrence_matrix_TNandNONTNrelgenes_q1_onlyHugo[(df_occurrence_matrix_TNandNONTNrelgenes_q1_onlyHugo == 0).all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [TP53_270_282, MAML3_503_503, MYL10_26_26, PIK3CA_102_113, PIK3CA_541_542, PIK3CA_545_546, PIK3CA_1046_1047, ZKSCAN1_270_270, PIK3R1_566_578, ZNF195_109_111, PIK3CA_345_345, TP53_191_199, TP53_173_177, TP53_236_258, MTMR12_520_521, PIK3CA_418_420, PTEN_317_318, NOTCH2_2297_2303, TP53_211_218, TP53_noClust, PIK3CA_noClust, MAML3_noClust, PTEN_noClust, NOTCH2_noClust, CDKN2A_noClust, FBXW7_noClust, RB1_noClust, ZNF195_noClust, PIK3R1_noClust, C6orf118_noClust, STAB2_noClust, BRCA1_noClust, MGAT5B_noClust, MYL10_noClust, NUP153_noClust, LZTR1_noClust, MTMR12_noClust, ZKSCAN1_noClust, COIL_noClust, NBN_noClust, ATG4C_noClust, RAB42_noClust]
# Index: []
#
# [0 rows x 42 columns]

# %% [markdown]
# There aren't patients with no mutations in the significant genes.

# %%
# number of columns containing all zero values 
(df_occurrence_matrix_TNandNONTNrelgenes_q1_onlyHugo == 0).all().sum()
# Out:
# 0

# %%
# sum the values for each row (patients): mutations for each patient
mutations_for_each_patient = df_occurrence_matrix_TNandNONTNrelgenes_q1_onlyHugo.sum(axis=1).to_frame()
mutations_for_each_patient.rename(columns={0: "Mutation count for each patient"}, inplace=True)
mutations_for_each_patient
# Out:
#                         Mutation count for each patient
# brca_smc_2018_BB01_002                                2
# brca_smc_2018_BB01_004                                2
# brca_smc_2018_BB01_005                                2
# brca_smc_2018_BB01_008                                1
# brca_smc_2018_BB01_010                                2
# ...                                                 ...
# MBCProject_pyhbI1H5                                   3
# MBCProject_rJHBiKTl                                   1
# MBCProject_rYSXcxcV                                   1
# MBCProject_rvULI3TV                                   1
# MBCProject_xBfJfri9                                   1
#
# [1058 rows x 1 columns]

# %%
mutations_for_each_patient.sum()
# Out:
# Mutation count for each patient    1660
# dtype: int64

# %% [markdown]
# ### Label the TN patients with 1 and the NON TN patients with 0

# %%
# Load the total TN mutation dataset and select the TN patients 
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi")
data_mutation_ductal_total_TN = pd.read_csv('mutation_table_ALL_DATASETS_ductal_TN_nohypo_nohyper.csv', sep=None, engine='python')
data_mutation_ductal_total_TN
# Out:
#                    PATIENT_ID                    Tumor_Sample_Barcode  \
# 0      brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 1      brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 2      brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 3      brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 4      brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# ...                       ...                                     ...
# 31982     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 31983     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 31984     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 31985     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 31986     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
#
#       Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0         TMEM131          2      98460725.0    98460725.0
# 1          DNAAF1         16      84188289.0    84188289.0
# 2            TP53         17       7577117.0     7577117.0
# 3            MATK         19       3778305.0     3778305.0
# 4             BAX         19      49459542.0    49459542.0
# ...           ...        ...             ...           ...
# 31982        VAV1         19       6836477.0     6836477.0
# 31983         ADA         20      43251667.0    43251667.0
# 31984       ABCG1         21      43711661.0    43711661.0
# 31985       TRPM2         21      45784140.0    45784140.0
# 31986      FBXO11          2      48066626.0    48066626.0
#
#       Variant_Classification Variant_Type Reference_Allele Tumor_Seq_Allele1  \
# 0                Splice_Site          SNP                C                 C
# 1          Missense_Mutation          SNP                C                 C
# 2          Missense_Mutation          SNP                A                 A
# 3          Missense_Mutation          SNP                C                 C
# 4          Nonsense_Mutation          SNP                G                 G
# ...                      ...          ...              ...               ...
# 31982                 Silent          SNP                C                 C
# 31983      Missense_Mutation          SNP                G                 G
# 31984                 Silent          SNP                G                 G
# 31985      Missense_Mutation          SNP                C                 C
# 31986        Frame_Shift_Del          DEL                G                 G
#
#       Tumor_Seq_Allele2                         HGVSc    HGVSp_Short  \
# 0                     T  ENST00000186436.5:c.484-1G>A  p.X162_splice
# 1                     T    ENST00000378553.5:c.460C>T        p.R154C
# 2                     C    ENST00000269305.4:c.821T>G        p.V274G
# 3                     A   ENST00000395045.2:c.1403G>T        p.R468L
# 4                     A    ENST00000293288.8:c.321G>A        p.W107*
# ...                 ...                           ...            ...
# 31982                 T   ENST00000602142.1:c.1812C>T        p.Y604=
# 31983                 A    ENST00000372874.4:c.659C>T        p.S220L
# 31984                 A   ENST00000361802.2:c.1584G>A        p.P528=
# 31985                 T    ENST00000300482.5:c.398C>T        p.T133M
# 31986                 -    ENST00000403359.3:c.374del        p.S125*
#
#       Protein_position    Transcript_ID  Gene_length ENSP
# 0                162.0  ENST00000186436       239590  NaN
# 1                154.0  ENST00000378553        33509  NaN
# 2                274.0  ENST00000269305        25760  NaN
# 3                468.0  ENST00000395045        24157  NaN
# 4                107.0  ENST00000293288         6984  NaN
# ...                ...              ...          ...  ...
# 31982            604.0  ENST00000602142        84653  NaN
# 31983            220.0  ENST00000372874        32712  NaN
# 31984            528.0  ENST00000361802        97556  NaN
# 31985            133.0  ENST00000300482        92919  NaN
# 31986            125.0  ENST00000403359       116478  NaN
#
# [31987 rows x 17 columns]

# %%
data_mutation_ductal_total_TN.PATIENT_ID.nunique()
# Out:
# 293

# %%
unique_patientsID_TN = data_mutation_ductal_total_TN['PATIENT_ID'].unique()
len(unique_patientsID_TN)
# Out:
# 293

# %%
# Load the total NON TN mutation dataset and select the NON TN patients 
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi")
data_mutation_ductal_total_NON_TN = pd.read_csv('mutation_table_ALL_DATASETS_ductal_NONTN_nohypo_nohyper.csv', sep=None, engine='python') 
data_mutation_ductal_total_NON_TN
# Out:
#                     PATIENT_ID                    Tumor_Sample_Barcode  \
# 0       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 1       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 2       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 3       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 4       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# ...                        ...                                     ...
# 107378     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 107379     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 107380     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 107381     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 107382     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#        Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0            KALRN          3     123988087.0   123988087.0
# 1             ANK2          4     114195720.0   114195720.0
# 2           SORBS2          4     186539742.0   186539742.0
# 3          PCDHA11          5     140250828.0   140250828.0
# 4           WRNIP1          6       2766210.0     2766210.0
# ...            ...        ...             ...           ...
# 107378       NRSN2         20        333991.0      333991.0
# 107379      CHRNA4         20      61986887.0    61986887.0
# 107380      CHRNA4         20      61987386.0    61987386.0
# 107381       KCNQ2         20      62078103.0    62078103.0
# 107382        XBP1         22      29191563.0    29191563.0
#
#        Variant_Classification Variant_Type Reference_Allele Tumor_Seq_Allele1  \
# 0           Missense_Mutation          SNP                G                 G
# 1           Missense_Mutation          SNP                C                 C
# 2           Missense_Mutation          SNP                G                 G
# 3           Missense_Mutation          SNP                C                 C
# 4           Missense_Mutation          SNP                C                 C
# ...                       ...          ...              ...               ...
# 107378                 Silent          SNP                C                 C
# 107379                 Intron          SNP                G                 G
# 107380                 Silent          SNP                G                 G
# 107381                 Silent          SNP                G                 G
# 107382      Nonsense_Mutation          SNP                G                 G
#
#        Tumor_Seq_Allele2                           HGVSc HGVSp_Short  \
# 0                      C      ENST00000240874.3:c.948G>C     p.E316D
# 1                      T     ENST00000357077.4:c.1598C>T     p.P533L
# 2                      C     ENST00000355634.5:c.2936C>G     p.S979C
# 3                      G     ENST00000398640.2:c.2140C>G     p.L714V
# 4                      A      ENST00000380773.4:c.354C>A     p.S118R
# ...                  ...                             ...         ...
# 107378                 T      ENST00000382285.2:c.327C>T     p.N109=
# 107379                 C  ENST00000370263.4:c.383+440C>G     p.*128*
# 107380                 A      ENST00000370263.4:c.324C>T     p.V108=
# 107381                 A      ENST00000359125.2:c.384C>T     p.I128=
# 107382                 A      ENST00000216037.6:c.757C>T     p.Q253*
#
#        Protein_position    Transcript_ID  Gene_length ENSP
# 0                 316.0  ENST00000240874       646303  NaN
# 1                 533.0  ENST00000357077       565632  NaN
# 2                 979.0  ENST00000355634       371209  NaN
# 3                 714.0  ENST00000398640       143241  NaN
# 4                 118.0  ENST00000380773        21539  NaN
# ...                 ...              ...          ...  ...
# 107378            109.0  ENST00000382285        12879  NaN
# 107379              NaN  ENST00000370263        34334  NaN
# 107380            108.0  ENST00000370263        34334  NaN
# 107381            128.0  ENST00000359125        66452  NaN
# 107382            253.0  ENST00000216037         6043  NaN
#
# [107383 rows x 17 columns]

# %%
data_mutation_ductal_total_NON_TN.PATIENT_ID.nunique()
# Out:
# 1234

# %%
unique_patientsID_NONTN = data_mutation_ductal_total_NON_TN['PATIENT_ID'].unique()
unique_patientsID_NONTN
# Out:
# array(['brca_smc_2018_BB01_002', 'brca_smc_2018_BB01_005',
#        'brca_smc_2018_BB01_006', ..., 'MBCProject_yZSnSluK',
#        'MBCProject_ygcMFgCR', 'MBCProject_zyt5TKFB'], dtype=object)

# %%
len(unique_patientsID_NONTN)
# Out:
# 1234

# %%
unique_patientIDs_with_sign_mut
# Out:
# array(['brca_smc_2018_BB01_002', 'brca_smc_2018_BB01_004',
#        'brca_smc_2018_BB01_005', ..., 'MBCProject_rYSXcxcV',
#        'MBCProject_rvULI3TV', 'MBCProject_xBfJfri9'], dtype=object)

# %%
len(unique_patientIDs_with_sign_mut)
# Out:
# 1058

# %%
# create the column with the target for each patient 
def target(indexes_patientID):
    TN_patientIDs = unique_patientsID_TN
    NON_TN_patientsIDs = unique_patientsID_NONTN
    
    target = pd.DataFrame(index=indexes_patientID, columns=['Target'])
    target['Target'] = 0  # Initialize all labels to 0
    
    for i in indexes_patientID:
        if i in TN_patientIDs:
            target.loc[i, 'Target'] = 1
    
    return (target)

# %%
target_relgenes_TNandNONTN_q1 = target(unique_patientIDs_with_sign_mut)
target_relgenes_TNandNONTN_q1
# Out:
#                         Target
# brca_smc_2018_BB01_002       0
# brca_smc_2018_BB01_004       1
# brca_smc_2018_BB01_005       0
# brca_smc_2018_BB01_008       0
# brca_smc_2018_BB01_010       0
# ...                        ...
# MBCProject_pyhbI1H5          0
# MBCProject_rJHBiKTl          1
# MBCProject_rYSXcxcV          0
# MBCProject_rvULI3TV          0
# MBCProject_xBfJfri9          0
#
# [1058 rows x 1 columns]

# %%
# add the label column to the occurrence matrix 
Matrix_TNandNONTNrelgenes_q1_withLabels_onlyHugo = df_occurrence_matrix_TNandNONTNrelgenes_q1_onlyHugo.assign(Target=target_relgenes_TNandNONTN_q1)
Matrix_TNandNONTNrelgenes_q1_withLabels_onlyHugo
# Out:
#                         TP53_270_282  MAML3_503_503  MYL10_26_26  \
# brca_smc_2018_BB01_002             0              0            0
# brca_smc_2018_BB01_004             1              1            0
# brca_smc_2018_BB01_005             0              0            0
# brca_smc_2018_BB01_008             0              0            0
# brca_smc_2018_BB01_010             0              0            0
# ...                              ...            ...          ...
# MBCProject_pyhbI1H5                0              0            0
# MBCProject_rJHBiKTl                0              0            0
# MBCProject_rYSXcxcV                0              0            0
# MBCProject_rvULI3TV                0              0            0
# MBCProject_xBfJfri9                0              0            0
#
#                         PIK3CA_102_113  PIK3CA_541_542  PIK3CA_545_546  \
# brca_smc_2018_BB01_002               0               0               0
# brca_smc_2018_BB01_004               0               0               0
# brca_smc_2018_BB01_005               0               0               0
# brca_smc_2018_BB01_008               0               0               0
# brca_smc_2018_BB01_010               0               0               0
# ...                                ...             ...             ...
# MBCProject_pyhbI1H5                  0               0               0
# MBCProject_rJHBiKTl                  0               0               0
# MBCProject_rYSXcxcV                  0               0               0
# MBCProject_rvULI3TV                  0               0               0
# MBCProject_xBfJfri9                  0               0               0
#
#                         PIK3CA_1046_1047  ZKSCAN1_270_270  PIK3R1_566_578  \
# brca_smc_2018_BB01_002                 0                0               0
# brca_smc_2018_BB01_004                 0                0               0
# brca_smc_2018_BB01_005                 1                0               0
# brca_smc_2018_BB01_008                 0                0               0
# brca_smc_2018_BB01_010                 0                0               0
# ...                                  ...              ...             ...
# MBCProject_pyhbI1H5                    0                0               0
# MBCProject_rJHBiKTl                    0                0               0
# MBCProject_rYSXcxcV                    0                0               0
# MBCProject_rvULI3TV                    0                1               0
# MBCProject_xBfJfri9                    0                0               0
#
#                         ZNF195_109_111  ...  MYL10_noClust  NUP153_noClust  \
# brca_smc_2018_BB01_002               0  ...              0               0
# brca_smc_2018_BB01_004               0  ...              0               0
# brca_smc_2018_BB01_005               0  ...              0               0
# brca_smc_2018_BB01_008               0  ...              0               0
# brca_smc_2018_BB01_010               0  ...              0               0
# ...                                ...  ...            ...             ...
# MBCProject_pyhbI1H5                  0  ...              0               0
# MBCProject_rJHBiKTl                  0  ...              0               0
# MBCProject_rYSXcxcV                  0  ...              0               0
# MBCProject_rvULI3TV                  0  ...              0               0
# MBCProject_xBfJfri9                  0  ...              0               0
#
#                         LZTR1_noClust  MTMR12_noClust  ZKSCAN1_noClust  \
# brca_smc_2018_BB01_002              0               0                0
# brca_smc_2018_BB01_004              0               0                0
# brca_smc_2018_BB01_005              0               0                0
# brca_smc_2018_BB01_008              0               0                0
# brca_smc_2018_BB01_010              0               0                0
# ...                               ...             ...              ...
# MBCProject_pyhbI1H5                 0               0                0
# MBCProject_rJHBiKTl                 0               0                0
# MBCProject_rYSXcxcV                 0               0                0
# MBCProject_rvULI3TV                 0               0                0
# MBCProject_xBfJfri9                 0               0                0
#
#                         COIL_noClust  NBN_noClust  ATG4C_noClust  \
# brca_smc_2018_BB01_002             0            0              0
# brca_smc_2018_BB01_004             0            0              0
# brca_smc_2018_BB01_005             0            0              0
# brca_smc_2018_BB01_008             0            0              0
# brca_smc_2018_BB01_010             0            0              0
# ...                              ...          ...            ...
# MBCProject_pyhbI1H5                0            0              0
# MBCProject_rJHBiKTl                0            0              0
# MBCProject_rYSXcxcV                0            0              0
# MBCProject_rvULI3TV                0            0              0
# MBCProject_xBfJfri9                0            0              0
#
#                         RAB42_noClust  Target
# brca_smc_2018_BB01_002              0       0
# brca_smc_2018_BB01_004              0       1
# brca_smc_2018_BB01_005              0       0
# brca_smc_2018_BB01_008              0       0
# brca_smc_2018_BB01_010              0       0
# ...                               ...     ...
# MBCProject_pyhbI1H5                 0       0
# MBCProject_rJHBiKTl                 0       1
# MBCProject_rYSXcxcV                 0       0
# MBCProject_rvULI3TV                 0       0
# MBCProject_xBfJfri9                 0       0
#
# [1058 rows x 43 columns]

# %% [markdown]
# **NOTE:**
# - Label = 1 : TN patient
# - Label = 0 : NON TN patient

# %%
# sum the values for each column (mutations)
mutations_sum = Matrix_TNandNONTNrelgenes_q1_withLabels_onlyHugo.sum().to_frame()
mutations_sum.rename(columns={0: "Mutation count"}, inplace=True)
mutations_sum
# Out:
#                   Mutation count
# TP53_270_282                  78
# MAML3_503_503                  7
# MYL10_26_26                    7
# PIK3CA_102_113                26
# PIK3CA_541_542                56
# PIK3CA_545_546                98
# PIK3CA_1046_1047             198
# ZKSCAN1_270_270               16
# PIK3R1_566_578                12
# ZNF195_109_111                 8
# PIK3CA_345_345                31
# TP53_191_199                  65
# TP53_173_177                  47
# TP53_236_258                  94
# MTMR12_520_521                 5
# PIK3CA_418_420                12
# PTEN_317_318                   7
# NOTCH2_2297_2303               5
# TP53_211_218                  32
# TP53_noClust                 331
# PIK3CA_noClust                94
# MAML3_noClust                 12
# PTEN_noClust                  72
# NOTCH2_noClust                32
# CDKN2A_noClust                12
# FBXW7_noClust                 25
# RB1_noClust                   38
# ZNF195_noClust                 8
# PIK3R1_noClust                26
# C6orf118_noClust              13
# STAB2_noClust                 41
# BRCA1_noClust                 42
# MGAT5B_noClust                20
# MYL10_noClust                  5
# NUP153_noClust                23
# LZTR1_noClust                 13
# MTMR12_noClust                 9
# ZKSCAN1_noClust               13
# COIL_noClust                   8
# NBN_noClust                    8
# ATG4C_noClust                  9
# RAB42_noClust                  2
# Target                       272

# %% [markdown]
# NOTE:
# - 272 patients are Triple-Negative
# - 786 patients are NO Triple-Negative

# %%
# save the occurrence matrix 
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Occurrence matrix data_definitivo")
Matrix_TNandNONTNrelgenes_q1_withLabels_onlyHugo.to_csv('Occurrence_Matrix_onlyTNrelgenes_q1_withLabels_ONLYHUGO_definitivo.csv', index=True, sep='\t')
