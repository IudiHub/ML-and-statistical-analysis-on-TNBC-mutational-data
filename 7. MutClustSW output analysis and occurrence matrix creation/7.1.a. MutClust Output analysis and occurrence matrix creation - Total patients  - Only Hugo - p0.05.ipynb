# %% [markdown]
# # MutClust Output analysis and occurrence matrix creation - Total patients - Only Hugo - p-value < 0.05

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import os
import sklearn

# %%
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/MutClust_output_definitivo")

# %% [markdown]
# REMEMBER:
# - from MutSig2CV I selected the genes with p-value < 0.05
# - in input to MutClust I just gave the Hugo symbols without the variant classifications

# %% [markdown]
# ### Genes significantly mutated only both in TN and non TN dataset (pval < 0.05)

# %%
# I run MutClust on the TOTAL DATASET intersected with the significant genes from MutSig2CV
df_mutclust_100_p005_TNandNONTN_onlyHugo = pd.read_csv('Output_onlyHugo_TNandNONTN_p005_definitivo.txt', delimiter='\t', engine='python')
df_mutclust_100_p005_TNandNONTN_onlyHugo
# Out:
#        Gene  Start  End  Scoresum Recursion  Mutation        NES    Pvalue
# 0      TP53    270  282  0.085953         Y        78  12.390603  0.000000
# 1      TP53    191  199  0.079947         Y        65  11.235052  0.000000
# 2      TP53    236  258  0.077052         Y        94  10.677970  0.000000
# 3      TP53    173  177  0.061644         Y        47   7.713317  0.000000
# 4      TP53    211  218  0.030277         Y        32   1.677717  0.089109
# ...     ...    ...  ...       ...       ...       ...        ...       ...
# 8134  PIAS2    391  391  0.089299         N         1  -1.885482  0.990099
# 8135  PIAS2    427  427  0.089299         N         1  -1.885482  0.990099
# 8136  PIAS2    481  481  0.089299         N         1  -1.885482  0.990099
# 8137  PIAS2    538  538  0.089299         N         1  -1.885482  0.990099
# 8138  PIAS2    602  602  0.089299         N         1  -1.885482  0.990099
#
# [8139 rows x 8 columns]

# %%
# sort the dataframe by ascending order of Pvalue (from the most significant mutation to the least significant)
df_mutclust_100_p005_TNandNONTN_onlyHugo = df_mutclust_100_p005_TNandNONTN_onlyHugo.sort_values('Pvalue')
df_mutclust_100_p005_TNandNONTN_onlyHugo
# Out:
#         Gene  Start   End  Scoresum Recursion  Mutation        NES    Pvalue
# 0       TP53    270   282  0.085953         Y        78  12.390603  0.000000
# 1179   GATA3    406   408  0.150000         Y        29  17.358447  0.000000
# 84     MAML3    503   503  0.388010         Y         7   7.172536  0.000000
# 2288    AKT1     17    17  0.801838         N        41  46.515847  0.000000
# 6053   MYL10     26    26  0.631939         Y         7   6.857645  0.000000
# ...      ...    ...   ...       ...       ...       ...        ...       ...
# 2819  CDKN2A     69    69  0.076923         N         1  -2.231282  0.990099
# 2818  CDKN2A     50    50  0.076923         N         1  -2.231282  0.990099
# 2817  CDKN2A     36    36  0.076923         N         1  -2.231282  0.990099
# 2781  CREBBP   1593  1593  0.038052         N         1  -2.337278  0.990099
# 8138   PIAS2    602   602  0.089299         N         1  -1.885482  0.990099
#
# [8139 rows x 8 columns]

# %% [markdown]
# **Relevant_cluster** : creates a dictionary containing values from 0.01 to 1 (with an interval of 0.01), in which each value is associated to the number of genes with p-value lower than the value itself.

# %%
# define a function that gives in output the number of relevant clusters at different p-values
def Relevant_cluster (df_mutclust):
    n_relevant_clusters = {}   
    for i in np.arange(0.01, 1, 0.01):
        n_relevant_clusters[i]=len(df_mutclust[df_mutclust.Pvalue<i]) 
    return (n_relevant_clusters)

# %%
n_relevant_clusters_mutclust_100_p005_TNandNONTN_onlyHugo = Relevant_cluster(df_mutclust_100_p005_TNandNONTN_onlyHugo)
n_relevant_clusters_mutclust_100_p005_TNandNONTN_onlyHugo
# Out:
# {0.01: 36,
#  0.02: 37,
#  0.03: 47,
#  0.04: 51,
#  0.05: 54,
#  0.060000000000000005: 57,
#  0.06999999999999999: 60,
#  0.08: 63,
#  0.09: 66,
#  0.09999999999999999: 69,
#  0.11: 69,
#  0.12: 74,
#  0.13: 77,
#  0.14: 85,
#  0.15000000000000002: 88,
#  0.16: 93,
#  0.17: 95,
#  0.18000000000000002: 98,
#  0.19: 103,
#  0.2: 107,
#  0.21000000000000002: 113,
#  0.22: 113,
#  0.23: 116,
#  0.24000000000000002: 118,
#  0.25: 119,
#  0.26: 120,
#  0.27: 124,
#  0.28: 128,
#  0.29000000000000004: 132,
#  0.3: 135,
#  0.31: 137,
#  0.32: 140,
#  0.33: 143,
#  0.34: 145,
#  0.35000000000000003: 149,
#  0.36000000000000004: 151,
#  0.37: 155,
#  0.38: 159,
#  0.39: 161,
#  0.4: 164,
#  0.41000000000000003: 168,
#  0.42000000000000004: 168,
#  0.43: 172,
#  0.44: 172,
#  0.45: 174,
#  0.46: 175,
#  0.47000000000000003: 176,
#  0.48000000000000004: 179,
#  0.49: 184,
#  0.5: 184,
#  0.51: 186,
#  0.52: 187,
#  0.53: 189,
#  0.54: 194,
#  0.55: 197,
#  0.56: 199,
#  0.5700000000000001: 203,
#  0.5800000000000001: 207,
#  0.59: 213,
#  0.6: 221,
#  0.61: 227,
#  0.62: 232,
#  0.63: 239,
#  0.64: 242,
#  0.65: 249,
#  0.66: 258,
#  0.67: 271,
#  0.68: 281,
#  0.6900000000000001: 288,
#  0.7000000000000001: 294,
#  0.7100000000000001: 304,
#  0.72: 314,
#  0.73: 330,
#  0.74: 341,
#  0.75: 358,
#  0.76: 365,
#  0.77: 371,
#  0.78: 382,
#  0.79: 389,
#  0.8: 400,
#  0.81: 413,
#  0.8200000000000001: 427,
#  0.8300000000000001: 442,
#  0.8400000000000001: 452,
#  0.85: 462,
#  0.86: 477,
#  0.87: 494,
#  0.88: 510,
#  0.89: 527,
#  0.9: 546,
#  0.91: 565,
#  0.92: 581,
#  0.93: 602,
#  0.9400000000000001: 629,
#  0.9500000000000001: 654,
#  0.9600000000000001: 698,
#  0.97: 726,
#  0.98: 767,
#  0.99: 830}

# %%
# count how many clusters have p-value = 0 
len(df_mutclust_100_p005_TNandNONTN_onlyHugo.loc[df_mutclust_100_p005_TNandNONTN_onlyHugo['Pvalue'] == 0.000000])
# Out:
# 32

# %%
# convert the dictionary into a Dataframe
df_n_relevant_clusters_mutclust_100_p005_TNandNONTN_onlyHugo = pd.DataFrame.from_dict(n_relevant_clusters_mutclust_100_p005_TNandNONTN_onlyHugo, orient='index')
df_n_relevant_clusters_mutclust_100_p005_TNandNONTN_onlyHugo.rename(columns={0: "Significant clusters"}, inplace=True)
df_n_relevant_clusters_mutclust_100_p005_TNandNONTN_onlyHugo.reset_index(level=0, inplace=True)
df_n_relevant_clusters_mutclust_100_p005_TNandNONTN_onlyHugo.rename(columns={"index": "P-value"}, inplace=True)
df_n_relevant_clusters_mutclust_100_p005_TNandNONTN_onlyHugo
# Out:
#     P-value  Significant clusters
# 0      0.01                    36
# 1      0.02                    37
# 2      0.03                    47
# 3      0.04                    51
# 4      0.05                    54
# ..      ...                   ...
# 94     0.95                   654
# 95     0.96                   698
# 96     0.97                   726
# 97     0.98                   767
# 98     0.99                   830
#
# [99 rows x 2 columns]

# %% [markdown]
# ### Plot the number of significant clusters as the p-value varies
#
# Define a function to plot the number of significant clusters as the p-value varies.

# %%
def Grafico_Clusters_significativi_one_dataset(df_n_rel_clusters_mutclust, caso):
    casistica_titolo = 'Significant hotspots as the p-value varies - XXX'
    casistica_titolo = casistica_titolo.replace('XXX',caso)
    casistica_legenda = 'Significant hotspots determined by the XXX'
    casistica_legenda = casistica_legenda.replace('XXX', caso)
    
    df_n_rel_clusters_mutclust_copy = df_n_rel_clusters_mutclust.copy()
    df_n_rel_clusters_mutclust_copy = df_n_rel_clusters_mutclust_copy.set_index('P-value')
    
    plt.rcParams['figure.figsize'] = (10, 8)
    plt.plot(df_n_rel_clusters_mutclust_copy, label = casistica_legenda, color = 'red')
    plt.xlabel('P-value', fontsize=13)
    plt.ylabel('Number of significant hotspots', fontsize=13)
    plt.legend(loc='lower left', bbox_to_anchor=(0.0, -0.2), fontsize='large')
    plt.title(casistica_titolo,fontsize= 18)

# %%
Grafico_Clusters_significativi_one_dataset(df_n_relevant_clusters_mutclust_100_p005_TNandNONTN_onlyHugo, 'total genes from Triple-negative and Non Triple-negative patients')

# %% [markdown]
# ### Look at the clusters with a p-value < 0.05

# %% [markdown]
# **Freq_cluster**: this function takes as input the output of MutClust containing the clusters associated to a p-value and a specific p-value. The output is a subset of the original dataframe containing only the clusters with a p-value < seleceted p-value.

# %%
def Freq_cluster (df, val):
    freq_clusters = df[(df.Pvalue<val)]
    return (freq_clusters)

# %%
# Genes significantly mutated both in the Triple-Negative dataset and in the non Triple-Negative dataset (pval < 0.05)
freq_cluster_100_TNandNONTN_onlyHugo = Freq_cluster(df_mutclust_100_p005_TNandNONTN_onlyHugo, 0.05)
freq_cluster_100_TNandNONTN_onlyHugo = freq_cluster_100_TNandNONTN_onlyHugo.reset_index(drop=True)
freq_cluster_100_TNandNONTN_onlyHugo
# Out:
#         Gene  Start   End  Scoresum Recursion  Mutation         NES    Pvalue
# 0       TP53    270   282  0.085953         Y        78   12.390603  0.000000
# 1      GATA3    406   408  0.150000         Y        29   17.358447  0.000000
# 2      MAML3    503   503  0.388010         Y         7    7.172536  0.000000
# 3       AKT1     17    17  0.801838         N        41   46.515847  0.000000
# 4      MYL10     26    26  0.631939         Y         7    6.857645  0.000000
# 5     PIK3R1    566   578  0.327791         Y        12   10.541688  0.000000
# 6      NUP93     14    15  0.597558         Y         6    7.387957  0.000000
# 7    ZKSCAN1    270   270  0.569652         Y        16   15.939144  0.000000
# 8       CTCF    283   288  0.188882         Y         7    4.380968  0.000000
# 9      GATA3    308   335  0.248216         Y        64   31.756190  0.000000
# 10    PIK3CA   1046  1047  0.383341         Y       198  101.987609  0.000000
# 11    PIK3CA    541   542  0.107077         Y        56   25.581354  0.000000
# 12    PIK3CA    345   345  0.059375         N        31   12.388508  0.000000
# 13    PIK3CA    102   113  0.037354         Y        26    6.298105  0.000000
# 14     FOXA1    254   268  0.194442         Y        11    5.712539  0.000000
# 15    MTMR12    520   521  0.381938         Y         5    4.540252  0.000000
# 16      PRB2     81    81  0.442041         Y         8    7.871352  0.000000
# 17     ERBB2    767   777  0.285521         Y        12    8.670552  0.000000
# 18    ZNF208    548   549  0.224244         N         7    4.673289  0.000000
# 19    PIK3CA    545   546  0.188789         Y        98   48.180387  0.000000
# 20      KRAS     12    12  0.812891         N         9   10.904479  0.000000
# 21     GATA3    429   434  0.072973         Y        16    6.066876  0.000000
# 22      ESR1    537   538  0.355613         Y        14   11.034673  0.000000
# 23      TP53    191   199  0.079947         Y        65   11.235052  0.000000
# 24    ZNF195    109   111  0.493618         Y         8    7.387738  0.000000
# 25      TP53    236   258  0.077052         Y        94   10.677970  0.000000
# 26      TP53    173   177  0.061644         Y        47    7.713317  0.000000
# 27      TBX3    210   218  0.186766         Y         7    4.335766  0.000000
# 28    ZNF814    303   311  0.463812         Y        13   13.712803  0.000000
# 29   C8orf44     38    39  0.587421         Y         6    5.400021  0.000000
# 30      CHD9   2120  2120  0.188842         Y         7    4.557884  0.000000
# 31     SF3B1    700   700  0.713519         N        20   23.547668  0.000000
# 32    DNAH14    143   288  0.118630         Y         8    2.560046  0.009901
# 33   FAM208B    805   805  0.213874         Y         6    3.596274  0.009901
# 34     RBM27    719   719  0.356199         Y         5    3.338427  0.009901
# 35      ESR1    380   380  0.177807         Y         7    3.690278  0.009901
# 36     ABCG2     22    32  0.304117         Y         4    2.017633  0.019802
# 37      DAP3    331   331  0.305180         Y         4    2.454638  0.029703
# 38    ZNF716    294   294  0.247980         Y         4    2.117712  0.029703
# 39     DMXL2   1709  1740  0.165349         Y         5    1.974744  0.029703
# 40     ZNF19    280   280  0.452362         N         5    3.220024  0.029703
# 41    MAP4K3    395   415  0.357279         Y         4    2.361509  0.029703
# 42     FGFR2    549   549  0.248783         Y         4    2.317941  0.029703
# 43      USP8    523   523  0.293223         Y         5    2.474702  0.029703
# 44    OR4D10    175   183  0.318031         Y         4    2.264147  0.029703
# 45  TMPRSS13     77    83  0.378710         Y         4    2.474637  0.029703
# 46     RUNX1    122   123  0.162500         Y         6    2.420004  0.029703
# 47      DDX5    134   141  0.264366         Y         4    1.745621  0.039604
# 48     FHDC1     57    57  0.284839         Y         4    1.968941  0.039604
# 49      PTEN    317   318  0.088371         Y         7    1.999475  0.039604
# 50      RCC2    271   278  0.338545         Y         4    2.249734  0.039604
# 51    NUP153   1299  1299  0.173235         Y         4    1.807961  0.049505
# 52    NOTCH2   2297  2303  0.134416         Y         5    1.967820  0.049505
# 53   FAM193A   1170  1214  0.244127         Y         5    1.874261  0.049505

# %%
len(freq_cluster_100_TNandNONTN_onlyHugo)
# Out:
# 54

# %% [markdown]
# There are 54 significant clusters (p-value < 0.05) considering all the relevant genes in BOTH the Triple-negative dataset and the NON Triple-Negative dataset.

# %% [markdown]
# # Occurrence Matrix Creation

# %%
# load the mutation dataset resulting from the intersection between the significant TN and NON TN genes from MutSig and the total ductal dataset
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/MutClust_input_DEFINITIVO")
significant_mutations_TNandNONTN_AND_total_ductal_onlyHugo = pd.read_csv('data_mutation_SINIFICANTgenes_ONLYhugo_bothTNandNONTN_P005_definitivo.txt', sep=None, engine='python')
significant_mutations_TNandNONTN_AND_total_ductal_onlyHugo
# Out:
#                    PATIENT_ID                      Tumor_Sample_Barcode  \
# 0      brca_smc_2018_BB01_002                    brca_smc_2018_BB01_002
# 1      brca_smc_2018_BB01_002                    brca_smc_2018_BB01_002
# 2      brca_smc_2018_BB01_004                    brca_smc_2018_BB01_004
# 3      brca_smc_2018_BB01_004                    brca_smc_2018_BB01_004
# 4      brca_smc_2018_BB01_005                    brca_smc_2018_BB01_005
# ...                       ...                                       ...
# 15129     MBCProject_ygcMFgCR  RP-1156_MBCProject_ygcMFgCR_T1A_v1_Exome
# 15130     MBCProject_ygcMFgCR  RP-1156_MBCProject_ygcMFgCR_T1A_v1_Exome
# 15131     MBCProject_zyt5TKFB    MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 15132     MBCProject_zyt5TKFB    MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 15133     MBCProject_zyt5TKFB    MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#       Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0            TP53         17       7574003.0     7574003.0
# 1          PIK3CA          3     178952150.0   178952151.0
# 2            TP53         17       7577117.0     7577117.0
# 3           MAML3          4     140811082.0   140811083.0
# 4           SF3B4          1     149895518.0   149895518.0
# ...           ...        ...             ...           ...
# 15129       SOGA2         18       8824961.0     8824961.0
# 15130       GATA3         10       8111513.0     8111514.0
# 15131       EPAS1          2      46525087.0    46525087.0
# 15132       CLOCK          4      56315636.0    56315636.0
# 15133       HCFC2         12     104492158.0   104492158.0
#
#       Variant_Classification Variant_Type Reference_Allele Tumor_Seq_Allele1  \
# 0          Nonsense_Mutation          SNP                G                 G
# 1            Frame_Shift_Ins          INS                -                 -
# 2          Missense_Mutation          SNP                A                 A
# 3               In_Frame_Ins          INS                -                 -
# 4          Missense_Mutation          SNP                C                 C
# ...                      ...          ...              ...               ...
# 15129                 Silent          SNP                C                 C
# 15130        Frame_Shift_Ins          INS                -                 -
# 15131                 Intron          SNP                G                 G
# 15132      Missense_Mutation          SNP                G                 G
# 15133      Missense_Mutation          SNP                C                 C
#
#        ...                                 HGVSc     HGVSp_Short  \
# 0      ...           ENST00000269305.4:c.1024C>T         p.R342*
# 1      ...  ENST00000263967.3:c.3205_3206insTTTT    p.*1069Ffs*5
# 2      ...            ENST00000269305.4:c.821T>G         p.V274G
# 3      ...   ENST00000509479.2:c.1508_1509insCAA  p.Q503delinsHK
# 4      ...           ENST00000271628.8:c.1191G>T         p.Q397H
# ...    ...                                   ...             ...
# 15129  ...          ENST00000306329.11:c.4410C>G        p.P1470=
# 15130  ...           ENST00000346208.3:c.1003dup    p.D335Gfs*17
# 15131  ...          ENST00000263734.3:c.26+11G>A           p.*9*
# 15132  ...           ENST00000309964.4:c.1376C>T         p.T459M
# 15133  ...           ENST00000229330.4:c.1778C>T         p.A593V
#
#          Transcript_ID Gene_length  ENSP             Hugo_variant  \
# 0      ENST00000269305       25760   NaN   TP53_Nonsense_Mutation
# 1      ENST00000263967       91980   NaN   PIK3CA_Frame_Shift_Ins
# 2      ENST00000269305       25760   NaN   TP53_Missense_Mutation
# 3      ENST00000509479      437432   NaN       MAML3_In_Frame_Ins
# 4      ENST00000271628        5028   NaN  SF3B4_Missense_Mutation
# ...                ...         ...   ...                      ...
# 15129  ENST00000306329      127118   NaN             SOGA2_Silent
# 15130  ENST00000346208       21595   NaN    GATA3_Frame_Shift_Ins
# 15131  ENST00000263734       93031   NaN             EPAS1_Intron
# 15132  ENST00000309964      119236   NaN  CLOCK_Missense_Mutation
# 15133  ENST00000229330       40405   NaN  HCFC2_Missense_Mutation
#
#       Mutation_length  Protein_position_start  Protein_position_end  \
# 0                 1.0                   342.0                 342.0
# 1                 2.0                  1069.0                1069.0
# 2                 1.0                   274.0                 274.0
# 3                 2.0                   503.0                 503.0
# 4                 1.0                   397.0                 397.0
# ...               ...                     ...                   ...
# 15129             1.0                  1470.0                1470.0
# 15130             2.0                   333.0                 333.0
# 15131             1.0                     NaN                   NaN
# 15132             1.0                   459.0                 459.0
# 15133             1.0                   593.0                 593.0
#
#        Protein_length
# 0                 393
# 1                1068
# 2                 393
# 3                1138
# 4                 424
# ...               ...
# 15129            1586
# 15130             444
# 15131             870
# 15132             846
# 15133             792
#
# [15134 rows x 21 columns]

# %%
significant_mutations_TNandNONTN_AND_total_ductal_onlyHugo.PATIENT_ID.nunique()
# Out:
# 1508

# %%
significant_mutations_TNandNONTN_AND_total_ductal_onlyHugo.Hugo_Symbol.nunique()
# Out:
# 1017

# %%
unique_Hugo_symbols_array = significant_mutations_TNandNONTN_AND_total_ductal_onlyHugo.Hugo_Symbol.unique()
unique_Hugo_symbols_array
# Out:
# array(['TP53', 'PIK3CA', 'MAML3', ..., 'CCNT2', 'CSN2', 'KRTAP5-1'],
#       dtype=object)

# %%
df_unique_Hugo_symbols = pd.DataFrame(unique_Hugo_symbols_array, columns=['Hugo_Symbol'])
df_unique_Hugo_symbols
# Out:
#      Hugo_Symbol
# 0           TP53
# 1         PIK3CA
# 2          MAML3
# 3          SF3B4
# 4            TTN
# ...          ...
# 1012       SPG21
# 1013       PFDN5
# 1014       CCNT2
# 1015        CSN2
# 1016    KRTAP5-1
#
# [1017 rows x 1 columns]

# %%
# load the total ductal mutation dataset with the corrected protein_positions end and start
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi")
total_ductal_dataset = pd.read_csv('data_mutation_total_ductal_nohypo_nohyper_CORRECTION_protein_pos_definitivo.csv', sep=None, engine='python')
total_ductal_dataset
# Out:
#                     PATIENT_ID                    Tumor_Sample_Barcode  \
# 0       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 1       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 2       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 3       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 4       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# ...                        ...                                     ...
# 139365     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 139366     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 139367     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 139368     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 139369     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#        Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0            KALRN          3     123988087.0   123988087.0
# 1             ANK2          4     114195720.0   114195720.0
# 2           SORBS2          4     186539742.0   186539742.0
# 3          PCDHA11          5     140250828.0   140250828.0
# 4           WRNIP1          6       2766210.0     2766210.0
# ...            ...        ...             ...           ...
# 139365       NRSN2         20        333991.0      333991.0
# 139366      CHRNA4         20      61986887.0    61986887.0
# 139367      CHRNA4         20      61987386.0    61987386.0
# 139368       KCNQ2         20      62078103.0    62078103.0
# 139369        XBP1         22      29191563.0    29191563.0
#
#        Variant_Classification Variant_Type Reference_Allele Tumor_Seq_Allele1  \
# 0           Missense_Mutation          SNP                G                 G
# 1           Missense_Mutation          SNP                C                 C
# 2           Missense_Mutation          SNP                G                 G
# 3           Missense_Mutation          SNP                C                 C
# 4           Missense_Mutation          SNP                C                 C
# ...                       ...          ...              ...               ...
# 139365                 Silent          SNP                C                 C
# 139366                 Intron          SNP                G                 G
# 139367                 Silent          SNP                G                 G
# 139368                 Silent          SNP                G                 G
# 139369      Nonsense_Mutation          SNP                G                 G
#
#        Tumor_Seq_Allele2                           HGVSc HGVSp_Short  \
# 0                      C      ENST00000240874.3:c.948G>C     p.E316D
# 1                      T     ENST00000357077.4:c.1598C>T     p.P533L
# 2                      C     ENST00000355634.5:c.2936C>G     p.S979C
# 3                      G     ENST00000398640.2:c.2140C>G     p.L714V
# 4                      A      ENST00000380773.4:c.354C>A     p.S118R
# ...                  ...                             ...         ...
# 139365                 T      ENST00000382285.2:c.327C>T     p.N109=
# 139366                 C  ENST00000370263.4:c.383+440C>G     p.*128*
# 139367                 A      ENST00000370263.4:c.324C>T     p.V108=
# 139368                 A      ENST00000359125.2:c.384C>T     p.I128=
# 139369                 A      ENST00000216037.6:c.757C>T     p.Q253*
#
#           Transcript_ID  Gene_length ENSP               Hugo_variant  \
# 0       ENST00000240874       646303  NaN    KALRN_Missense_Mutation
# 1       ENST00000357077       565632  NaN     ANK2_Missense_Mutation
# 2       ENST00000355634       371209  NaN   SORBS2_Missense_Mutation
# 3       ENST00000398640       143241  NaN  PCDHA11_Missense_Mutation
# 4       ENST00000380773        21539  NaN   WRNIP1_Missense_Mutation
# ...                 ...          ...  ...                        ...
# 139365  ENST00000382285        12879  NaN               NRSN2_Silent
# 139366  ENST00000370263        34334  NaN              CHRNA4_Intron
# 139367  ENST00000370263        34334  NaN              CHRNA4_Silent
# 139368  ENST00000359125        66452  NaN               KCNQ2_Silent
# 139369  ENST00000216037         6043  NaN     XBP1_Nonsense_Mutation
#
#         Mutation_length  Protein_position_start  Protein_position_end
# 0                   1.0                   316.0                 316.0
# 1                   1.0                   533.0                 533.0
# 2                   1.0                   979.0                 979.0
# 3                   1.0                   714.0                 714.0
# 4                   1.0                   118.0                 118.0
# ...                 ...                     ...                   ...
# 139365              1.0                   109.0                 109.0
# 139366              1.0                     NaN                   NaN
# 139367              1.0                   108.0                 108.0
# 139368              1.0                   128.0                 128.0
# 139369              1.0                   253.0                 253.0
#
# [139370 rows x 20 columns]

# %% [markdown]
# ### Columns of the occurence matrix: hotspots found by MutClust and mutations on genes not belonging to any hotspot (columns that are marked with the suffix noClust)

# %%
# creo la lista delle colonne della matrice di occorrenza
def CreatingColumns_OccMatrix(freq_cluster_x, df_Hugo_unique):
    columns = []

    for index_clust, row_clust in freq_cluster_x.iterrows():
        columns.append(row_clust.Gene + '_' + str(row_clust.Start) + '_' + str(row_clust.End)) 
    
    #aggiungo le colonne per le mutazioni che non sono presenti in nessun cluster
    for index_mut, row_mut in df_Hugo_unique.iterrows():
        columns.append(row_mut.Hugo_Symbol + '_noClust')
    
    return columns

# %%
columns_occ_matrix_TNandNONTNgenes_pval005_onlyHugo = CreatingColumns_OccMatrix (freq_cluster_100_TNandNONTN_onlyHugo, df_unique_Hugo_symbols)
columns_occ_matrix_TNandNONTNgenes_pval005_onlyHugo
# Out:
# ['TP53_270_282',
#  'GATA3_406_408',
#  'MAML3_503_503',
#  'AKT1_17_17',
#  'MYL10_26_26',
#  'PIK3R1_566_578',
#  'NUP93_14_15',
#  'ZKSCAN1_270_270',
#  'CTCF_283_288',
#  'GATA3_308_335',
#  'PIK3CA_1046_1047',
#  'PIK3CA_541_542',
#  'PIK3CA_345_345',
#  'PIK3CA_102_113',
#  'FOXA1_254_268',
#  'MTMR12_520_521',
#  'PRB2_81_81',
#  'ERBB2_767_777',
#  'ZNF208_548_549',
#  'PIK3CA_545_546',
#  'KRAS_12_12',
#  'GATA3_429_434',
#  'ESR1_537_538',
#  'TP53_191_199',
#  'ZNF195_109_111',
#  'TP53_236_258',
#  'TP53_173_177',
#  'TBX3_210_218',
#  'ZNF814_303_311',
#  'C8orf44_38_39',
#  'CHD9_2120_2120',
#  'SF3B1_700_700',
#  'DNAH14_143_288',
#  'FAM208B_805_805',
#  'RBM27_719_719',
#  'ESR1_380_380',
#  'ABCG2_22_32',
#  'DAP3_331_331',
#  'ZNF716_294_294',
#  'DMXL2_1709_1740',
#  'ZNF19_280_280',
#  'MAP4K3_395_415',
#  'FGFR2_549_549',
#  'USP8_523_523',
#  'OR4D10_175_183',
#  'TMPRSS13_77_83',
#  'RUNX1_122_123',
#  'DDX5_134_141',
#  'FHDC1_57_57',
#  'PTEN_317_318',
#  'RCC2_271_278',
#  'NUP153_1299_1299',
#  'NOTCH2_2297_2303',
#  'FAM193A_1170_1214',
#  'TP53_noClust',
#  'PIK3CA_noClust',
#  'MAML3_noClust',
#  'SF3B4_noClust',
#  'TTN_noClust',
#  'COL6A6_noClust',
#  'NF1_noClust',
#  'KDM5B_noClust',
#  'ACACB_noClust',
#  'ATP11A_noClust',
#  'CXorf38_noClust',
#  'APEX2_noClust',
#  'STAT1_noClust',
#  'MLLT10_noClust',
#  'CDC20_noClust',
#  'COL5A3_noClust',
#  'MMS22L_noClust',
#  'KMT2C_noClust',
#  'LMTK2_noClust',
#  'PTEN_noClust',
#  'ZNF19_noClust',
#  'GPRIN1_noClust',
#  'KCNH6_noClust',
#  'TOR1AIP1_noClust',
#  'CCDC142_noClust',
#  'NIPBL_noClust',
#  'ITPKB_noClust',
#  'DNAH7_noClust',
#  'MDGA1_noClust',
#  'NFE2L3_noClust',
#  'TMEM261_noClust',
#  'FBRSL1_noClust',
#  'PALB2_noClust',
#  'KRTAP24-1_noClust',
#  'CBFB_noClust',
#  'ARID1A_noClust',
#  'JMJD6_noClust',
#  'ZNF546_noClust',
#  'MUC4_noClust',
#  'AKAP11_noClust',
#  'GALK1_noClust',
#  'SEC63_noClust',
#  'GATA3_noClust',
#  'COL17A1_noClust',
#  'NOTCH2_noClust',
#  'CFTR_noClust',
#  'RAD54B_noClust',
#  'CCNE2_noClust',
#  'PNN_noClust',
#  'SEMA6D_noClust',
#  'MYH7B_noClust',
#  'OCRL_noClust',
#  'SPEN_noClust',
#  'DNAH12_noClust',
#  'FAM154A_noClust',
#  'TNRC6C_noClust',
#  'TULP4_noClust',
#  'PRB2_noClust',
#  'ERBB2_noClust',
#  'FAM171B_noClust',
#  'ZNF654_noClust',
#  'MAP2K4_noClust',
#  'EIF4G3_noClust',
#  'ARHGAP5_noClust',
#  'SERPINB3_noClust',
#  'ASH1L_noClust',
#  'CACNA1S_noClust',
#  'PODXL2_noClust',
#  'TUBD1_noClust',
#  'FASN_noClust',
#  'ACTN4_noClust',
#  'WTAP_noClust',
#  'FOXA1_noClust',
#  'PUM1_noClust',
#  'TFDP2_noClust',
#  'KIAA1109_noClust',
#  'RSBN1L_noClust',
#  'LARP4B_noClust',
#  'SMTNL1_noClust',
#  'MTRF1_noClust',
#  'CTCF_noClust',
#  'TEX14_noClust',
#  'MAGEA12_noClust',
#  'TAF2_noClust',
#  'HIST1H3B_noClust',
#  'SZT2_noClust',
#  'SVIL_noClust',
#  'NPAS4_noClust',
#  'NAV3_noClust',
#  'DIDO1_noClust',
#  'EPS8L3_noClust',
#  'MTHFD1L_noClust',
#  'SYNE1_noClust',
#  'PON1_noClust',
#  'ZNF438_noClust',
#  'CALB2_noClust',
#  'SOGA2_noClust',
#  'DOCK11_noClust',
#  'SELL_noClust',
#  'IL31RA_noClust',
#  'FBXO18_noClust',
#  'MCRS1_noClust',
#  'ZNF207_noClust',
#  'WDR62_noClust',
#  'PDIK1L_noClust',
#  'C5orf48_noClust',
#  'UBAP2L_noClust',
#  'TFPI2_noClust',
#  'SNX16_noClust',
#  'OSBPL8_noClust',
#  'KIAA1033_noClust',
#  'STON2_noClust',
#  'CRABP1_noClust',
#  'ZC3H4_noClust',
#  'MLXIPL_noClust',
#  'HECTD1_noClust',
#  'CDH23_noClust',
#  'RLIM_noClust',
#  'AKT1_noClust',
#  'INSRR_noClust',
#  'STRN4_noClust',
#  'ATRX_noClust',
#  'NCOR1_noClust',
#  'ASXL2_noClust',
#  'OMA1_noClust',
#  'MAP3K1_noClust',
#  'WWP1_noClust',
#  'UBAP2_noClust',
#  'ERBB3_noClust',
#  'XRCC6BP1_noClust',
#  'LAMP5_noClust',
#  'TCHHL1_noClust',
#  'MYB_noClust',
#  'UBE3B_noClust',
#  'ATG14_noClust',
#  'EPHB2_noClust',
#  'TRPM8_noClust',
#  'KCNB2_noClust',
#  'P2RX2_noClust',
#  'ACTG1_noClust',
#  'LDLR_noClust',
#  'WDR44_noClust',
#  'BCL9_noClust',
#  'TMEM214_noClust',
#  'ATM_noClust',
#  'CREBBP_noClust',
#  'KIAA0556_noClust',
#  'PBRM1_noClust',
#  'CDKN2A_noClust',
#  'SH3TC1_noClust',
#  'APC_noClust',
#  'NUMA1_noClust',
#  'FERMT2_noClust',
#  'TRIP11_noClust',
#  'SAMD11_noClust',
#  'SRSF4_noClust',
#  'MUSK_noClust',
#  'USP8_noClust',
#  'PRPF38B_noClust',
#  'OR2W3_noClust',
#  'FGF18_noClust',
#  'RAB11FIP1_noClust',
#  'CYHR1_noClust',
#  'DNAL1_noClust',
#  'SCPEP1_noClust',
#  'MKNK2_noClust',
#  'LCA5L_noClust',
#  'GPR119_noClust',
#  'ZNF764_noClust',
#  'PLK4_noClust',
#  'COL19A1_noClust',
#  'CYP3A4_noClust',
#  'BLK_noClust',
#  'BRCA2_noClust',
#  'MYH6_noClust',
#  'EPG5_noClust',
#  'CD33_noClust',
#  'SLC1A7_noClust',
#  'SELP_noClust',
#  'OSR2_noClust',
#  'ZFHX3_noClust',
#  'AP1M2_noClust',
#  'NXPE3_noClust',
#  'DIEXF_noClust',
#  'THUMPD2_noClust',
#  'PPP1R9A_noClust',
#  'KLF10_noClust',
#  'OR4X2_noClust',
#  'SF3B3_noClust',
#  'DUSP18_noClust',
#  'CTPS2_noClust',
#  'SMARCA1_noClust',
#  'KIAA1614_noClust',
#  'ALK_noClust',
#  'FOXP1_noClust',
#  'HERC6_noClust',
#  'PCDHGA8_noClust',
#  'RUNX2_noClust',
#  'C8orf44_noClust',
#  'ZNF250_noClust',
#  'NUP188_noClust',
#  'KLHDC2_noClust',
#  'CDH1_noClust',
#  'FLII_noClust',
#  'KIAA0195_noClust',
#  'ZMYND8_noClust',
#  'ICOSLG_noClust',
#  'USP9X_noClust',
#  'TAF7L_noClust',
#  'TAS1R3_noClust',
#  'NASP_noClust',
#  'THADA_noClust',
#  'PHIP_noClust',
#  'GPHA2_noClust',
#  'KRTAP9-8_noClust',
#  'TBX3_noClust',
#  'ORC2_noClust',
#  'STAB1_noClust',
#  'ESF1_noClust',
#  'COL4A4_noClust',
#  'TSKS_noClust',
#  'LOR_noClust',
#  'COL24A1_noClust',
#  'KIDINS220_noClust',
#  'MSH2_noClust',
#  'GCM2_noClust',
#  'TMEM126A_noClust',
#  'CCDC57_noClust',
#  'PPCS_noClust',
#  'SETDB1_noClust',
#  'XRN1_noClust',
#  'RPS3A_noClust',
#  'FBXW7_noClust',
#  'ANKRD37_noClust',
#  'ANKHD1_noClust',
#  'PI16_noClust',
#  'FAM107B_noClust',
#  'CLEC1A_noClust',
#  'HPD_noClust',
#  'DNAH10_noClust',
#  'DSC3_noClust',
#  'RUNX1_noClust',
#  'STAG2_noClust',
#  'DBT_noClust',
#  'PTPN22_noClust',
#  'MBD5_noClust',
#  'IFNGR1_noClust',
#  'AIG1_noClust',
#  'GLDC_noClust',
#  'EHD2_noClust',
#  'TOP3A_noClust',
#  'C3orf70_noClust',
#  'FAM96A_noClust',
#  'G6PD_noClust',
#  'FKBP4_noClust',
#  'FMO5_noClust',
#  'ATP2B2_noClust',
#  'MCF2L2_noClust',
#  'TMPRSS13_noClust',
#  'TNRC6A_noClust',
#  'KLK2_noClust',
#  'RB1_noClust',
#  'ARAP3_noClust',
#  'UACA_noClust',
#  'ABCG2_noClust',
#  'LRCH3_noClust',
#  'TBC1D21_noClust',
#  'KLC3_noClust',
#  'CHRM1_noClust',
#  'GP2_noClust',
#  'TSTA3_noClust',
#  'PLS3_noClust',
#  'NLRP2_noClust',
#  'PSMD5_noClust',
#  'ZNF195_noClust',
#  'DNAH14_noClust',
#  'A2M_noClust',
#  'REV1_noClust',
#  'HCFC2_noClust',
#  'PIK3R1_noClust',
#  'ETV5_noClust',
#  'AP5M1_noClust',
#  'PRKCZ_noClust',
#  'TNC_noClust',
#  'OCSTAMP_noClust',
#  'INADL_noClust',
#  'TBC1D8_noClust',
#  'GLS_noClust',
#  'KNG1_noClust',
#  'ANLN_noClust',
#  'SYBU_noClust',
#  'CCAR1_noClust',
#  'SPPL3_noClust',
#  'EML5_noClust',
#  'ALPK1_noClust',
#  'HSD17B11_noClust',
#  'HERC1_noClust',
#  'EWSR1_noClust',
#  'GPR133_noClust',
#  'ANKRD12_noClust',
#  'PNMAL1_noClust',
#  'NOV_noClust',
#  'KRTAP9-4_noClust',
#  'ITSN2_noClust',
#  'NAA15_noClust',
#  'DMXL2_noClust',
#  'NCF2_noClust',
#  'NBL1_noClust',
#  'MARC1_noClust',
#  'BMPR2_noClust',
#  'RBP3_noClust',
#  'SCAPER_noClust',
#  'PLEKHH2_noClust',
#  'RC3H2_noClust',
#  'GLT6D1_noClust',
#  'UNC13A_noClust',
#  'OR4D10_noClust',
#  'SREBF1_noClust',
#  'CIR1_noClust',
#  'C6orf118_noClust',
#  'TEAD4_noClust',
#  'TMEM132C_noClust',
#  'RPGRIP1_noClust',
#  'KATNAL1_noClust',
#  'FSD2_noClust',
#  'CLCC1_noClust',
#  'GRM2_noClust',
#  'PLEKHA6_noClust',
#  'EPHX3_noClust',
#  'STAB2_noClust',
#  'IL24_noClust',
#  'ACAN_noClust',
#  'RIF1_noClust',
#  'KMT2A_noClust',
#  'NRK_noClust',
#  'GPC3_noClust',
#  'MLLT4_noClust',
#  'PRAMEF2_noClust',
#  'PARP9_noClust',
#  'RASA1_noClust',
#  'HOOK2_noClust',
#  'NFRKB_noClust',
#  'CA9_noClust',
#  'GCNT1_noClust',
#  'ITGAM_noClust',
#  'MAP4K1_noClust',
#  'GLG1_noClust',
#  'DDB1_noClust',
#  'OR9K2_noClust',
#  'EML2_noClust',
#  'PLA2G4D_noClust',
#  'LEF1_noClust',
#  'CLTCL1_noClust',
#  'RASIP1_noClust',
#  'ZBTB48_noClust',
#  'KL_noClust',
#  'MED23_noClust',
#  'AGL_noClust',
#  'ARRDC1_noClust',
#  'TSPYL2_noClust',
#  'TET3_noClust',
#  'OBSL1_noClust',
#  'ZNF106_noClust',
#  'ATAD2B_noClust',
#  'ASTN1_noClust',
#  'RMDN2_noClust',
#  'SEMA5A_noClust',
#  'EGR3_noClust',
#  'NCOA6_noClust',
#  'PPIL2_noClust',
#  'EP300_noClust',
#  'LAMB3_noClust',
#  'TSC1_noClust',
#  'SLAMF9_noClust',
#  'STK10_noClust',
#  'MFSD3_noClust',
#  'ANKRD11_noClust',
#  'PZP_noClust',
#  'EFS_noClust',
#  'SLC4A9_noClust',
#  'VWF_noClust',
#  'MYH9_noClust',
#  'ARHGEF28_noClust',
#  'BAP1_noClust',
#  'TRIML2_noClust',
#  'MEFV_noClust',
#  'MRGPRX4_noClust',
#  'CHD9_noClust',
#  'COL4A2_noClust',
#  'NOTCH4_noClust',
#  'PKN2_noClust',
#  'PRRG4_noClust',
#  'ST3GAL6_noClust',
#  'ZC3HC1_noClust',
#  'AKR1C3_noClust',
#  'NME5_noClust',
#  'SPIRE2_noClust',
#  'TLN2_noClust',
#  'EDC4_noClust',
#  'PRPF3_noClust',
#  'ASB11_noClust',
#  'SF3B1_noClust',
#  'HERC4_noClust',
#  'P2RY8_noClust',
#  'KIAA1586_noClust',
#  'JAK1_noClust',
#  'KDM6B_noClust',
#  'MAP4K3_noClust',
#  'SPRED2_noClust',
#  'TACC2_noClust',
#  'BPIFB2_noClust',
#  'CCDC102B_noClust',
#  'KIAA0430_noClust',
#  'KIF1B_noClust',
#  'PLOD1_noClust',
#  'POGZ_noClust',
#  'SORT1_noClust',
#  'TET2_noClust',
#  'ATL3_noClust',
#  'F2RL2_noClust',
#  'ABCC8_noClust',
#  'KIF5B_noClust',
#  'TAT_noClust',
#  'ZBTB11_noClust',
#  'AGO1_noClust',
#  'FABP1_noClust',
#  'PIK3R4_noClust',
#  'SPP1_noClust',
#  'CTGF_noClust',
#  'DDX11_noClust',
#  'FAM193A_noClust',
#  'IFT172_noClust',
#  'SLC45A1_noClust',
#  'ADAM30_noClust',
#  'BRCA1_noClust',
#  'CYP46A1_noClust',
#  'TAAR5_noClust',
#  'DCST1_noClust',
#  'SLC28A2_noClust',
#  'SLC6A11_noClust',
#  'M6PR_noClust',
#  'KCNV2_noClust',
#  'SEC24B_noClust',
#  'SLC26A10_noClust',
#  'TACC3_noClust',
#  'C11orf85_noClust',
#  'COL6A3_noClust',
#  'PSIP1_noClust',
#  'RSPH4A_noClust',
#  'SPTAN1_noClust',
#  'ILF2_noClust',
#  'KMO_noClust',
#  'SRCAP_noClust',
#  'WHAMM_noClust',
#  'TECR_noClust',
#  'AZIN1_noClust',
#  'GLUD2_noClust',
#  'KIAA1045_noClust',
#  'KRTAP1-3_noClust',
#  'RHPN1_noClust',
#  'RNF220_noClust',
#  'PLK2_noClust',
#  'WDR45B_noClust',
#  'CASP8_noClust',
#  'MGAT5B_noClust',
#  'OR2B6_noClust',
#  'CPT1B_noClust',
#  'AP4M1_noClust',
#  'CLN3_noClust',
#  'CXorf23_noClust',
#  'ERG_noClust',
#  'KLF4_noClust',
#  'MTM1_noClust',
#  'SMAD4_noClust',
#  'TLR3_noClust',
#  'TRAF3_noClust',
#  'ZNF672_noClust',
#  'CCDC82_noClust',
#  'SLFN13_noClust',
#  'ITPR3_noClust',
#  'KRT79_noClust',
#  'ESR1_noClust',
#  'DIAPH1_noClust',
#  'ERCC5_noClust',
#  'IL15RA_noClust',
#  'PPEF2_noClust',
#  'SIN3B_noClust',
#  'TF_noClust',
#  'ZNF311_noClust',
#  'SLC4A2_noClust',
#  'CD93_noClust',
#  'HSP90B1_noClust',
#  'LRRC43_noClust',
#  'FAM83G_noClust',
#  'DAZAP1_noClust',
#  'METTL7B_noClust',
#  'MYL10_noClust',
#  'PHF11_noClust',
#  'STK31_noClust',
#  'COL2A1_noClust',
#  'LRRC16B_noClust',
#  'LMOD1_noClust',
#  'IGHMBP2_noClust',
#  'RASSF2_noClust',
#  'TRAPPC12_noClust',
#  'MYOT_noClust',
#  'TRAF5_noClust',
#  'FAM227B_noClust',
#  'RIPK1_noClust',
#  'KCNH4_noClust',
#  'DAP3_noClust',
#  'DISP1_noClust',
#  'FANCF_noClust',
#  'KLHL40_noClust',
#  'MCHR1_noClust',
#  'NUP93_noClust',
#  'UQCR10_noClust',
#  'GPR3_noClust',
#  'SUCO_noClust',
#  'EIF3K_noClust',
#  'BRD7_noClust',
#  'C11orf63_noClust',
#  'RCOR2_noClust',
#  'IFIT2_noClust',
#  'NUP153_noClust',
#  'C16orf89_noClust',
#  'GAS6_noClust',
#  'OLFML2B_noClust',
#  'ARHGAP24_noClust',
#  'CFP_noClust',
#  'RAPGEF4_noClust',
#  'SMG1_noClust',
#  'TMEM14B_noClust',
#  'AKT2_noClust',
#  'CUL7_noClust',
#  'E2F4_noClust',
#  'EIF4A2_noClust',
#  'FILIP1L_noClust',
#  'MATN4_noClust',
#  'NKX3-2_noClust',
#  'NOD2_noClust',
#  'PDCD4_noClust',
#  'TRIM24_noClust',
#  'ZNF500_noClust',
#  'WASF3_noClust',
#  'TM2D1_noClust',
#  'KIAA0907_noClust',
#  'ANKRD28_noClust',
#  'TFAP2A_noClust',
#  'DNTT_noClust',
#  'ZEB2_noClust',
#  'CATSPER1_noClust',
#  'ZBTB24_noClust',
#  'SFMBT2_noClust',
#  'GUCY2C_noClust',
#  'CAPN2_noClust',
#  'ZNF608_noClust',
#  'SP140_noClust',
#  'IFNGR2_noClust',
#  'EIF2AK2_noClust',
#  'TLN1_noClust',
#  'S100A7_noClust',
#  'KRT6B_noClust',
#  'PTCD3_noClust',
#  'CEP152_noClust',
#  'PRB3_noClust',
#  'KTN1_noClust',
#  'MSH5_noClust',
#  'KMT2E_noClust',
#  'DDX55_noClust',
#  'IL12RB2_noClust',
#  'CYTIP_noClust',
#  'FCRLA_noClust',
#  'MUC17_noClust',
#  'TMED6_noClust',
#  'SCAF8_noClust',
#  'DDX5_noClust',
#  'PPFIA4_noClust',
#  'OR6X1_noClust',
#  'ADORA3_noClust',
#  'RCC2_noClust',
#  'FANCD2_noClust',
#  'PPARG_noClust',
#  'IBSP_noClust',
#  'NUP160_noClust',
#  'GLIPR1L2_noClust',
#  'MTERFD3_noClust',
#  'LZTR1_noClust',
#  'CELA3B_noClust',
#  'GAB3_noClust',
#  'CPNE8_noClust',
#  'MBOAT1_noClust',
#  'TRPV5_noClust',
#  'FAM208B_noClust',
#  'ZNF208_noClust',
#  'FANCB_noClust',
#  'HNF1B_noClust',
#  'SLC11A2_noClust',
#  'TRMT1L_noClust',
#  'PLEKHA4_noClust',
#  'ARMC8_noClust',
#  'SPEF2_noClust',
#  'ANP32E_noClust',
#  'CPEB1_noClust',
#  'SEC13_noClust',
#  'KIAA0355_noClust',
#  'CACNA1F_noClust',
#  'WBP5_noClust',
#  'SERPINA4_noClust',
#  'OR7C1_noClust',
#  'PCDHA10_noClust',
#  'IL1R1_noClust',
#  'SUPT16H_noClust',
#  'MTMR12_noClust',
#  'PRDM1_noClust',
#  'TRAPPC10_noClust',
#  'RGN_noClust',
#  'OMD_noClust',
#  'ATF6_noClust',
#  'LETM1_noClust',
#  'ZNF716_noClust',
#  'ZKSCAN1_noClust',
#  'ZNF25_noClust',
#  'NPY4R_noClust',
#  'MICAL2_noClust',
#  'CPSF7_noClust',
#  'CTTN_noClust',
#  'PRB4_noClust',
#  'B2M_noClust',
#  'APH1B_noClust',
#  'DPP8_noClust',
#  'CRYBA1_noClust',
#  'SAMD14_noClust',
#  'SIRT7_noClust',
#  'OSBPL1A_noClust',
#  'ULBP2_noClust',
#  'THNSL2_noClust',
#  'CLOCK_noClust',
#  'MYRF_noClust',
#  'SPOPL_noClust',
#  'KCNAB3_noClust',
#  'HSPBAP1_noClust',
#  'LPCAT3_noClust',
#  'SLFN12L_noClust',
#  'AMZ1_noClust',
#  'GBGT1_noClust',
#  'FGFR2_noClust',
#  'ZNF554_noClust',
#  'CDKN1B_noClust',
#  'IARS_noClust',
#  'LRP4_noClust',
#  'L3MBTL4_noClust',
#  'RBM47_noClust',
#  'HRAS_noClust',
#  'ARNTL2_noClust',
#  'MEN1_noClust',
#  'ZMIZ2_noClust',
#  'KRAS_noClust',
#  'CCNT1_noClust',
#  'TH_noClust',
#  'LPCAT4_noClust',
#  'AMPD1_noClust',
#  'KPRP_noClust',
#  'TSSK3_noClust',
#  'DNTTIP2_noClust',
#  'GOLGA4_noClust',
#  'XPO5_noClust',
#  'GALNTL5_noClust',
#  'ASH2L_noClust',
#  'STAT2_noClust',
#  'IL25_noClust',
#  'PYCARD_noClust',
#  'CCT6B_noClust',
#  'LRRC37A3_noClust',
#  'ZNF230_noClust',
#  'RNF185_noClust',
#  'HIST1H3D_noClust',
#  'HIST2H2AC_noClust',
#  'COPG1_noClust',
#  'FANCG_noClust',
#  'OAS2_noClust',
#  'RSL1D1_noClust',
#  'PTRH1_noClust',
#  'FSHR_noClust',
#  'FCHO1_noClust',
#  'EPAS1_noClust',
#  'SMC6_noClust',
#  'ACOT11_noClust',
#  'TYRP1_noClust',
#  'CHD4_noClust',
#  'TCTN1_noClust',
#  'CTTNBP2NL_noClust',
#  'SP3_noClust',
#  'RBM27_noClust',
#  'HIST1H2BC_noClust',
#  'WBSCR27_noClust',
#  'RABEP1_noClust',
#  'CCSER1_noClust',
#  'SERPINC1_noClust',
#  'CARD6_noClust',
#  'GARNL3_noClust',
#  'GRB10_noClust',
#  'LMAN1L_noClust',
#  'COIL_noClust',
#  'SLC26A9_noClust',
#  'GNPTAB_noClust',
#  'PFKM_noClust',
#  'SLC6A13_noClust',
#  'KDELC2_noClust',
#  'XPO4_noClust',
#  'VPS9D1_noClust',
#  'AKAP4_noClust',
#  'TSC22D1_noClust',
#  'SLC25A19_noClust',
#  'TLR4_noClust',
#  'MFGE8_noClust',
#  'KIAA1324_noClust',
#  'PRUNE_noClust',
#  'DDX42_noClust',
#  'CA14_noClust',
#  'FBXL18_noClust',
#  'CCNDBP1_noClust',
#  'CCDC135_noClust',
#  'B4GALNT2_noClust',
#  'SIRPG_noClust',
#  'GPR97_noClust',
#  'TRAPPC8_noClust',
#  'RBPJL_noClust',
#  'CEACAM3_noClust',
#  'SGIP1_noClust',
#  'IP6K1_noClust',
#  'FAM65B_noClust',
#  'CA3_noClust',
#  'HSF1_noClust',
#  'GRAMD1A_noClust',
#  'KCNT2_noClust',
#  'TFIP11_noClust',
#  'DDOST_noClust',
#  'DYSF_noClust',
#  'MEA1_noClust',
#  'SMARCE1_noClust',
#  'DNMT3L_noClust',
#  'TFDP1_noClust',
#  'C11orf35_noClust',
#  'ZNF710_noClust',
#  'SETD6_noClust',
#  'PIAS3_noClust',
#  'GZMK_noClust',
#  'RGS11_noClust',
#  'C19orf10_noClust',
#  'TYROBP_noClust',
#  'FHDC1_noClust',
#  'PMS2_noClust',
#  'B4GALNT3_noClust',
#  'CCDC53_noClust',
#  'SGK2_noClust',
#  'CDC42BPA_noClust',
#  'AQR_noClust',
#  'HMGN1_noClust',
#  'WDR47_noClust',
#  'C6orf136_noClust',
#  'HSPA5_noClust',
#  'CD276_noClust',
#  'SLC13A2_noClust',
#  'PLA2G3_noClust',
#  'AANAT_noClust',
#  'KCNAB2_noClust',
#  'CASZ1_noClust',
#  'DAB1_noClust',
#  'PLIN2_noClust',
#  'PTPRE_noClust',
#  'MED17_noClust',
#  'LAMP1_noClust',
#  'C16orf62_noClust',
#  'CHAF1A_noClust',
#  'BCL10_noClust',
#  'GPATCH4_noClust',
#  'IP6K3_noClust',
#  'PTPRJ_noClust',
#  'SPINT2_noClust',
#  'ETV3L_noClust',
#  'GRPEL2_noClust',
#  'DDC_noClust',
#  'TRIM14_noClust',
#  'GPR144_noClust',
#  'RIC8A_noClust',
#  'ACLY_noClust',
#  'AGT_noClust',
#  'TANC1_noClust',
#  'GPS2_noClust',
#  'CMBL_noClust',
#  'ADRBK1_noClust',
#  'SLC20A2_noClust',
#  'MEF2A_noClust',
#  'PTGS2_noClust',
#  'NDRG1_noClust',
#  'VASH2_noClust',
#  'ACVR2A_noClust',
#  'FASTKD2_noClust',
#  'NBN_noClust',
#  'APTX_noClust',
#  'FAM166B_noClust',
#  'PKNOX2_noClust',
#  'RALGAPA1_noClust',
#  'BATF_noClust',
#  'CABYR_noClust',
#  'GAMT_noClust',
#  'ZNRF4_noClust',
#  'PLVAP_noClust',
#  'ZC3H12C_noClust',
#  'GALNTL6_noClust',
#  'INPP5A_noClust',
#  'HAUS8_noClust',
#  'C1orf43_noClust',
#  'PEX11G_noClust',
#  'SMTNL2_noClust',
#  'ABCG1_noClust',
#  'ATG4C_noClust',
#  'ARPC5_noClust',
#  'NCCRP1_noClust',
#  'GRB7_noClust',
#  'KDM6A_noClust',
#  'ZMIZ1_noClust',
#  'FKBP2_noClust',
#  'PSKH1_noClust',
#  'FAM69A_noClust',
#  'LUC7L2_noClust',
#  'E2F7_noClust',
#  'GOLGA3_noClust',
#  'ZC3H11A_noClust',
#  'FYB_noClust',
#  'UPF1_noClust',
#  'RPL5_noClust',
#  'TRAF6_noClust',
#  'ADRBK2_noClust',
#  'EIF4ENIF1_noClust',
#  'NDUFB6_noClust',
#  'PIK3C2A_noClust',
#  'JUN_noClust',
#  'LINGO3_noClust',
#  'DNASE1L3_noClust',
#  'KAT8_noClust',
#  'DCUN1D2_noClust',
#  'FBXO44_noClust',
#  'EIF3I_noClust',
#  'SMURF1_noClust',
#  'MBD6_noClust',
#  'CTSO_noClust',
#  'SLC1A4_noClust',
#  'CAST_noClust',
#  'RRM2B_noClust',
#  'ZW10_noClust',
#  'HNRNPUL1_noClust',
#  'CHRNB2_noClust',
#  'ZNF814_noClust',
#  'MYLK3_noClust',
#  'ITGAV_noClust',
#  'BCS1L_noClust',
#  'GSAP_noClust',
#  'ABCB9_noClust',
#  'CCRL2_noClust',
#  'CD180_noClust',
#  'NPEPPS_noClust',
#  'SYT17_noClust',
#  'RPL23_noClust',
#  'TMEM190_noClust',
#  'C20orf96_noClust',
#  'ASCC2_noClust',
#  'ZNF251_noClust',
#  'ENPP1_noClust',
#  'KRT28_noClust',
#  'TNP2_noClust',
#  'ESYT1_noClust',
#  'CDS2_noClust',
#  'RDH5_noClust',
#  'USPL1_noClust',
#  'SCG3_noClust',
#  'NADK2_noClust',
#  'BATF2_noClust',
#  'TAS2R31_noClust',
#  'MTHFD1_noClust',
#  'OR7A10_noClust',
#  'PDLIM4_noClust',
#  'PCDHGB4_noClust',
#  'SRPK1_noClust',
#  'TARBP2_noClust',
#  'BYSL_noClust',
#  'TMEM189-UBE2V1_noClust',
#  'TRIB1_noClust',
#  'RAB42_noClust',
#  'NFKBIA_noClust',
#  'TBL1XR1_noClust',
#  'PAGE2_noClust',
#  'WBP11_noClust',
#  'FASTKD3_noClust',
#  'CYCS_noClust',
#  'C8orf31_noClust',
#  'VAMP1_noClust',
#  'MRPS7_noClust',
#  'FAM49B_noClust',
#  'OR5A1_noClust',
#  'SNAPC1_noClust',
#  'APLF_noClust',
#  'TRIM60_noClust',
#  'LGALS14_noClust',
#  'USP15_noClust',
#  'RPL18A_noClust',
#  'SRSF11_noClust',
#  'ACSM5_noClust',
#  'PAXBP1_noClust',
#  'AKIRIN1_noClust',
#  'OR5K4_noClust',
#  'OR52N2_noClust',
#  'TRA2B_noClust',
#  'MSN_noClust',
#  'TSPAN12_noClust',
#  'BSND_noClust',
#  'ZNF341_noClust',
#  'PHF1_noClust',
#  'ATP8B1_noClust',
#  'TMEM120B_noClust',
#  'POLE3_noClust',
#  'PITX1_noClust',
#  'CDK19_noClust',
#  'RAB21_noClust',
#  'TPGS2_noClust',
#  'BOLA1_noClust',
#  'RPS6_noClust',
#  'ACSBG1_noClust',
#  'FAH_noClust',
#  'WNT7A_noClust',
#  'USP42_noClust',
#  'CD300LF_noClust',
#  'INSL5_noClust',
#  'OSBP2_noClust',
#  'LIPH_noClust',
#  'CLIC1_noClust',
#  'FIGNL1_noClust',
#  'WFDC5_noClust',
#  'RPL18_noClust',
#  'PHF6_noClust',
#  'SERTAD3_noClust',
#  'HSD3B2_noClust',
#  'ELMOD3_noClust',
#  'ELOVL5_noClust',
#  'TMEM87B_noClust',
#  ...]

# %%
len(columns_occ_matrix_TNandNONTNgenes_pval005_onlyHugo)
# Out:
# 1071

# %%
# convert the list of columns into a dataframe
df_columns_occ_matrix_onlyHugo = pd.DataFrame(columns_occ_matrix_TNandNONTNgenes_pval005_onlyHugo, columns=['columns_occurence_matrix'])
df_columns_occ_matrix_onlyHugo
# Out:
#      columns_occurence_matrix
# 0                TP53_270_282
# 1               GATA3_406_408
# 2               MAML3_503_503
# 3                  AKT1_17_17
# 4                 MYL10_26_26
# ...                       ...
# 1066            SPG21_noClust
# 1067            PFDN5_noClust
# 1068            CCNT2_noClust
# 1069             CSN2_noClust
# 1070         KRTAP5-1_noClust
#
# [1071 rows x 1 columns]

# %% [markdown]
# ### Rows of the occurence matrix: Patient IDs

# %%
significant_mutations_TNandNONTN_AND_total_ductal_onlyHugo
# Out:
#                    PATIENT_ID                      Tumor_Sample_Barcode  \
# 0      brca_smc_2018_BB01_002                    brca_smc_2018_BB01_002
# 1      brca_smc_2018_BB01_002                    brca_smc_2018_BB01_002
# 2      brca_smc_2018_BB01_004                    brca_smc_2018_BB01_004
# 3      brca_smc_2018_BB01_004                    brca_smc_2018_BB01_004
# 4      brca_smc_2018_BB01_005                    brca_smc_2018_BB01_005
# ...                       ...                                       ...
# 15129     MBCProject_ygcMFgCR  RP-1156_MBCProject_ygcMFgCR_T1A_v1_Exome
# 15130     MBCProject_ygcMFgCR  RP-1156_MBCProject_ygcMFgCR_T1A_v1_Exome
# 15131     MBCProject_zyt5TKFB    MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 15132     MBCProject_zyt5TKFB    MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 15133     MBCProject_zyt5TKFB    MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#       Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0            TP53         17       7574003.0     7574003.0
# 1          PIK3CA          3     178952150.0   178952151.0
# 2            TP53         17       7577117.0     7577117.0
# 3           MAML3          4     140811082.0   140811083.0
# 4           SF3B4          1     149895518.0   149895518.0
# ...           ...        ...             ...           ...
# 15129       SOGA2         18       8824961.0     8824961.0
# 15130       GATA3         10       8111513.0     8111514.0
# 15131       EPAS1          2      46525087.0    46525087.0
# 15132       CLOCK          4      56315636.0    56315636.0
# 15133       HCFC2         12     104492158.0   104492158.0
#
#       Variant_Classification Variant_Type Reference_Allele Tumor_Seq_Allele1  \
# 0          Nonsense_Mutation          SNP                G                 G
# 1            Frame_Shift_Ins          INS                -                 -
# 2          Missense_Mutation          SNP                A                 A
# 3               In_Frame_Ins          INS                -                 -
# 4          Missense_Mutation          SNP                C                 C
# ...                      ...          ...              ...               ...
# 15129                 Silent          SNP                C                 C
# 15130        Frame_Shift_Ins          INS                -                 -
# 15131                 Intron          SNP                G                 G
# 15132      Missense_Mutation          SNP                G                 G
# 15133      Missense_Mutation          SNP                C                 C
#
#        ...                                 HGVSc     HGVSp_Short  \
# 0      ...           ENST00000269305.4:c.1024C>T         p.R342*
# 1      ...  ENST00000263967.3:c.3205_3206insTTTT    p.*1069Ffs*5
# 2      ...            ENST00000269305.4:c.821T>G         p.V274G
# 3      ...   ENST00000509479.2:c.1508_1509insCAA  p.Q503delinsHK
# 4      ...           ENST00000271628.8:c.1191G>T         p.Q397H
# ...    ...                                   ...             ...
# 15129  ...          ENST00000306329.11:c.4410C>G        p.P1470=
# 15130  ...           ENST00000346208.3:c.1003dup    p.D335Gfs*17
# 15131  ...          ENST00000263734.3:c.26+11G>A           p.*9*
# 15132  ...           ENST00000309964.4:c.1376C>T         p.T459M
# 15133  ...           ENST00000229330.4:c.1778C>T         p.A593V
#
#          Transcript_ID Gene_length  ENSP             Hugo_variant  \
# 0      ENST00000269305       25760   NaN   TP53_Nonsense_Mutation
# 1      ENST00000263967       91980   NaN   PIK3CA_Frame_Shift_Ins
# 2      ENST00000269305       25760   NaN   TP53_Missense_Mutation
# 3      ENST00000509479      437432   NaN       MAML3_In_Frame_Ins
# 4      ENST00000271628        5028   NaN  SF3B4_Missense_Mutation
# ...                ...         ...   ...                      ...
# 15129  ENST00000306329      127118   NaN             SOGA2_Silent
# 15130  ENST00000346208       21595   NaN    GATA3_Frame_Shift_Ins
# 15131  ENST00000263734       93031   NaN             EPAS1_Intron
# 15132  ENST00000309964      119236   NaN  CLOCK_Missense_Mutation
# 15133  ENST00000229330       40405   NaN  HCFC2_Missense_Mutation
#
#       Mutation_length  Protein_position_start  Protein_position_end  \
# 0                 1.0                   342.0                 342.0
# 1                 2.0                  1069.0                1069.0
# 2                 1.0                   274.0                 274.0
# 3                 2.0                   503.0                 503.0
# 4                 1.0                   397.0                 397.0
# ...               ...                     ...                   ...
# 15129             1.0                  1470.0                1470.0
# 15130             2.0                   333.0                 333.0
# 15131             1.0                     NaN                   NaN
# 15132             1.0                   459.0                 459.0
# 15133             1.0                   593.0                 593.0
#
#        Protein_length
# 0                 393
# 1                1068
# 2                 393
# 3                1138
# 4                 424
# ...               ...
# 15129            1586
# 15130             444
# 15131             870
# 15132             846
# 15133             792
#
# [15134 rows x 21 columns]

# %%
# Create the rows for the occurrence matrix
# NOTE: consider directly the mutation dataset that is the result of the intersection between the significant mutations from MutSig and the total ductal dataset
# There are not the total ductal patients (1551) but just 1508, because not all the patients have mutations on the significant genes 
unique_patientIDs_with_sign_mut = significant_mutations_TNandNONTN_AND_total_ductal_onlyHugo.PATIENT_ID.unique()
unique_patientIDs_with_sign_mut
# Out:
# array(['brca_smc_2018_BB01_002', 'brca_smc_2018_BB01_004',
#        'brca_smc_2018_BB01_005', ..., 'MBCProject_yZSnSluK',
#        'MBCProject_ygcMFgCR', 'MBCProject_zyt5TKFB'], dtype=object)

# %%
len(unique_patientIDs_with_sign_mut)
# Out:
# 1508

# %% [markdown]
# ### Creation zeros matrix

# %%
def Matrice_zeri (columns, rows):
    df = pd.DataFrame(index=rows, columns=columns)
    df = df.fillna(0)
    return(df)

# %%
matrix_zeros_TNandNONTN_pval005_onlyHugo = Matrice_zeri(columns_occ_matrix_TNandNONTNgenes_pval005_onlyHugo, unique_patientIDs_with_sign_mut)
matrix_zeros_TNandNONTN_pval005_onlyHugo
# Out:
#                         TP53_270_282  GATA3_406_408  MAML3_503_503  \
# brca_smc_2018_BB01_002             0              0              0
# brca_smc_2018_BB01_004             0              0              0
# brca_smc_2018_BB01_005             0              0              0
# brca_smc_2018_BB01_006             0              0              0
# brca_smc_2018_BB01_008             0              0              0
# ...                              ...            ...            ...
# MBCProject_xlhkS5CG                0              0              0
# MBCProject_xoHAF6s8                0              0              0
# MBCProject_yZSnSluK                0              0              0
# MBCProject_ygcMFgCR                0              0              0
# MBCProject_zyt5TKFB                0              0              0
#
#                         AKT1_17_17  MYL10_26_26  PIK3R1_566_578  NUP93_14_15  \
# brca_smc_2018_BB01_002           0            0               0            0
# brca_smc_2018_BB01_004           0            0               0            0
# brca_smc_2018_BB01_005           0            0               0            0
# brca_smc_2018_BB01_006           0            0               0            0
# brca_smc_2018_BB01_008           0            0               0            0
# ...                            ...          ...             ...          ...
# MBCProject_xlhkS5CG              0            0               0            0
# MBCProject_xoHAF6s8              0            0               0            0
# MBCProject_yZSnSluK              0            0               0            0
# MBCProject_ygcMFgCR              0            0               0            0
# MBCProject_zyt5TKFB              0            0               0            0
#
#                         ZKSCAN1_270_270  CTCF_283_288  GATA3_308_335  ...  \
# brca_smc_2018_BB01_002                0             0              0  ...
# brca_smc_2018_BB01_004                0             0              0  ...
# brca_smc_2018_BB01_005                0             0              0  ...
# brca_smc_2018_BB01_006                0             0              0  ...
# brca_smc_2018_BB01_008                0             0              0  ...
# ...                                 ...           ...            ...  ...
# MBCProject_xlhkS5CG                   0             0              0  ...
# MBCProject_xoHAF6s8                   0             0              0  ...
# MBCProject_yZSnSluK                   0             0              0  ...
# MBCProject_ygcMFgCR                   0             0              0  ...
# MBCProject_zyt5TKFB                   0             0              0  ...
#
#                         KPNA6_noClust  FOXR1_noClust  HCRT_noClust  \
# brca_smc_2018_BB01_002              0              0             0
# brca_smc_2018_BB01_004              0              0             0
# brca_smc_2018_BB01_005              0              0             0
# brca_smc_2018_BB01_006              0              0             0
# brca_smc_2018_BB01_008              0              0             0
# ...                               ...            ...           ...
# MBCProject_xlhkS5CG                 0              0             0
# MBCProject_xoHAF6s8                 0              0             0
# MBCProject_yZSnSluK                 0              0             0
# MBCProject_ygcMFgCR                 0              0             0
# MBCProject_zyt5TKFB                 0              0             0
#
#                         FUT1_noClust  WDR38_noClust  SPG21_noClust  \
# brca_smc_2018_BB01_002             0              0              0
# brca_smc_2018_BB01_004             0              0              0
# brca_smc_2018_BB01_005             0              0              0
# brca_smc_2018_BB01_006             0              0              0
# brca_smc_2018_BB01_008             0              0              0
# ...                              ...            ...            ...
# MBCProject_xlhkS5CG                0              0              0
# MBCProject_xoHAF6s8                0              0              0
# MBCProject_yZSnSluK                0              0              0
# MBCProject_ygcMFgCR                0              0              0
# MBCProject_zyt5TKFB                0              0              0
#
#                         PFDN5_noClust  CCNT2_noClust  CSN2_noClust  \
# brca_smc_2018_BB01_002              0              0             0
# brca_smc_2018_BB01_004              0              0             0
# brca_smc_2018_BB01_005              0              0             0
# brca_smc_2018_BB01_006              0              0             0
# brca_smc_2018_BB01_008              0              0             0
# ...                               ...            ...           ...
# MBCProject_xlhkS5CG                 0              0             0
# MBCProject_xoHAF6s8                 0              0             0
# MBCProject_yZSnSluK                 0              0             0
# MBCProject_ygcMFgCR                 0              0             0
# MBCProject_zyt5TKFB                 0              0             0
#
#                         KRTAP5-1_noClust
# brca_smc_2018_BB01_002                 0
# brca_smc_2018_BB01_004                 0
# brca_smc_2018_BB01_005                 0
# brca_smc_2018_BB01_006                 0
# brca_smc_2018_BB01_008                 0
# ...                                  ...
# MBCProject_xlhkS5CG                    0
# MBCProject_xoHAF6s8                    0
# MBCProject_yZSnSluK                    0
# MBCProject_ygcMFgCR                    0
# MBCProject_zyt5TKFB                    0
#
# [1508 rows x 1071 columns]

# %% [markdown]
# The occurence matrix has 1508 rows (patients) and 1071 columns (gene clust and noClust).
#
# **NOTE:** 54 genes form clusters (the start and end positions of the clusters are indicated).

# %%
# select the relevant mutations from the total ductal dataset 
total_ductal_dataset_selected_signif_mutations_onlyHugo = total_ductal_dataset[total_ductal_dataset['Hugo_Symbol'].isin(unique_Hugo_symbols_array)]
total_ductal_dataset_selected_signif_mutations_onlyHugo
# Out:
#                     PATIENT_ID                      Tumor_Sample_Barcode  \
# 15      brca_smc_2018_BB01_002                    brca_smc_2018_BB01_002
# 18      brca_smc_2018_BB01_002                    brca_smc_2018_BB01_002
# 22      brca_smc_2018_BB01_004                    brca_smc_2018_BB01_004
# 25      brca_smc_2018_BB01_004                    brca_smc_2018_BB01_004
# 26      brca_smc_2018_BB01_005                    brca_smc_2018_BB01_005
# ...                        ...                                       ...
# 139294     MBCProject_ygcMFgCR  RP-1156_MBCProject_ygcMFgCR_T1A_v1_Exome
# 139312     MBCProject_ygcMFgCR  RP-1156_MBCProject_ygcMFgCR_T1A_v1_Exome
# 139317     MBCProject_zyt5TKFB    MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 139327     MBCProject_zyt5TKFB    MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 139347     MBCProject_zyt5TKFB    MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#        Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 15            TP53         17       7574003.0     7574003.0
# 18          PIK3CA          3     178952150.0   178952151.0
# 22            TP53         17       7577117.0     7577117.0
# 25           MAML3          4     140811082.0   140811083.0
# 26           SF3B4          1     149895518.0   149895518.0
# ...            ...        ...             ...           ...
# 139294       SOGA2         18       8824961.0     8824961.0
# 139312       GATA3         10       8111513.0     8111514.0
# 139317       EPAS1          2      46525087.0    46525087.0
# 139327       CLOCK          4      56315636.0    56315636.0
# 139347       HCFC2         12     104492158.0   104492158.0
#
#        Variant_Classification Variant_Type Reference_Allele Tumor_Seq_Allele1  \
# 15          Nonsense_Mutation          SNP                G                 G
# 18            Frame_Shift_Ins          INS                -                 -
# 22          Missense_Mutation          SNP                A                 A
# 25               In_Frame_Ins          INS                -                 -
# 26          Missense_Mutation          SNP                C                 C
# ...                       ...          ...              ...               ...
# 139294                 Silent          SNP                C                 C
# 139312        Frame_Shift_Ins          INS                -                 -
# 139317                 Intron          SNP                G                 G
# 139327      Missense_Mutation          SNP                G                 G
# 139347      Missense_Mutation          SNP                C                 C
#
#        Tumor_Seq_Allele2                                 HGVSc  \
# 15                     A           ENST00000269305.4:c.1024C>T
# 18                  TTTT  ENST00000263967.3:c.3205_3206insTTTT
# 22                     C            ENST00000269305.4:c.821T>G
# 25                   TGT   ENST00000509479.2:c.1508_1509insCAA
# 26                     A           ENST00000271628.8:c.1191G>T
# ...                  ...                                   ...
# 139294                 G          ENST00000306329.11:c.4410C>G
# 139312                 G           ENST00000346208.3:c.1003dup
# 139317                 A          ENST00000263734.3:c.26+11G>A
# 139327                 A           ENST00000309964.4:c.1376C>T
# 139347                 T           ENST00000229330.4:c.1778C>T
#
#            HGVSp_Short    Transcript_ID  Gene_length ENSP  \
# 15             p.R342*  ENST00000269305        25760  NaN
# 18        p.*1069Ffs*5  ENST00000263967        91980  NaN
# 22             p.V274G  ENST00000269305        25760  NaN
# 25      p.Q503delinsHK  ENST00000509479       437432  NaN
# 26             p.Q397H  ENST00000271628         5028  NaN
# ...                ...              ...          ...  ...
# 139294        p.P1470=  ENST00000306329       127118  NaN
# 139312    p.D335Gfs*17  ENST00000346208        21595  NaN
# 139317           p.*9*  ENST00000263734        93031  NaN
# 139327         p.T459M  ENST00000309964       119236  NaN
# 139347         p.A593V  ENST00000229330        40405  NaN
#
#                    Hugo_variant  Mutation_length  Protein_position_start  \
# 15       TP53_Nonsense_Mutation              1.0                   342.0
# 18       PIK3CA_Frame_Shift_Ins              2.0                  1069.0
# 22       TP53_Missense_Mutation              1.0                   274.0
# 25           MAML3_In_Frame_Ins              2.0                   503.0
# 26      SF3B4_Missense_Mutation              1.0                   397.0
# ...                         ...              ...                     ...
# 139294             SOGA2_Silent              1.0                  1470.0
# 139312    GATA3_Frame_Shift_Ins              2.0                   333.0
# 139317             EPAS1_Intron              1.0                     NaN
# 139327  CLOCK_Missense_Mutation              1.0                   459.0
# 139347  HCFC2_Missense_Mutation              1.0                   593.0
#
#         Protein_position_end
# 15                     342.0
# 18                    1069.0
# 22                     274.0
# 25                     503.0
# 26                     397.0
# ...                      ...
# 139294                1470.0
# 139312                 333.0
# 139317                   NaN
# 139327                 459.0
# 139347                 593.0
#
# [15134 rows x 20 columns]

# %%
total_ductal_dataset_selected_signif_mutations_onlyHugo.loc[total_ductal_dataset_selected_signif_mutations_onlyHugo['PATIENT_ID'] == 'brca_smc_2018_BB01_005']
# Out:
#                 PATIENT_ID    Tumor_Sample_Barcode Hugo_Symbol Chromosome  \
# 26  brca_smc_2018_BB01_005  brca_smc_2018_BB01_005       SF3B4          1
# 30  brca_smc_2018_BB01_005  brca_smc_2018_BB01_005         TTN          2
# 33  brca_smc_2018_BB01_005  brca_smc_2018_BB01_005      COL6A6          3
# 34  brca_smc_2018_BB01_005  brca_smc_2018_BB01_005      PIK3CA          3
# 52  brca_smc_2018_BB01_005  brca_smc_2018_BB01_005        TP53         17
# 54  brca_smc_2018_BB01_005  brca_smc_2018_BB01_005         NF1         17
#
#     Start_Position  End_Position Variant_Classification Variant_Type  \
# 26     149895518.0   149895518.0      Missense_Mutation          SNP
# 30     179504433.0   179504433.0      Missense_Mutation          SNP
# 33     130285953.0   130285953.0      Missense_Mutation          SNP
# 34     178952085.0   178952085.0      Missense_Mutation          SNP
# 52       7579415.0     7579415.0      Nonsense_Mutation          SNP
# 54      29664577.0    29664577.0      Nonsense_Mutation          SNP
#
#    Reference_Allele Tumor_Seq_Allele1 Tumor_Seq_Allele2  \
# 26                C                 C                 A
# 30                C                 C                 G
# 33                C                 C                 T
# 34                A                 A                 G
# 52                C                 C                 T
# 54                G                 G                 T
#
#                            HGVSc HGVSp_Short    Transcript_ID  Gene_length  \
# 26   ENST00000271628.8:c.1191G>T     p.Q397H  ENST00000271628         5028
# 30  ENST00000589042.1:c.40869G>C   p.K13623N  ENST00000589042       304814
# 33   ENST00000358511.6:c.1690C>T     p.H564Y  ENST00000358511       117822
# 34   ENST00000263967.3:c.3140A>G    p.H1047R  ENST00000263967        91980
# 52    ENST00000269305.4:c.272G>A      p.W91*  ENST00000269305        25760
# 54   ENST00000358273.4:c.6619G>T    p.E2207*  ENST00000358273       287190
#
#    ENSP              Hugo_variant  Mutation_length  Protein_position_start  \
# 26  NaN   SF3B4_Missense_Mutation              1.0                   397.0
# 30  NaN     TTN_Missense_Mutation              1.0                 13623.0
# 33  NaN  COL6A6_Missense_Mutation              1.0                   564.0
# 34  NaN  PIK3CA_Missense_Mutation              1.0                  1047.0
# 52  NaN    TP53_Nonsense_Mutation              1.0                    91.0
# 54  NaN     NF1_Nonsense_Mutation              1.0                  2207.0
#
#     Protein_position_end
# 26                 397.0
# 30               13623.0
# 33                 564.0
# 34                1047.0
# 52                  91.0
# 54                2207.0

# %% [markdown]
# ### Fill the matrix with values

# %%
def Riempimento_matrice(df_sign_mutations, matrix, freq_cluster):
    for index_mut, row_mut in df_sign_mutations.iterrows():
        found = False
        gene = row_mut.at['Hugo_Symbol']
        #consequence = row_mut.at['Variant_Classification']
        patient = row_mut.at['PATIENT_ID']
        position_start = row_mut.at['Protein_position_start']
        position_end = row_mut.at['Protein_position_end']
        
        for index_cluster, row_cluster in freq_cluster.iterrows():
            if (gene == row_cluster['Gene']) and (
                ((position_start >= row_cluster['Start']) and (position_start <= row_cluster['End'])) or 
                ((position_end >= row_cluster['Start']) and (position_end <= row_cluster['End']))
            ):
                matrix.at[patient, (gene + '_'+ str(row_cluster['Start']) + '_' + str(row_cluster['End']))] += 1
                found = True
                break
                
        if not found:
            matrix.at[patient, gene + '_noClust'] += 1
    
    return matrix

# %%
df_occurrence_matrix_TNandNONTNrelgenes_pval005_onlyHugo = Riempimento_matrice(total_ductal_dataset_selected_signif_mutations_onlyHugo, matrix_zeros_TNandNONTN_pval005_onlyHugo, freq_cluster_100_TNandNONTN_onlyHugo)
df_occurrence_matrix_TNandNONTNrelgenes_pval005_onlyHugo
# Out:
#                         TP53_270_282  GATA3_406_408  MAML3_503_503  \
# brca_smc_2018_BB01_002             0              0              0
# brca_smc_2018_BB01_004             1              0              1
# brca_smc_2018_BB01_005             0              0              0
# brca_smc_2018_BB01_006             0              0              0
# brca_smc_2018_BB01_008             0              0              0
# ...                              ...            ...            ...
# MBCProject_xlhkS5CG                0              0              0
# MBCProject_xoHAF6s8                0              0              0
# MBCProject_yZSnSluK                0              0              0
# MBCProject_ygcMFgCR                0              0              0
# MBCProject_zyt5TKFB                0              0              0
#
#                         AKT1_17_17  MYL10_26_26  PIK3R1_566_578  NUP93_14_15  \
# brca_smc_2018_BB01_002           0            0               0            0
# brca_smc_2018_BB01_004           0            0               0            0
# brca_smc_2018_BB01_005           0            0               0            0
# brca_smc_2018_BB01_006           0            0               0            0
# brca_smc_2018_BB01_008           0            0               0            0
# ...                            ...          ...             ...          ...
# MBCProject_xlhkS5CG              0            0               0            0
# MBCProject_xoHAF6s8              0            0               0            0
# MBCProject_yZSnSluK              0            0               0            0
# MBCProject_ygcMFgCR              0            0               0            0
# MBCProject_zyt5TKFB              0            0               0            0
#
#                         ZKSCAN1_270_270  CTCF_283_288  GATA3_308_335  ...  \
# brca_smc_2018_BB01_002                0             0              0  ...
# brca_smc_2018_BB01_004                0             0              0  ...
# brca_smc_2018_BB01_005                0             0              0  ...
# brca_smc_2018_BB01_006                0             0              0  ...
# brca_smc_2018_BB01_008                0             0              0  ...
# ...                                 ...           ...            ...  ...
# MBCProject_xlhkS5CG                   0             0              0  ...
# MBCProject_xoHAF6s8                   0             0              0  ...
# MBCProject_yZSnSluK                   0             0              0  ...
# MBCProject_ygcMFgCR                   0             0              1  ...
# MBCProject_zyt5TKFB                   0             0              0  ...
#
#                         KPNA6_noClust  FOXR1_noClust  HCRT_noClust  \
# brca_smc_2018_BB01_002              0              0             0
# brca_smc_2018_BB01_004              0              0             0
# brca_smc_2018_BB01_005              0              0             0
# brca_smc_2018_BB01_006              0              0             0
# brca_smc_2018_BB01_008              0              0             0
# ...                               ...            ...           ...
# MBCProject_xlhkS5CG                 0              0             0
# MBCProject_xoHAF6s8                 0              0             0
# MBCProject_yZSnSluK                 0              0             0
# MBCProject_ygcMFgCR                 0              0             0
# MBCProject_zyt5TKFB                 0              0             0
#
#                         FUT1_noClust  WDR38_noClust  SPG21_noClust  \
# brca_smc_2018_BB01_002             0              0              0
# brca_smc_2018_BB01_004             0              0              0
# brca_smc_2018_BB01_005             0              0              0
# brca_smc_2018_BB01_006             0              0              0
# brca_smc_2018_BB01_008             0              0              0
# ...                              ...            ...            ...
# MBCProject_xlhkS5CG                0              0              0
# MBCProject_xoHAF6s8                0              0              0
# MBCProject_yZSnSluK                0              0              0
# MBCProject_ygcMFgCR                0              0              0
# MBCProject_zyt5TKFB                0              0              0
#
#                         PFDN5_noClust  CCNT2_noClust  CSN2_noClust  \
# brca_smc_2018_BB01_002              0              0             0
# brca_smc_2018_BB01_004              0              0             0
# brca_smc_2018_BB01_005              0              0             0
# brca_smc_2018_BB01_006              0              0             0
# brca_smc_2018_BB01_008              0              0             0
# ...                               ...            ...           ...
# MBCProject_xlhkS5CG                 0              0             0
# MBCProject_xoHAF6s8                 0              0             0
# MBCProject_yZSnSluK                 0              0             0
# MBCProject_ygcMFgCR                 0              0             0
# MBCProject_zyt5TKFB                 0              0             0
#
#                         KRTAP5-1_noClust
# brca_smc_2018_BB01_002                 0
# brca_smc_2018_BB01_004                 0
# brca_smc_2018_BB01_005                 0
# brca_smc_2018_BB01_006                 0
# brca_smc_2018_BB01_008                 0
# ...                                  ...
# MBCProject_xlhkS5CG                    0
# MBCProject_xoHAF6s8                    0
# MBCProject_yZSnSluK                    0
# MBCProject_ygcMFgCR                    0
# MBCProject_zyt5TKFB                    0
#
# [1508 rows x 1071 columns]

# %%
# count the total number of values in the matrix, i.e., the total number of mutations
df_occurrence_matrix_TNandNONTNrelgenes_pval005_onlyHugo.sum().sum()
# Out:
# 15134

# %%
# count the number of rows containing all zero values 
df_occurrence_matrix_TNandNONTNrelgenes_pval005_onlyHugo[(df_occurrence_matrix_TNandNONTNrelgenes_pval005_onlyHugo == 0).all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [TP53_270_282, GATA3_406_408, MAML3_503_503, AKT1_17_17, MYL10_26_26, PIK3R1_566_578, NUP93_14_15, ZKSCAN1_270_270, CTCF_283_288, GATA3_308_335, PIK3CA_1046_1047, PIK3CA_541_542, PIK3CA_345_345, PIK3CA_102_113, FOXA1_254_268, MTMR12_520_521, PRB2_81_81, ERBB2_767_777, ZNF208_548_549, PIK3CA_545_546, KRAS_12_12, GATA3_429_434, ESR1_537_538, TP53_191_199, ZNF195_109_111, TP53_236_258, TP53_173_177, TBX3_210_218, ZNF814_303_311, C8orf44_38_39, CHD9_2120_2120, SF3B1_700_700, DNAH14_143_288, FAM208B_805_805, RBM27_719_719, ESR1_380_380, ABCG2_22_32, DAP3_331_331, ZNF716_294_294, DMXL2_1709_1740, ZNF19_280_280, MAP4K3_395_415, FGFR2_549_549, USP8_523_523, OR4D10_175_183, TMPRSS13_77_83, RUNX1_122_123, DDX5_134_141, FHDC1_57_57, PTEN_317_318, RCC2_271_278, NUP153_1299_1299, NOTCH2_2297_2303, FAM193A_1170_1214, TP53_noClust, PIK3CA_noClust, MAML3_noClust, SF3B4_noClust, TTN_noClust, COL6A6_noClust, NF1_noClust, KDM5B_noClust, ACACB_noClust, ATP11A_noClust, CXorf38_noClust, APEX2_noClust, STAT1_noClust, MLLT10_noClust, CDC20_noClust, COL5A3_noClust, MMS22L_noClust, KMT2C_noClust, LMTK2_noClust, PTEN_noClust, ZNF19_noClust, GPRIN1_noClust, KCNH6_noClust, TOR1AIP1_noClust, CCDC142_noClust, NIPBL_noClust, ITPKB_noClust, DNAH7_noClust, MDGA1_noClust, NFE2L3_noClust, TMEM261_noClust, FBRSL1_noClust, PALB2_noClust, KRTAP24-1_noClust, CBFB_noClust, ARID1A_noClust, JMJD6_noClust, ZNF546_noClust, MUC4_noClust, AKAP11_noClust, GALK1_noClust, SEC63_noClust, GATA3_noClust, COL17A1_noClust, NOTCH2_noClust, CFTR_noClust, ...]
# Index: []
#
# [0 rows x 1071 columns]

# %% [markdown]
# There aren't patients with no mutations in the significant genes.

# %%
# number of columns containing all zero values 
(df_occurrence_matrix_TNandNONTNrelgenes_pval005_onlyHugo == 0).all().sum()
# Out:
# 0

# %%
# sum the values for each row (patients): mutations for each patient
mutations_for_each_patient = df_occurrence_matrix_TNandNONTNrelgenes_pval005_onlyHugo.sum(axis=1).to_frame()
mutations_for_each_patient.rename(columns={0: "Mutation count for each patient"}, inplace=True)
mutations_for_each_patient
# Out:
#                         Mutation count for each patient
# brca_smc_2018_BB01_002                                2
# brca_smc_2018_BB01_004                                2
# brca_smc_2018_BB01_005                                6
# brca_smc_2018_BB01_006                                5
# brca_smc_2018_BB01_008                                3
# ...                                                 ...
# MBCProject_xlhkS5CG                                   4
# MBCProject_xoHAF6s8                                  16
# MBCProject_yZSnSluK                                   8
# MBCProject_ygcMFgCR                                  14
# MBCProject_zyt5TKFB                                   3
#
# [1508 rows x 1 columns]

# %%
mutations_for_each_patient.sum()
# Out:
# Mutation count for each patient    15134
# dtype: int64

# %% [markdown]
# ### Label the TN patients with 1 and the NON TN patients with 0

# %%
# Load the total TN mutation dataset and select the TN patients 
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi")
data_mutation_ductal_total_TN = pd.read_csv('mutation_table_ALL_DATASETS_ductal_TN_nohypo_nohyper.csv', sep=None, engine='python')
data_mutation_ductal_total_TN
# Out:
#                    PATIENT_ID                    Tumor_Sample_Barcode  \
# 0      brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 1      brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 2      brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 3      brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# 4      brca_smc_2018_BB01_004                  brca_smc_2018_BB01_004
# ...                       ...                                     ...
# 31982     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 31983     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 31984     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 31985     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
# 31986     MBCProject_wzCxuoio  MBC-MBCProject_wzCxuoio-Tumor-SM-GQCHG
#
#       Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0         TMEM131          2      98460725.0    98460725.0
# 1          DNAAF1         16      84188289.0    84188289.0
# 2            TP53         17       7577117.0     7577117.0
# 3            MATK         19       3778305.0     3778305.0
# 4             BAX         19      49459542.0    49459542.0
# ...           ...        ...             ...           ...
# 31982        VAV1         19       6836477.0     6836477.0
# 31983         ADA         20      43251667.0    43251667.0
# 31984       ABCG1         21      43711661.0    43711661.0
# 31985       TRPM2         21      45784140.0    45784140.0
# 31986      FBXO11          2      48066626.0    48066626.0
#
#       Variant_Classification Variant_Type Reference_Allele Tumor_Seq_Allele1  \
# 0                Splice_Site          SNP                C                 C
# 1          Missense_Mutation          SNP                C                 C
# 2          Missense_Mutation          SNP                A                 A
# 3          Missense_Mutation          SNP                C                 C
# 4          Nonsense_Mutation          SNP                G                 G
# ...                      ...          ...              ...               ...
# 31982                 Silent          SNP                C                 C
# 31983      Missense_Mutation          SNP                G                 G
# 31984                 Silent          SNP                G                 G
# 31985      Missense_Mutation          SNP                C                 C
# 31986        Frame_Shift_Del          DEL                G                 G
#
#       Tumor_Seq_Allele2                         HGVSc    HGVSp_Short  \
# 0                     T  ENST00000186436.5:c.484-1G>A  p.X162_splice
# 1                     T    ENST00000378553.5:c.460C>T        p.R154C
# 2                     C    ENST00000269305.4:c.821T>G        p.V274G
# 3                     A   ENST00000395045.2:c.1403G>T        p.R468L
# 4                     A    ENST00000293288.8:c.321G>A        p.W107*
# ...                 ...                           ...            ...
# 31982                 T   ENST00000602142.1:c.1812C>T        p.Y604=
# 31983                 A    ENST00000372874.4:c.659C>T        p.S220L
# 31984                 A   ENST00000361802.2:c.1584G>A        p.P528=
# 31985                 T    ENST00000300482.5:c.398C>T        p.T133M
# 31986                 -    ENST00000403359.3:c.374del        p.S125*
#
#       Protein_position    Transcript_ID  Gene_length  Target ENSP
# 0                162.0  ENST00000186436       239590     NaN  NaN
# 1                154.0  ENST00000378553        33509     NaN  NaN
# 2                274.0  ENST00000269305        25760     NaN  NaN
# 3                468.0  ENST00000395045        24157     NaN  NaN
# 4                107.0  ENST00000293288         6984     NaN  NaN
# ...                ...              ...          ...     ...  ...
# 31982            604.0  ENST00000602142        84653     NaN  NaN
# 31983            220.0  ENST00000372874        32712     NaN  NaN
# 31984            528.0  ENST00000361802        97556     NaN  NaN
# 31985            133.0  ENST00000300482        92919     NaN  NaN
# 31986            125.0  ENST00000403359       116478     NaN  NaN
#
# [31987 rows x 18 columns]

# %%
data_mutation_ductal_total_TN.PATIENT_ID.nunique()
# Out:
# 293

# %%
unique_patientsID_TN = data_mutation_ductal_total_TN['PATIENT_ID'].unique()
unique_patientsID_TN
# Out:
# array(['brca_smc_2018_BB01_004', 'brca_smc_2018_BB01_022',
#        'brca_smc_2018_BB01_026', 'brca_smc_2018_BB01_035',
#        'brca_smc_2018_BB01_037', 'brca_smc_2018_BB01_040',
#        'brca_smc_2018_BB01_041', 'brca_smc_2018_BB01_044',
#        'brca_smc_2018_BB01_059', 'brca_smc_2018_BB01_067',
#        'brca_smc_2018_BB01_074', 'brca_smc_2018_BB01_079',
#        'brca_smc_2018_BB01_094', 'brca_smc_2018_BB01_099',
#        'brca_smc_2018_BB01_109', 'brca_smc_2018_BB01_110',
#        'brca_smc_2018_BB01_119', 'brca_smc_2018_BB01_126',
#        'brca_smc_2018_BR017', 'brca_smc_2018_BR041',
#        'brca_smc_2018_BR078', 'brca_smc_2018_BR091',
#        'brca_smc_2018_BR094', 'brca_smc_2018_BR097',
#        'brca_smc_2018_BR105', 'brca_smc_2018_BR108',
#        'brca_smc_2018_BR145', 'brca_smc_2018_BR164',
#        'brca_smc_2018_BR200', 'brca_smc_2018_BR301',
#        'brca_smc_2018_BR313', 'brca_smc_2018_BR367',
#        'brca_smc_2018_BR393', 'brca_smc_2018_BR395',
#        'brca_smc_2018_BR419', 'BR-M-045', 'BR-M-080', 'BR-M-122',
#        'BR-M-174', 'PD3987a', 'PD4002a', 'PD4003a', 'PD4091a', 'PD4107a',
#        'PD4109a', 'PD4113a', 'PD4130a', 'PD4133a', 'PD4200a', 'PD4252a',
#        'PD4601a', 'PD4844a', 'CPT000814', 'CPT001846', 'X01BR001',
#        'X01BR009', 'X01BR010', 'X01BR020', 'X01BR026', 'X01BR027',
#        'X01BR031', 'X01BR040', 'X01BR042', 'X03BR006', 'X05BR029',
#        'X05BR042', 'X05BR043', 'X05BR045', 'X11BR003', 'X11BR016',
#        'X11BR017', 'X11BR023', 'X11BR024', 'X11BR036', 'X11BR042',
#        'X18BR002', 'X20BR005', 'X20BR007', 'X20BR008', 'TCGA-A1-A0SO',
#        'TCGA-A1-A0SP', 'TCGA-A2-A04P', 'TCGA-A2-A04Q', 'TCGA-A2-A04T',
#        'TCGA-A2-A04U', 'TCGA-A2-A0CM', 'TCGA-A2-A0D0', 'TCGA-A2-A0D2',
#        'TCGA-A2-A0ST', 'TCGA-A2-A0SX', 'TCGA-A2-A0T0', 'TCGA-A2-A0T2',
#        'TCGA-A2-A0YE', 'TCGA-A2-A0YJ', 'TCGA-A2-A0YM', 'TCGA-A2-A1G1',
#        'TCGA-A2-A25F', 'TCGA-A2-A3XT', 'TCGA-A2-A3XU', 'TCGA-A2-A3XX',
#        'TCGA-A2-A3Y0', 'TCGA-A7-A0CE', 'TCGA-A7-A0DA', 'TCGA-A7-A13D',
#        'TCGA-A7-A13E', 'TCGA-A7-A26I', 'TCGA-A7-A4SD', 'TCGA-A7-A4SE',
#        'TCGA-A7-A6VV', 'TCGA-A7-A6VW', 'TCGA-A7-A6VY', 'TCGA-A8-A07O',
#        'TCGA-A8-A07U', 'TCGA-A8-A08R', 'TCGA-AC-A2BK', 'TCGA-AC-A62X',
#        'TCGA-AC-A6IW', 'TCGA-AC-A8OQ', 'TCGA-AN-A04D', 'TCGA-AN-A0AL',
#        'TCGA-AN-A0AR', 'TCGA-AN-A0AT', 'TCGA-AN-A0FJ', 'TCGA-AN-A0FL',
#        'TCGA-AN-A0FX', 'TCGA-AN-A0XU', 'TCGA-AO-A0J4', 'TCGA-AO-A0J6',
#        'TCGA-AO-A129', 'TCGA-AO-A12F', 'TCGA-AO-A1KR', 'TCGA-AQ-A04J',
#        'TCGA-AR-A0TP', 'TCGA-AR-A0TS', 'TCGA-AR-A0U0', 'TCGA-AR-A0U4',
#        'TCGA-AR-A1AH', 'TCGA-AR-A1AI', 'TCGA-AR-A1AJ', 'TCGA-AR-A1AQ',
#        'TCGA-AR-A1AR', 'TCGA-AR-A1AY', 'TCGA-AR-A24Q', 'TCGA-AR-A251',
#        'TCGA-AR-A256', 'TCGA-B6-A0I1', 'TCGA-B6-A0I2', 'TCGA-B6-A0IJ',
#        'TCGA-B6-A0IQ', 'TCGA-B6-A0RE', 'TCGA-B6-A0RT', 'TCGA-B6-A0X1',
#        'TCGA-B6-A1KF', 'TCGA-B6-A409', 'TCGA-BH-A0AV', 'TCGA-BH-A0B3',
#        'TCGA-BH-A0B9', 'TCGA-BH-A0BG', 'TCGA-BH-A0BL', 'TCGA-BH-A0BW',
#        'TCGA-BH-A0E0', 'TCGA-BH-A0E6', 'TCGA-BH-A0RX', 'TCGA-BH-A18Q',
#        'TCGA-BH-A18T', 'TCGA-BH-A1F0', 'TCGA-BH-A1F6', 'TCGA-BH-A1FC',
#        'TCGA-BH-A5IZ', 'TCGA-C8-A12K', 'TCGA-C8-A12V', 'TCGA-C8-A131',
#        'TCGA-C8-A134', 'TCGA-C8-A1HJ', 'TCGA-C8-A27B', 'TCGA-D8-A142',
#        'TCGA-D8-A143', 'TCGA-D8-A147', 'TCGA-D8-A1JK', 'TCGA-D8-A1JL',
#        'TCGA-D8-A1JM', 'TCGA-D8-A27F', 'TCGA-D8-A27H', 'TCGA-D8-A27M',
#        'TCGA-E2-A14N', 'TCGA-E2-A14R', 'TCGA-E2-A14X', 'TCGA-E2-A14Y',
#        'TCGA-E2-A150', 'TCGA-E2-A158', 'TCGA-E2-A159', 'TCGA-E2-A1AZ',
#        'TCGA-E2-A1B6', 'TCGA-E2-A1II', 'TCGA-E2-A1LH', 'TCGA-E2-A1LI',
#        'TCGA-E2-A1LK', 'TCGA-E2-A1LL', 'TCGA-E2-A573', 'TCGA-E2-A574',
#        'TCGA-E9-A1N8', 'TCGA-E9-A1ND', 'TCGA-E9-A22G', 'TCGA-E9-A243',
#        'TCGA-E9-A244', 'TCGA-E9-A3QA', 'TCGA-EW-A1P4', 'TCGA-EW-A1P8',
#        'TCGA-EW-A1PB', 'TCGA-EW-A1PH', 'TCGA-EW-A6SB', 'TCGA-GM-A2DF',
#        'TCGA-GM-A3XL', 'TCGA-LL-A5YP', 'TCGA-LL-A6FR', 'TCGA-LL-A73Y',
#        'TCGA-OL-A5D7', 'TCGA-OL-A5RW', 'TCGA-OL-A5S0', 'TCGA-OL-A66I',
#        'TCGA-OL-A6VO', 'TCGA-PL-A8LV', 'TCGA-PL-A8LZ', 'TCGA-S3-AA0Z',
#        'TCGA-S3-AA10', 'TCGA-S3-AA15', 'MBC_182', 'MBC_195', 'MBC_204',
#        'MBC_205', 'MBC_206', 'MBC_208', 'MBC_215', 'MBC_85', 'MBC_87',
#        'MBC_91', 'MBC_93', 'MBC_105', 'MBC_120', 'MBC_124', 'MBC_127',
#        'MBC_132', 'MBC_137', 'MBC_141', 'MBC_142', 'MBC_143', 'MBC_152',
#        'MBC_153', 'MBC_157', 'MBC_163', 'MBC_167', 'MBC_174', 'MBC_181',
#        'MBC_1', 'MBC_5', 'MBC_9', 'MBC_10', 'MBC_19', 'MBC_24', 'MBC_25',
#        'MBC_26', 'MBC_31', 'MBC_33', 'MBC_37', 'MBC_42', 'MBC_44',
#        'MBC_47', 'MBC_48', 'MBC_53', 'MBC_54', 'MBC_55', 'MBC_60',
#        'MBC_67', 'MBC_69', 'MBC_80', 'MBCProject_0aTBfPcG',
#        'MBCProject_6vTVHzur', 'MBCProject_7VFnIqfw',
#        'MBCProject_8bfWIQu1', 'MBCProject_AwukckTD',
#        'MBCProject_AzCnt3sL', 'MBCProject_DximH6Cn',
#        'MBCProject_EkHAIECZ', 'MBCProject_Gxhdtafa',
#        'MBCProject_JpCASlSG', 'MBCProject_QJFdf8hQ',
#        'MBCProject_d5CbUNTb', 'MBCProject_epUYsdCE',
#        'MBCProject_lQtMtjFR', 'MBCProject_oqupfDu7',
#        'MBCProject_pMcWcrtZ', 'MBCProject_rJHBiKTl',
#        'MBCProject_wzCxuoio'], dtype=object)

# %%
data_mutation_ductal_total_TN.PATIENT_ID.nunique()
# Out:
# 293

# %%
len(unique_patientsID_TN)
# Out:
# 293

# %%
# Load the total NON TN mutation dataset and select the NON TN patients 
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi")
data_mutation_ductal_total_NON_TN = pd.read_csv('mutation_table_ALL_DATASETS_ductal_NONTN_nohypo_nohyper.csv', sep=None, engine='python') 
data_mutation_ductal_total_NON_TN
# Out:
#                     PATIENT_ID                    Tumor_Sample_Barcode  \
# 0       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 1       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 2       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 3       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# 4       brca_smc_2018_BB01_002                  brca_smc_2018_BB01_002
# ...                        ...                                     ...
# 141476     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 141477     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 141478     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 141479     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
# 141480     MBCProject_zyt5TKFB  MBC-MBCProject_zyt5TKFB-Tumor-SM-CGM59
#
#        Hugo_Symbol Chromosome  Start_Position  End_Position  \
# 0            KALRN          3     123988087.0   123988087.0
# 1             ANK2          4     114195720.0   114195720.0
# 2           SORBS2          4     186539742.0   186539742.0
# 3          PCDHA11          5     140250828.0   140250828.0
# 4           WRNIP1          6       2766210.0     2766210.0
# ...            ...        ...             ...           ...
# 141476       NRSN2         20        333991.0      333991.0
# 141477      CHRNA4         20      61986887.0    61986887.0
# 141478      CHRNA4         20      61987386.0    61987386.0
# 141479       KCNQ2         20      62078103.0    62078103.0
# 141480        XBP1         22      29191563.0    29191563.0
#
#        Variant_Classification Variant_Type Reference_Allele Tumor_Seq_Allele1  \
# 0           Missense_Mutation          SNP                G                 G
# 1           Missense_Mutation          SNP                C                 C
# 2           Missense_Mutation          SNP                G                 G
# 3           Missense_Mutation          SNP                C                 C
# 4           Missense_Mutation          SNP                C                 C
# ...                       ...          ...              ...               ...
# 141476                 Silent          SNP                C                 C
# 141477                 Intron          SNP                G                 G
# 141478                 Silent          SNP                G                 G
# 141479                 Silent          SNP                G                 G
# 141480      Nonsense_Mutation          SNP                G                 G
#
#        Tumor_Seq_Allele2                           HGVSc HGVSp_Short  \
# 0                      C      ENST00000240874.3:c.948G>C     p.E316D
# 1                      T     ENST00000357077.4:c.1598C>T     p.P533L
# 2                      C     ENST00000355634.5:c.2936C>G     p.S979C
# 3                      G     ENST00000398640.2:c.2140C>G     p.L714V
# 4                      A      ENST00000380773.4:c.354C>A     p.S118R
# ...                  ...                             ...         ...
# 141476                 T      ENST00000382285.2:c.327C>T     p.N109=
# 141477                 C  ENST00000370263.4:c.383+440C>G     p.*128*
# 141478                 A      ENST00000370263.4:c.324C>T     p.V108=
# 141479                 A      ENST00000359125.2:c.384C>T     p.I128=
# 141480                 A      ENST00000216037.6:c.757C>T     p.Q253*
#
#        Protein_position    Transcript_ID  Gene_length  Target ENSP
# 0                 316.0  ENST00000240874       646303     NaN  NaN
# 1                 533.0  ENST00000357077       565632     NaN  NaN
# 2                 979.0  ENST00000355634       371209     NaN  NaN
# 3                 714.0  ENST00000398640       143241     NaN  NaN
# 4                 118.0  ENST00000380773        21539     NaN  NaN
# ...                 ...              ...          ...     ...  ...
# 141476            109.0  ENST00000382285        12879     NaN  NaN
# 141477              NaN  ENST00000370263        34334     NaN  NaN
# 141478            108.0  ENST00000370263        34334     NaN  NaN
# 141479            128.0  ENST00000359125        66452     NaN  NaN
# 141480            253.0  ENST00000216037         6043     NaN  NaN
#
# [141481 rows x 18 columns]

# %%
data_mutation_ductal_total_NON_TN.PATIENT_ID.nunique()
# Out:
# 1381

# %%
unique_patientsID_NONTN = data_mutation_ductal_total_NON_TN['PATIENT_ID'].unique()
unique_patientsID_NONTN
# Out:
# array(['brca_smc_2018_BB01_002', 'brca_smc_2018_BB01_005',
#        'brca_smc_2018_BB01_006', ..., 'MBCProject_yZSnSluK',
#        'MBCProject_ygcMFgCR', 'MBCProject_zyt5TKFB'], dtype=object)

# %%
len(unique_patientsID_NONTN)
# Out:
# 1381

# %%
unique_patientIDs_with_sign_mut
# Out:
# array(['brca_smc_2018_BB01_002', 'brca_smc_2018_BB01_004',
#        'brca_smc_2018_BB01_005', ..., 'MBCProject_yZSnSluK',
#        'MBCProject_ygcMFgCR', 'MBCProject_zyt5TKFB'], dtype=object)

# %%
len(unique_patientIDs_with_sign_mut)
# Out:
# 1508

# %%
# create the column with the target for each patient 
def target(indexes_patientID):
    TN_patientIDs = unique_patientsID_TN
    NON_TN_patientsIDs = unique_patientsID_NONTN
    
    target = pd.DataFrame(index=indexes_patientID, columns=['Target'])
    target['Target'] = 0  # Initialize all labels to 0
    
    for i in indexes_patientID:
        if i in TN_patientIDs:
            target.loc[i, 'Target'] = 1
    
    return (target)

# %%
target_relgenes_TNandNONTN_pval005 = target(unique_patientIDs_with_sign_mut)
target_relgenes_TNandNONTN_pval005
# Out:
#                         Target
# brca_smc_2018_BB01_002       0
# brca_smc_2018_BB01_004       1
# brca_smc_2018_BB01_005       0
# brca_smc_2018_BB01_006       0
# brca_smc_2018_BB01_008       0
# ...                        ...
# MBCProject_xlhkS5CG          0
# MBCProject_xoHAF6s8          0
# MBCProject_yZSnSluK          0
# MBCProject_ygcMFgCR          0
# MBCProject_zyt5TKFB          0
#
# [1508 rows x 1 columns]

# %%
# add the label column to the occurrence matrix 
Matrix_TNandNONTNrelgenes_pval005_withLabels_onlyHugo = df_occurrence_matrix_TNandNONTNrelgenes_pval005_onlyHugo.assign(Target=target_relgenes_TNandNONTN_pval005)
Matrix_TNandNONTNrelgenes_pval005_withLabels_onlyHugo
# Out:
#                         TP53_270_282  GATA3_406_408  MAML3_503_503  \
# brca_smc_2018_BB01_002             0              0              0
# brca_smc_2018_BB01_004             1              0              1
# brca_smc_2018_BB01_005             0              0              0
# brca_smc_2018_BB01_006             0              0              0
# brca_smc_2018_BB01_008             0              0              0
# ...                              ...            ...            ...
# MBCProject_xlhkS5CG                0              0              0
# MBCProject_xoHAF6s8                0              0              0
# MBCProject_yZSnSluK                0              0              0
# MBCProject_ygcMFgCR                0              0              0
# MBCProject_zyt5TKFB                0              0              0
#
#                         AKT1_17_17  MYL10_26_26  PIK3R1_566_578  NUP93_14_15  \
# brca_smc_2018_BB01_002           0            0               0            0
# brca_smc_2018_BB01_004           0            0               0            0
# brca_smc_2018_BB01_005           0            0               0            0
# brca_smc_2018_BB01_006           0            0               0            0
# brca_smc_2018_BB01_008           0            0               0            0
# ...                            ...          ...             ...          ...
# MBCProject_xlhkS5CG              0            0               0            0
# MBCProject_xoHAF6s8              0            0               0            0
# MBCProject_yZSnSluK              0            0               0            0
# MBCProject_ygcMFgCR              0            0               0            0
# MBCProject_zyt5TKFB              0            0               0            0
#
#                         ZKSCAN1_270_270  CTCF_283_288  GATA3_308_335  ...  \
# brca_smc_2018_BB01_002                0             0              0  ...
# brca_smc_2018_BB01_004                0             0              0  ...
# brca_smc_2018_BB01_005                0             0              0  ...
# brca_smc_2018_BB01_006                0             0              0  ...
# brca_smc_2018_BB01_008                0             0              0  ...
# ...                                 ...           ...            ...  ...
# MBCProject_xlhkS5CG                   0             0              0  ...
# MBCProject_xoHAF6s8                   0             0              0  ...
# MBCProject_yZSnSluK                   0             0              0  ...
# MBCProject_ygcMFgCR                   0             0              1  ...
# MBCProject_zyt5TKFB                   0             0              0  ...
#
#                         FOXR1_noClust  HCRT_noClust  FUT1_noClust  \
# brca_smc_2018_BB01_002              0             0             0
# brca_smc_2018_BB01_004              0             0             0
# brca_smc_2018_BB01_005              0             0             0
# brca_smc_2018_BB01_006              0             0             0
# brca_smc_2018_BB01_008              0             0             0
# ...                               ...           ...           ...
# MBCProject_xlhkS5CG                 0             0             0
# MBCProject_xoHAF6s8                 0             0             0
# MBCProject_yZSnSluK                 0             0             0
# MBCProject_ygcMFgCR                 0             0             0
# MBCProject_zyt5TKFB                 0             0             0
#
#                         WDR38_noClust  SPG21_noClust  PFDN5_noClust  \
# brca_smc_2018_BB01_002              0              0              0
# brca_smc_2018_BB01_004              0              0              0
# brca_smc_2018_BB01_005              0              0              0
# brca_smc_2018_BB01_006              0              0              0
# brca_smc_2018_BB01_008              0              0              0
# ...                               ...            ...            ...
# MBCProject_xlhkS5CG                 0              0              0
# MBCProject_xoHAF6s8                 0              0              0
# MBCProject_yZSnSluK                 0              0              0
# MBCProject_ygcMFgCR                 0              0              0
# MBCProject_zyt5TKFB                 0              0              0
#
#                         CCNT2_noClust  CSN2_noClust  KRTAP5-1_noClust  Target
# brca_smc_2018_BB01_002              0             0                 0       0
# brca_smc_2018_BB01_004              0             0                 0       1
# brca_smc_2018_BB01_005              0             0                 0       0
# brca_smc_2018_BB01_006              0             0                 0       0
# brca_smc_2018_BB01_008              0             0                 0       0
# ...                               ...           ...               ...     ...
# MBCProject_xlhkS5CG                 0             0                 0       0
# MBCProject_xoHAF6s8                 0             0                 0       0
# MBCProject_yZSnSluK                 0             0                 0       0
# MBCProject_ygcMFgCR                 0             0                 0       0
# MBCProject_zyt5TKFB                 0             0                 0       0
#
# [1508 rows x 1072 columns]

# %% [markdown]
# **NOTE:**
# - Label = 1 : TN patient
# - Label = 0 : NON TN patient

# %%
# sum the values for each column (mutations)
mutations_sum = Matrix_TNandNONTNrelgenes_pval005_withLabels_onlyHugo.sum().to_frame()
mutations_sum.rename(columns={0: "Mutation count"}, inplace=True)
mutations_sum
# Out:
#                   Mutation count
# TP53_270_282                  78
# GATA3_406_408                 29
# MAML3_503_503                  7
# AKT1_17_17                    41
# MYL10_26_26                    7
# ...                          ...
# PFDN5_noClust                  3
# CCNT2_noClust                  2
# CSN2_noClust                   1
# KRTAP5-1_noClust               3
# Target                       291
#
# [1072 rows x 1 columns]

# %% [markdown]
# NOTE:
# - 291 patients are Triple-Negative
# - 1217 patients are NO Triple-Negative

# %%
# save the occurrence matrix 
os.chdir("C:/Users/Cristina/OneDrive/Documenti/BCG/Tesi/Occurrence matrix data_definitivo")
Matrix_TNandNONTNrelgenes_pval005_withLabels_onlyHugo.to_csv('Occurrence_Matrix_TNandNONTNrelgenes_pval005_withLabels_ONLYHUGO_definitivo.csv', index=True, sep='\t')

# %% [markdown]
# ### Study which TN patients are discarded because they don't contain mutations on the relevant genes from MutSig

# %%
# occurrence matrix with only TN patients 
Matrix_1A_withLabels = Matrix_TNandNONTNrelgenes_pval005_withLabels_onlyHugo.loc[Matrix_TNandNONTNrelgenes_pval005_withLabels_onlyHugo['Target']==1]
Matrix_1A_withLabels
# Out:
#                         TP53_270_282  GATA3_406_408  MAML3_503_503  \
# brca_smc_2018_BB01_004             1              0              1
# brca_smc_2018_BB01_022             0              0              0
# brca_smc_2018_BB01_026             0              0              0
# brca_smc_2018_BB01_035             0              0              0
# brca_smc_2018_BB01_037             0              0              0
# ...                              ...            ...            ...
# MBCProject_lQtMtjFR                0              0              0
# MBCProject_oqupfDu7                0              0              0
# MBCProject_pMcWcrtZ                0              0              0
# MBCProject_rJHBiKTl                0              0              0
# MBCProject_wzCxuoio                0              0              0
#
#                         AKT1_17_17  MYL10_26_26  PIK3R1_566_578  NUP93_14_15  \
# brca_smc_2018_BB01_004           0            0               0            0
# brca_smc_2018_BB01_022           0            0               0            0
# brca_smc_2018_BB01_026           0            0               0            0
# brca_smc_2018_BB01_035           0            0               0            0
# brca_smc_2018_BB01_037           0            0               0            0
# ...                            ...          ...             ...          ...
# MBCProject_lQtMtjFR              0            0               0            0
# MBCProject_oqupfDu7              0            0               0            0
# MBCProject_pMcWcrtZ              0            0               0            0
# MBCProject_rJHBiKTl              0            0               0            0
# MBCProject_wzCxuoio              0            0               0            0
#
#                         ZKSCAN1_270_270  CTCF_283_288  GATA3_308_335  ...  \
# brca_smc_2018_BB01_004                0             0              0  ...
# brca_smc_2018_BB01_022                0             0              0  ...
# brca_smc_2018_BB01_026                0             0              0  ...
# brca_smc_2018_BB01_035                0             0              0  ...
# brca_smc_2018_BB01_037                0             0              0  ...
# ...                                 ...           ...            ...  ...
# MBCProject_lQtMtjFR                   0             0              0  ...
# MBCProject_oqupfDu7                   0             0              0  ...
# MBCProject_pMcWcrtZ                   0             0              0  ...
# MBCProject_rJHBiKTl                   0             0              0  ...
# MBCProject_wzCxuoio                   0             0              0  ...
#
#                         FOXR1_noClust  HCRT_noClust  FUT1_noClust  \
# brca_smc_2018_BB01_004              0             0             0
# brca_smc_2018_BB01_022              0             0             0
# brca_smc_2018_BB01_026              0             0             0
# brca_smc_2018_BB01_035              0             0             0
# brca_smc_2018_BB01_037              0             0             0
# ...                               ...           ...           ...
# MBCProject_lQtMtjFR                 0             0             0
# MBCProject_oqupfDu7                 0             0             0
# MBCProject_pMcWcrtZ                 1             0             0
# MBCProject_rJHBiKTl                 0             0             0
# MBCProject_wzCxuoio                 0             0             0
#
#                         WDR38_noClust  SPG21_noClust  PFDN5_noClust  \
# brca_smc_2018_BB01_004              0              0              0
# brca_smc_2018_BB01_022              0              0              0
# brca_smc_2018_BB01_026              0              0              0
# brca_smc_2018_BB01_035              0              0              0
# brca_smc_2018_BB01_037              0              0              0
# ...                               ...            ...            ...
# MBCProject_lQtMtjFR                 0              0              0
# MBCProject_oqupfDu7                 0              0              0
# MBCProject_pMcWcrtZ                 0              0              0
# MBCProject_rJHBiKTl                 0              0              0
# MBCProject_wzCxuoio                 0              0              0
#
#                         CCNT2_noClust  CSN2_noClust  KRTAP5-1_noClust  Target
# brca_smc_2018_BB01_004              0             0                 0       1
# brca_smc_2018_BB01_022              0             0                 0       1
# brca_smc_2018_BB01_026              0             0                 0       1
# brca_smc_2018_BB01_035              0             0                 0       1
# brca_smc_2018_BB01_037              0             0                 0       1
# ...                               ...           ...               ...     ...
# MBCProject_lQtMtjFR                 0             0                 0       1
# MBCProject_oqupfDu7                 0             0                 0       1
# MBCProject_pMcWcrtZ                 0             0                 0       1
# MBCProject_rJHBiKTl                 0             0                 0       1
# MBCProject_wzCxuoio                 0             0                 0       1
#
# [291 rows x 1072 columns]

# %%
TN_pts_1A = Matrix_1A_withLabels.index.to_list()
TN_pts_1A
# Out:
# ['brca_smc_2018_BB01_004',
#  'brca_smc_2018_BB01_022',
#  'brca_smc_2018_BB01_026',
#  'brca_smc_2018_BB01_035',
#  'brca_smc_2018_BB01_037',
#  'brca_smc_2018_BB01_040',
#  'brca_smc_2018_BB01_041',
#  'brca_smc_2018_BB01_044',
#  'brca_smc_2018_BB01_059',
#  'brca_smc_2018_BB01_067',
#  'brca_smc_2018_BB01_074',
#  'brca_smc_2018_BB01_079',
#  'brca_smc_2018_BB01_094',
#  'brca_smc_2018_BB01_099',
#  'brca_smc_2018_BB01_109',
#  'brca_smc_2018_BB01_110',
#  'brca_smc_2018_BB01_119',
#  'brca_smc_2018_BB01_126',
#  'brca_smc_2018_BR017',
#  'brca_smc_2018_BR041',
#  'brca_smc_2018_BR078',
#  'brca_smc_2018_BR091',
#  'brca_smc_2018_BR094',
#  'brca_smc_2018_BR097',
#  'brca_smc_2018_BR105',
#  'brca_smc_2018_BR108',
#  'brca_smc_2018_BR145',
#  'brca_smc_2018_BR164',
#  'brca_smc_2018_BR200',
#  'brca_smc_2018_BR301',
#  'brca_smc_2018_BR313',
#  'brca_smc_2018_BR367',
#  'brca_smc_2018_BR393',
#  'brca_smc_2018_BR395',
#  'brca_smc_2018_BR419',
#  'BR-M-045',
#  'BR-M-122',
#  'BR-M-174',
#  'PD3987a',
#  'PD4002a',
#  'PD4003a',
#  'PD4091a',
#  'PD4107a',
#  'PD4109a',
#  'PD4113a',
#  'PD4130a',
#  'PD4133a',
#  'PD4200a',
#  'PD4252a',
#  'PD4601a',
#  'PD4844a',
#  'CPT000814',
#  'CPT001846',
#  'X01BR001',
#  'X01BR009',
#  'X01BR010',
#  'X01BR020',
#  'X01BR026',
#  'X01BR027',
#  'X01BR031',
#  'X01BR040',
#  'X01BR042',
#  'X03BR006',
#  'X05BR029',
#  'X05BR042',
#  'X05BR043',
#  'X05BR045',
#  'X11BR003',
#  'X11BR016',
#  'X11BR017',
#  'X11BR023',
#  'X11BR024',
#  'X11BR036',
#  'X11BR042',
#  'X18BR002',
#  'X20BR005',
#  'X20BR007',
#  'X20BR008',
#  'TCGA-A1-A0SO',
#  'TCGA-A1-A0SP',
#  'TCGA-A2-A04P',
#  'TCGA-A2-A04Q',
#  'TCGA-A2-A04T',
#  'TCGA-A2-A04U',
#  'TCGA-A2-A0CM',
#  'TCGA-A2-A0D0',
#  'TCGA-A2-A0D2',
#  'TCGA-A2-A0ST',
#  'TCGA-A2-A0SX',
#  'TCGA-A2-A0T0',
#  'TCGA-A2-A0T2',
#  'TCGA-A2-A0YE',
#  'TCGA-A2-A0YJ',
#  'TCGA-A2-A0YM',
#  'TCGA-A2-A1G1',
#  'TCGA-A2-A3XT',
#  'TCGA-A2-A3XU',
#  'TCGA-A2-A3XX',
#  'TCGA-A2-A3Y0',
#  'TCGA-A7-A0CE',
#  'TCGA-A7-A0DA',
#  'TCGA-A7-A13D',
#  'TCGA-A7-A13E',
#  'TCGA-A7-A26I',
#  'TCGA-A7-A4SD',
#  'TCGA-A7-A4SE',
#  'TCGA-A7-A6VV',
#  'TCGA-A7-A6VW',
#  'TCGA-A7-A6VY',
#  'TCGA-A8-A07O',
#  'TCGA-A8-A07U',
#  'TCGA-A8-A08R',
#  'TCGA-AC-A2BK',
#  'TCGA-AC-A62X',
#  'TCGA-AC-A6IW',
#  'TCGA-AC-A8OQ',
#  'TCGA-AN-A04D',
#  'TCGA-AN-A0AL',
#  'TCGA-AN-A0AR',
#  'TCGA-AN-A0AT',
#  'TCGA-AN-A0FJ',
#  'TCGA-AN-A0FL',
#  'TCGA-AN-A0FX',
#  'TCGA-AN-A0XU',
#  'TCGA-AO-A0J4',
#  'TCGA-AO-A0J6',
#  'TCGA-AO-A129',
#  'TCGA-AO-A12F',
#  'TCGA-AO-A1KR',
#  'TCGA-AQ-A04J',
#  'TCGA-AR-A0TP',
#  'TCGA-AR-A0TS',
#  'TCGA-AR-A0U0',
#  'TCGA-AR-A0U4',
#  'TCGA-AR-A1AH',
#  'TCGA-AR-A1AI',
#  'TCGA-AR-A1AJ',
#  'TCGA-AR-A1AQ',
#  'TCGA-AR-A1AR',
#  'TCGA-AR-A1AY',
#  'TCGA-AR-A24Q',
#  'TCGA-AR-A251',
#  'TCGA-AR-A256',
#  'TCGA-B6-A0I1',
#  'TCGA-B6-A0I2',
#  'TCGA-B6-A0IJ',
#  'TCGA-B6-A0IQ',
#  'TCGA-B6-A0RE',
#  'TCGA-B6-A0RT',
#  'TCGA-B6-A0X1',
#  'TCGA-B6-A1KF',
#  'TCGA-B6-A409',
#  'TCGA-BH-A0AV',
#  'TCGA-BH-A0B3',
#  'TCGA-BH-A0B9',
#  'TCGA-BH-A0BG',
#  'TCGA-BH-A0BL',
#  'TCGA-BH-A0BW',
#  'TCGA-BH-A0E0',
#  'TCGA-BH-A0E6',
#  'TCGA-BH-A0RX',
#  'TCGA-BH-A18Q',
#  'TCGA-BH-A18T',
#  'TCGA-BH-A1F0',
#  'TCGA-BH-A1F6',
#  'TCGA-BH-A1FC',
#  'TCGA-BH-A5IZ',
#  'TCGA-C8-A12K',
#  'TCGA-C8-A12V',
#  'TCGA-C8-A131',
#  'TCGA-C8-A134',
#  'TCGA-C8-A1HJ',
#  'TCGA-C8-A27B',
#  'TCGA-D8-A142',
#  'TCGA-D8-A143',
#  'TCGA-D8-A147',
#  'TCGA-D8-A1JK',
#  'TCGA-D8-A1JL',
#  'TCGA-D8-A1JM',
#  'TCGA-D8-A27F',
#  'TCGA-D8-A27H',
#  'TCGA-D8-A27M',
#  'TCGA-E2-A14N',
#  'TCGA-E2-A14R',
#  'TCGA-E2-A14X',
#  'TCGA-E2-A14Y',
#  'TCGA-E2-A150',
#  'TCGA-E2-A158',
#  'TCGA-E2-A159',
#  'TCGA-E2-A1AZ',
#  'TCGA-E2-A1B6',
#  'TCGA-E2-A1II',
#  'TCGA-E2-A1LH',
#  'TCGA-E2-A1LI',
#  'TCGA-E2-A1LK',
#  'TCGA-E2-A1LL',
#  'TCGA-E2-A573',
#  'TCGA-E2-A574',
#  'TCGA-E9-A1N8',
#  'TCGA-E9-A1ND',
#  'TCGA-E9-A22G',
#  'TCGA-E9-A243',
#  'TCGA-E9-A244',
#  'TCGA-E9-A3QA',
#  'TCGA-EW-A1P4',
#  'TCGA-EW-A1P8',
#  'TCGA-EW-A1PB',
#  'TCGA-EW-A1PH',
#  'TCGA-EW-A6SB',
#  'TCGA-GM-A2DF',
#  'TCGA-GM-A3XL',
#  'TCGA-LL-A5YP',
#  'TCGA-LL-A6FR',
#  'TCGA-LL-A73Y',
#  'TCGA-OL-A5D7',
#  'TCGA-OL-A5RW',
#  'TCGA-OL-A5S0',
#  'TCGA-OL-A66I',
#  'TCGA-OL-A6VO',
#  'TCGA-PL-A8LV',
#  'TCGA-PL-A8LZ',
#  'TCGA-S3-AA0Z',
#  'TCGA-S3-AA10',
#  'TCGA-S3-AA15',
#  'MBC_85',
#  'MBC_87',
#  'MBC_91',
#  'MBC_93',
#  'MBC_105',
#  'MBC_120',
#  'MBC_124',
#  'MBC_127',
#  'MBC_132',
#  'MBC_137',
#  'MBC_141',
#  'MBC_142',
#  'MBC_143',
#  'MBC_152',
#  'MBC_153',
#  'MBC_157',
#  'MBC_163',
#  'MBC_167',
#  'MBC_174',
#  'MBC_181',
#  'MBC_1',
#  'MBC_5',
#  'MBC_9',
#  'MBC_10',
#  'MBC_19',
#  'MBC_24',
#  'MBC_25',
#  'MBC_26',
#  'MBC_31',
#  'MBC_33',
#  'MBC_37',
#  'MBC_42',
#  'MBC_44',
#  'MBC_47',
#  'MBC_48',
#  'MBC_53',
#  'MBC_54',
#  'MBC_55',
#  'MBC_60',
#  'MBC_67',
#  'MBC_69',
#  'MBC_80',
#  'MBC_182',
#  'MBC_195',
#  'MBC_204',
#  'MBC_205',
#  'MBC_206',
#  'MBC_208',
#  'MBC_215',
#  'MBCProject_0aTBfPcG',
#  'MBCProject_6vTVHzur',
#  'MBCProject_7VFnIqfw',
#  'MBCProject_8bfWIQu1',
#  'MBCProject_AwukckTD',
#  'MBCProject_AzCnt3sL',
#  'MBCProject_DximH6Cn',
#  'MBCProject_EkHAIECZ',
#  'MBCProject_Gxhdtafa',
#  'MBCProject_JpCASlSG',
#  'MBCProject_QJFdf8hQ',
#  'MBCProject_d5CbUNTb',
#  'MBCProject_epUYsdCE',
#  'MBCProject_lQtMtjFR',
#  'MBCProject_oqupfDu7',
#  'MBCProject_pMcWcrtZ',
#  'MBCProject_rJHBiKTl',
#  'MBCProject_wzCxuoio']

# %%
all_TN_pts = data_mutation_ductal_total_TN[['PATIENT_ID']]
all_TN_pts = all_TN_pts.drop_duplicates()
all_TN_pts
# Out:
#                    PATIENT_ID
# 0      brca_smc_2018_BB01_004
# 6      brca_smc_2018_BB01_022
# 14     brca_smc_2018_BB01_026
# 85     brca_smc_2018_BB01_035
# 98     brca_smc_2018_BB01_037
# ...                       ...
# 31427     MBCProject_lQtMtjFR
# 31569     MBCProject_oqupfDu7
# 31711     MBCProject_pMcWcrtZ
# 31853     MBCProject_rJHBiKTl
# 31939     MBCProject_wzCxuoio
#
# [293 rows x 1 columns]

# %%
# which are the 6 patients excluded from the analyses??
all_TN_pts[~all_TN_pts['PATIENT_ID'].isin(TN_pts_1A)]
# Out:
#         PATIENT_ID
# 1978      BR-M-080
# 9715  TCGA-A2-A25F
